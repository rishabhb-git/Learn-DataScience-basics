# %% [markdown]
# # Series
#
# Series datastructure - In pandas library the Series, being the basic, is an indexed datastructure used to store and manipulate single or multi-dimensional indexed data.
#
# Series is the core data structures in Pandas. You can think of it a cross between list and dictionary. The items are all stored in an order and there's labels with which you can retrieve them. An easy way to visualize this is 2 columns of data. The first is the special index, a lot like keys in a dictionary. While the second is your actual data. It's important to note the data column has a label of its own and can be retrieved using the .name attribute.
# This is different than with dictionaries and is useful when it comes to merging multiple columns of data.

# %%
import pandas as pd

# %%
# You can create a series by passing in a list of values.
# When you do this, Pandas automatically assigns an index starting with zero
# and sets the name of the series to None. For eg:

# One of the ways to create a series is to use an array-like object, like a list.
students = ['Nitin', 'Rishabh', 'Simran']

# and turn it into a Series
pd.Series(students)
# Out:
# 0      Nitin
# 1    Rishabh
# 2     Simran
# dtype: object

# %%
# the result above is a Series object which is nicely rendered to the screen.
# We see here that pandas has automatically identified the type of data in this Series as "object" and set the dtype parameter as 'object'.
# Also, the values here are indexed with integers, starting at zero.

# Here, the result is of dtype of int64 objects

# %% [markdown]
# Pandas's series datastructure performs type-conversion wherever required

# %%
# If we create a list of strings and we have one element, a None type, pandas inserts it as a None and uses the type object for the underlying array.
# For eg:

students = ['Nitin', None, 'Ramesh']
pd.Series(students)
# Out:
# 0     Nitin
# 1      None
# 2    Ramesh
# dtype: object

# %%
# However, if we create a list of numbers, integers or floats, and put in the None type.
# pandas automatically converts this to a special floating point value designed as NaN i.e. "Not a Number"

marks = [245, None, 210]
x = pd.Series(marks)
x
# Well, it's basically evident for a numeric data of "None" type (i.e. meaning, it doesn't exist) to be actually type-casted
# to NaN (not-a-number) type because that data doesn't exist in reality.
# Out:
# 0    245.0
# 1      NaN
# 2    210.0
# dtype: float64

# %%
# Note here that pandas sets the dtype of this series to floating point numbers instead of object or int.
# It happens because - underneath, pandas represents NaN as a floating point number, so integers got type-casted to floats.

# So, whenever a list of integers you put into a Series is not floats, it's probably there is some missing data

# %% [markdown]
# ****

# %% [markdown]
# In context of scientific computing it's important to stress that, NaN and None might be used by a data scientist in the same way, to denote missing data. But that underneath these are not represented by pandas in the same way.
#
# NaN is "NOT" equivilent to None and when we try the equality test, the result is False.

# %%
import numpy as np

# generate a NaN value via NumPy library
np.nan == None
# Out:
# False

# %%
# It turns out that, an equality test of NaN to itself can't be done. Because when
# it's done the answer is always False.

np.nan == np.nan
# Out:
# False

# %%
# Instead, special functions can be used to test for the presence of NaN,
# such as numpy library isnan()

np.isnan(np.nan)
# Out:
# True

# %% [markdown]
# ###### hence NOTE - when you come across NaN, it's meaning is similar to None, but it's a
# ###### numeric value (mostly treated as `float64` type) and treated differently for efficiency reasons.
#
# _________________________

# %% [markdown]
# A series can be created directly from dictionary data.
# Here, index is automatically assigned to the keys of the dictionary that is provided by user and not just incrementing integers.
#
# For eg:

# %%
students_score = {'Nitin': 'Physics',
                  'Rishabh': 'Math',
                  'Simran': 'English'}
s = pd.Series(students_score)
s
# Out:
# Nitin      Physics
# Rishabh       Math
# Simran     English
# dtype: object

# %%
# We see that, since it was string data, pandas set the data type of the series to 'object'.
# We see that index, the first column, is also a list of strings.

# After creating the series, we can get the index object using the index attribute.
s.index
# Out:
# Index(['Nitin', 'Rishabh', 'Simran'], dtype='object')

# %% [markdown]
# As you play more with pandas you'll notice that a lot of things are implemented as numpy arrays, and have dtype value set.
# This is true of indices, and here pandas infered that we were using objects for the index.

# %% [markdown]
# Now, this is kind of interesting. The dtype of object is not just for strings, but for arbitrary objects.
# For eg:

# %%
# here, we take a list of tuples and convert it into a series.
students = [('Nitin','Sharma'), ('Rishabh', 'Barman'), ('Simran', 'Chopra')]
pd.Series(students)
# Out:
# 0      (Nitin, Sharma)
# 1    (Rishabh, Barman)
# 2     (Simran, Chopra)
# dtype: object

# %% [markdown]
# We see that each of the series of tuples is stored in series object, and type is object.

# %%
# You can also seperate your index creation from the data by passing in the index as a list explicitly
# to the series.

s = pd.Series(['Physics', 'Chemistry', 'English'], index=['Nitin', 'Rishabh', 'Simran'])
s
# Out:
# Nitin        Physics
# Rishabh    Chemistry
# Simran       English
# dtype: object

# %% [markdown]
# So what happens if your list of values in the index object are not aligned with the keys in your dictionary for creating the series ?
#
# Well, pandas overrides the automatic creation to favor only and only of the indices values that you provided. So it will ignore from your dictionary all keys which are not in your index, and pandas will add None or NaN type values for your index value you provided, which is not in your dictionary key list.

# %%
# For example,

# let's create a dictionary of 3 items - students & thier courses.
students_scores = {'Nitin': 'Physics',
                   'Rishabh': 'Chemistry',
                   'Simran': 'English'}

# When I create the series object though I'll only ask for an index with 3 students,
# and I'll exclude Rishabh
s = pd.Series(students_scores, index=['Nitin', 'Simran', 'Arpan'])
s


# the result is that the Series "s" object doesn't have Rishabh in it, even though he was in our original dataset,
# but it explicitly does have Arpan in it as a missing value.
# Out:
# Nitin     Physics
# Simran    English
# Arpan         NaN
# dtype: object

# %% [markdown]
# ### Structure of a Series | Querying a Series | Merging Series objects together
#
# - A pandas Series can be queried either by the index position or the index label.
#
# - If you don't give an index to the series when querying, the position and the label are effectively the same values.
#
# - To query by numeric location, starting at zero, use the iloc attribute.
#
# - To query by the index label, you can use the loc attribute.
#
# - `.iloc` refers to the **position**.
#
# - `.loc` refers to the **index**.

# %%
# For example, let's a create a dictionary of students enrolled in classes.

import pandas as pd
students_classes = {'Nitin': 'Physics',
                    'Rishabh': 'Math',
                    'Simran': 'English',
                    'Samer': 'History' }
s = pd.Series(students_classes)
s
# Out:
# Nitin      Physics
# Rishabh       Math
# Simran     English
# Samer      History
# dtype: object

# %%
# So, for this series, if you want to see the fourth entry we would use the iloc attribute with parameter 3.
s.iloc[3]
# Out:
# 'History'

# %%
# If you want to see the class Simran has, we would use loc attribute with Simran as parameter.
print(s.loc['Simran'])
# Out:
# English

# %% [markdown]
# ##### Note:
# Keep in mind that <b>iloc and loc are <b>attributes, and not methods.</b>
#
# So you don't use paranthesis to query them, but sqaure brackets instead, which is called the indexing operator.
# In Python, this call a get or set for an item on the context of its use.

# %%
# this can also be achieved by using an integer parameter,
s[2]

# because, the operator will behave as if you want it to query via iloc attribute.
# Out:
# 'English'

# %%
# if you pass in an object, it will query as if you wanted to use the label based loc attribute.
print(s['Samer'])
print(s['Rishabh'])
# Out:
# History
# Math

# %% [markdown]
# <b>So what happens if your index is a list of integers ?</b>
#
# This is a bit complicated and Pandas cannot determine automatically whether you're intending to query by position or index label.
#
# So you need to be careful when using the indexing operator on the Series itself. The safer option is to be more explicit and use the iloc or loc attributes directly.
#
# Indices of a Series data could be **Float type** too.

# %%
# for example; the class and their classcode info are given here, where classes are indexed by classcodes, in the form of integers
class_code = {99: 'Physics',
              100: 'Chemistry',
              101: 'English',
              102: 'History'}
s = pd.Series(class_code)
s
# Out:
# 99       Physics
# 100    Chemistry
# 101      English
# 102      History
# dtype: object

# %%
# if we try to call s[1] we get a key error because there's no item in the classes list with an index of one, instead we have to call iloc explicitly if we want the second item.
s[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-8c325295bc82> in <module>
#       1 # if we try to call s[1] we get a key error because there's no item in the classes list with an index of one, instead we have to call iloc explicitly if we want the second item.
# ----> 2 s[1]
#
# ~/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 1

# %%
# Well because it didn't s.ioc[1] underneath as one might expect, instead it generates an error.

# so, s.iloc[1] will produce the desired result.
s.iloc[1]
# Out:
# 'Chemistry'

# %% [markdown]
# _____________________________________

# %% [markdown]
# ### Vectorization

# %% [markdown]
# <p>Now we know how to get out of the series, let's talk about working with the data. A common task is to want to consider all of the values inside of a series and do some sort of operation. This could be trying to find a certain number, or summarizing data or transforming the data in some way.<br><br>
# A typical programatic approach to this would be to iterate over all the items in the series, and invoke the interested operation.<br>
# For instance, we could create a Series of integers representing student grades, and calculate the average.</p>

# %%
grades = pd.Series([80, 82, 95, 84, 83, 97])

total = 0
for grade in grades:
    total += grade
print(total/len(grades))
# Out:
# 86.83333333333333

# %% [markdown]
# <p>This works, but it's slow. Modern computers can do many tasks simultaneously, especially, but not only, tasks involving mathematics.<br>
# Pandas and the underlyimg numpy libraries support a method of compution called <strong>vectorization.</strong>
# Vectorization works with most of the functions in numpy library, including the sum function.<br><br>
# Here's how we write the code using numpy sum method.</p>

# %%
import numpy as np

total = np.sum(grades)      # passing an iterable item inside sum()
print(total/len(grades))
# Out:
# 86.83333333333333

# %% [markdown]
# Now both of these methods create the same value, <i><b>but vectorization is actually faster than operating via loops.</b></i>
# Jupyter Notebook has a magic function which can help to demonstrate this.

# %%
# the iPython interpreter has something called magic function that begin with a percentage sign.
# to view list of these functions, type % sign and hit 'tab' key.
# Custom magic functions can also be created by oneself.

# Here, we would use cellular magic function. These start with 2 percentage signs and wrap the code in Jupyter cell.
# The function used here is called timeit. This function will run our code for a few times to etermine, on average, how long it takes.
# You can speciufy how many number of loops that timeit shall run. However, by default, it is 1000 loops.

# Note: in order to use a cellular magic function, it has to be the first line in the cell.

# %%
# create a big series of random numbers.
numbers = pd.Series(np.random.randint(1,1000,10000))

# %%
# %%timeit -n 1000
total = 0
for number in numbers:
    total += number

total/len(numbers)
# Out:
# 998 µs ± 7.18 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit -n 1000
total = np.sum(numbers)
total/len(numbers)
# Out:
# 54.8 µs ± 5.59 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# Well, you can notice the performance difference yourself.<br>
# This is the advantage of vectorization - that amplifies the ability of a computer to execute multiple instructions at once.

# %% [markdown]
# #### Broadcasting
# A related feature in pandas and numpy is called broadcasting. With broadcasting, an operation can be applied to every value in the series.
#
# For example: Let's notice the performance difference between incrementing a series by value of 2.
#
# I. The procedural way i.e. Iterating the series

# %%
# %%timeit -n 10

s = pd.Series(np.random.randint(0,100,1000))

# incrementing 's' series by 2
for label,value in s.iteritems():
    s.loc[label] = value + 2
    
# iteritems() function returns a label and a value, which is tuple type.
# Out:
# 41.4 ms ± 1.6 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# II. Broadcasting

# %%
# %%timeit -n 10

s = pd.Series(np.random.randint(0,100,1000))
s += 2
# Out:
# 192 µs ± 45.4 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# <b>Hence, broadcasting is significantly faster than doing same operation via iteration.</b>

# %% [markdown]
# One note on using the indexing oprators to access series data. The .loc attribute not only modifies data in place, but also add new data as well. If the value that's passed in as index doesn't exist, then a new entry is added.
#
# Indices can be of mixed types. Pandas will automatically change the underlying NumPy types as appropriate.<br>
# For eg:

# %%
s = pd.Series([1, 4, 7])

s.loc['English'] = 88

s
# Out:
# 0           1
# 1           4
# 2           7
# English    88
# dtype: int64

# %%
# i.e. we see that mixed types for data values of index labels are no problem for Pandas. Since 'English' is not in the original list of indices,
# s.['English'] essentially creates a new element in the series, with the index named 'English', and value of 88

# %% [markdown]
# ##### An example to show a Series can accept index values of different datatype

# %%
studentClasses = pd.Series({
                            'Rishabh': 'Physics',
                            'Nitin': 'Math',
                            'Simran': 'Hindi',
                            'Kevin': 'History'})

studentClasses
# Out:
# Rishabh    Physics
# Nitin         Math
# Simran       Hindi
# Kevin      History
# dtype: object

# %%
# let's create a Series just for some new student Ravi, which lists all courses he has taken.
raviClasses = pd.Series(['Philosophy', 'Arts', 'Math', 'English'], index=['Ravi', 'Ravi', 'Ravi', 'Ravi'])
raviClasses
# Out:
# Ravi    Philosophy
# Ravi          Arts
# Ravi          Math
# Ravi       English
# dtype: object

# %%
allStudents = studentClasses.append(raviClasses)
print(allStudents)
# Out:
# Rishabh       Physics
# Nitin            Math
# Simran          Hindi
# Kevin         History
# Ravi       Philosophy
# Ravi             Arts
# Ravi             Math
# Ravi          English
# dtype: object

# %%
# .append() method does not actually change the Series objects, it instead returns a new series which is made up of the 2 appended together.
# This is a common pattern in pandas - by default returning a new object instead of modifying the one in place.

studentClasses
# Out:
# Rishabh    Physics
# Nitin         Math
# Simran       Hindi
# Kevin      History
# dtype: object

# %%
# you can see that studentsClasses series is intact and hasn't been modified. Instead append operation itself returned a new series object which we stored as allStudents variable.

# %%
print(allStudents.loc['Nitin'])   # query the final-appended series for Nitin

print(allStudents.loc['Ravi'])    # query the final-appended series for Ravi will get a series itself.
# Out:
# Math
# Ravi    Philosophy
# Ravi          Arts
# Ravi          Math
# Ravi       English
# dtype: object

# %% [markdown]
# ****
# # DataFrame
#
# DataFrame is conceptually a 2-D series object, where there's an index and multiple columns of content, with each column having a label. In fact, the distinction between a column and a row is only a conceptual distinction.
#
# DataFrame can be thought itself as simply a 2-axis labelled array.

# %%
import pandas as pd

# %% [markdown]
# **Example 1 :**

# %%
# Let's create 3 school records for students and their class grades.
# I'll create each as a series which has a student name, the class name, and the score.

record1 = pd.Series({'Name': 'Rishabh',
                     'Class': 'Math',
                     'Score': 94})

record2 = pd.Series({'Name': 'Nitin',
                     'Class': 'Chemistry',
                     'Score': 89})

record3 = pd.Series({'Name': 'Simran',
                     'Class': 'Physics',
                     'Score': 91})

print(record1)
# Out:
# Name     Rishabh
# Class       Math
# Score         94
# dtype: object

# %% [markdown]
# Like a Series, the DataFrame object is index. Here, we'll use a group of series, where each series represents a row of data. Just like the Series function, we can pass in our individual items in an array, and we can pass in our index values as a second arguments.
#
# <b>You can think like, in a DataFrame each column or row is a Series in itself</b>

# %%
recordDF = pd.DataFrame([record1, record2, record3], index=['school1', 'school2', 'school3'])

recordDF
# Out:
#             Name      Class  Score
# school1  Rishabh       Math     94
# school2    Nitin  Chemistry     89
# school3   Simran    Physics     91

# %%
print(recordDF['Name'])
type(recordDF['Name'])
# Out:
# school1    Rishabh
# school2      Nitin
# school3     Simran
# Name: Name, dtype: object
# pandas.core.series.Series

# %% [markdown]
# **Example 2 :**

# %%
# an alternative method is by creating a list of dictionaries, where each dictionary represents a row of data.

students = [{'Name': 'Rishabh',
             'Class': 'Math',
             'Score': 94},
            {'Name': 'Nitin',
             'Class': 'Chemistry',
             'Score': 89},
            {'Name': 'Simran',
             'Class': 'Physics',
             'Score': 91}]

# now, pass this list of dictionaries into the DataFrame function
studentsDF = pd.DataFrame(students, index=['school1', 'school2', 'school1'])
studentsDF
# Out:
#             Name      Class  Score
# school1  Rishabh       Math     94
# school2    Nitin  Chemistry     89
# school1   Simran    Physics     91

# %% [markdown]
# **Example 3 :**

# %%
car_data = pd.Series(['Toyota', 'Honda', 'Ford', 'Tata'])

car_data
# Out:
# 0    Toyota
# 1     Honda
# 2      Ford
# 3      Tata
# dtype: object

# %%
color = pd.Series(['White', 'Red', 'Black', 'Indigo'])
color
# Out:
# 0     White
# 1       Red
# 2     Black
# 3    Indigo
# dtype: object

# %%
carDF = pd.DataFrame({"Car Manufacturer": car_data, "Color shade": color})

carDF
# Out:
#   Car Manufacturer Color shade
# 0           Toyota       White
# 1            Honda         Red
# 2             Ford       Black
# 3             Tata      Indigo

# %% [markdown]
# ### Extracting data via 'loc' and 'iloc' attributes with DataFrames

# %% [markdown]
# Similar to the series, we can extract data using the <b>.iloc and .loc</b> attributes.
# Because the DataFrame is 2-D, passing a single value to the loc indexing operator will return the series if there's only one row to return.

# %%
studentsDF.loc['school2']

# we can notice that name of the series is returned as the index value, while the column name is included in the output.
# Out:
# Name         Nitin
# Class    Chemistry
# Score           89
# Name: school2, dtype: object

# %%
# It's important to remember that the indices and cloumn names along either axes, horizontal or vertical, could be non-unique.
# In this example, we see two records for school1 as different rows.
# If we use a single value with DataFrame loc atribute, multiple rows of the DataFrame will return, not as a new Series, but as new DataFrame.

studentsDF.loc['school1']
# Out:
#             Name    Class  Score
# school1  Rishabh     Math     94
# school1   Simran  Physics     91

# %%
print(type(studentsDF.loc['school1']))   # typeof for school1 is DataFrame

print(type(studentsDF.loc['school2']))   # typeof for school2 is Series

# so you may notice here the difference in datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# One of the powers of the Pandas' DataFrames is that you can quickly slelect data based on multiple axes. For instance, if you wanted to just list the student names for school1, you would supply two parameters to .loc , the row index and other being the column index.

# %%
# for example, if we want to get student names of school1
studentsDF.loc['school1', 'Name']
# Out:
# school1    Rishabh
# school1     Simran
# Name: Name, dtype: object

# %%
# if we want to get student names only
# i.e., you want to select out the "Name" column from studentsDF dataframe.
print(studentsDF.T.loc['Name'])   # here .T is done to transpose

print("\nAn another way to do same is studentsDF['Name'] =>\n" )

print(studentsDF['Name'])
# Out:
# school1    Rishabh
# school2      Nitin
# school1     Simran
# Name: Name, dtype: object
#
# An another way to do same is studentsDF['Name'] =>
#
# school1    Rishabh
# school2      Nitin
# school1     Simran
# Name: Name, dtype: object

# %%
# However, since iloc and loc are used for row selection, Panda reserves the indexing operator
# directly on the DataFrame for column selection. In a panda's DataFrame, columns always have a name.
# So this selection is always label based, and is not as confusing as it was when using the square bracket operator on series objects.
# This operator is analogous to column projection, as in scenarios of relational DBs.

studentsDF['Name']
# Out:
# school1    Rishabh
# school2      Nitin
# school1     Simran
# Name: Name, dtype: object

# %%
type(studentsDF['Name'])    # result of a single column projection is a Series object
# Out:
# pandas.core.series.Series

# %%
# Since the result of using the indexing operator is either a DataFrame or Series; chaining of operations can be done.

# For instance, select all rows which relates to school1 using .loc, then project the Name column from those rows.
studentsDF.loc['school1']['Name']
# Out:
# school1    Rishabh
# school1     Simran
# Name: Name, dtype: object

# %%
# checking the type of the responses from resulting operations
print(type(studentsDF.loc['school1']))          # it's a DataFrame
print(type(studentsDF.loc['school1']['Name']))  # it's a Series
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# <b>Chaining</b>, by indexing on the return type of another index, can come with some costs and is best avoided if you can use another approach. In particular, chaining tends to cause Pandas to return a copy of the DataFrame instead of a view on the DataFrame.
#
# For selecting data, this is not a big deal though it might be slower than necessary when dealing with large datasets.
#
# Here's an another approach.<br>
# As we saw, .loc does row selection and it can take 2 parameters,<br>
# the row index and list of column names.
#
# The .loc attribute also supports slicing. If you want to select all rows,  use a colon to indicate a full slice from beginning to end. Then, add the column names as the second parameter as a string. If multiple columns are required; so pass the column names in a list and Pandas will bring back only the column names that were asked for.
#
# For example, we need names and scores of all students :

# %%
studentsDF.loc[:, ['Name', 'Score']]

# colon means that selecting up all the rows, and the list in second argument position is the list of columns we want to get hold of.
# Out:
#             Name  Score
# school1  Rishabh     94
# school2    Nitin     89
# school1   Simran     91

# %% [markdown]
# That's selecting and rojecting data from a DataFrame based on row and column labels. The key concepts to remember are that the row and columns are really just for our benefit. Underneath, this is a just 2 axes labelled array.
#
# Also, consider the issue of chaining carefully, and try to avoid it, as it can unpredictable results, where intention was to obtain a view of the data, but instead Pandas returns a copy of it.

# %% [markdown]
# ____________________
#
# ### Dropping Data
#
# It's easy to delete data in Series and DataFrames; drop function is used to do so.
#
# drop( ) => takes a single prameter, which is the index or row or column label, to drop.
#
# The drop function doesn't change the DatFrame by default! Instead, the drop function returns a new copy of the DataFrame with the given rows removed.
#
# more info here, [https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html]

# %%
studentsDF.drop('school1')    # returns a new DataFrame after dropping the 'school1' row
# Out:
#           Name      Class  Score
# school2  Nitin  Chemistry     89

# %%
studentsDF    # original studentsDF DataFrame is intact
# Out:
#             Name      Class  Score
# school1  Rishabh       Math     94
# school2    Nitin  Chemistry     89
# school1   Simran    Physics     91

# %% [markdown]
# Drop has some interesting parameters -
#
# 1st is called inplace, and if it's set to true, the DataFrame will be updated in place, instead of a copy being returned.
#
# 2nd parameter is the axes, which requires to be dropped. By default, axes is set to 0, i.e. the row axis. If set to 1, means you can drop a column.

# %%
stDF = studentsDF.copy()   # just creating a copy of studentsDF dataframe for further operations
stDF
# Out:
#             Name      Class  Score
# school1  Rishabh       Math     94
# school2    Nitin  Chemistry     89
# school1   Simran    Physics     91

# %%
# dropping off 'Score' column
stDF.drop("Score", inplace=True, axis=1)
stDF
# Out:
#             Name      Class
# school1  Rishabh       Math
# school2    Nitin  Chemistry
# school1   Simran    Physics

# %% [markdown]
# There is an another way to drop a column, and that's directly through the use of indexing operator, using the del keyword. This way of dropping data takes immediate effect on the DataFrame and does not return a view.

# %%
del stDF['Class']     # drops off 'Class' column from the original array
stDF
# Out:
#             Name
# school1  Rishabh
# school2    Nitin
# school1   Simran

# %% [markdown]
# ### Adding a new column
#
# Adding a new column to the DataFrame is as easy as assigning it to some value using the indexing operator. For instance, if we want to add a 'Rank' column with default value of None, we can do so using assignment operator after squre brackets. This broadcasts the default value to the new column immediately.

# %%
studentsDF['Rank'] = None
studentsDF
# Out:
#             Name      Class  Score  Rank
# school1  Rishabh       Math     94  None
# school2    Nitin  Chemistry     89  None
# school1   Simran    Physics     91  None

# %% [markdown]
# ### DataFrame Indexing and Loading
#
# A common flow using Pandas is to read the datasets in, usually from some external file, then begin to clean and manipulate the dataset for analysis.

# %%
# "cat" i.e. 'concatenate', outputs the contents of a file.
# In Ipython, if we prepend the line with an exclamation mark it will execute the remainder of the line as a shell command.

# !cat ./datasets/Health-Tweets/latimeshealth.txt
# Out:
# 576760256031682561|Sat Mar 14 15:02:15 +0000 2015|Five new running shoes that aim to go the extra mile http://lat.ms/1ELp3wU
# 576715414811471872|Sat Mar 14 12:04:04 +0000 2015|Gym Rat: Disq class at Crunch is intense workout on pulley system http://lat.ms/1EKOFdr
# 576438353555365888|Fri Mar 13 17:43:07 +0000 2015|Noshing through thousands of ideas at Natural Products Expo West http://lat.ms/1EHqywg
# 576438347003908096|Fri Mar 13 17:43:06 +0000 2015|Natural Products Expo also explores beauty, supplements and more http://lat.ms/1EHqyfE
# 576413058177712128|Fri Mar 13 16:02:36 +0000 2015|Free Fitness Weekends in South Bay beach cities aim to spark activity http://lat.ms/1EH3SMC
# 576394093485412352|Fri Mar 13 14:47:15 +0000 2015|For Kayla Harrison, sacrifices paid off with judo gold http://lat.ms/1EGNyve
# 576162196272594944|Thu Mar 12 23:25:46 +0000 2015|Sonic waves a treatment for Alzheimer's Disease? http://lat.ms/1FbQ2kk
# 576161553759760384|Thu Mar 12 23:23:13 +0000 2015|An ultrasound for the brain restores memory in Alzheimer's w/o so much as a needle. But only--so far--in mice.
# 575736772082208768|Wed Mar 11 19:15:17 +0000 2015|Is Apple's new ResearchKit really a boon for medical research? http://lat.ms/1b0E0Pi
# 575689067540660224|Wed Mar 11 16:05:44 +0000 2015|Warning to Chantix users: If you drink while taking this drug, you might not remember it the next day. http://lat.ms/1KSN5Kh
# 575459939872731136|Wed Mar 11 00:55:15 +0000 2015|Some Chantix users had memory problems after drinking a modest amount of alcohol, @US_FDA says http://lat.ms/1KSN5Kh
# 575425988869423104|Tue Mar 10 22:40:21 +0000 2015|Guanine isn't just an ingredient in DNA. In nanocrystal form, it allows chameleons to change colors. @NatureComms http://lat.ms/1wr2qv0
# 575419755986817024|Tue Mar 10 22:15:35 +0000 2015|The @US_FDA has documented 64 cases of Chantix users having seizures after using the smoking cessation drug http://lat.ms/1KSN5Kh
# 575404616818491392|Tue Mar 10 21:15:25 +0000 2015|Drinking while taking Chantix may make people more inebriated and aggressive than usual, @US_FDA warns http://lat.ms/1KSN5Kh
# 575400153873563648|Tue Mar 10 20:57:41 +0000 2015|The @US_FDA warns Chantix users that the smoking-cessation drug could cause seizures and make drinking problematic http://lat.ms/1KSN5Kh
# 575371994293755907|Tue Mar 10 19:05:47 +0000 2015|Loving a kid is good for his self-esteem; thinking he is better than other kids can make him narcissistic http://lat.ms/1AbI1X4
# 575327944295456768|Tue Mar 10 16:10:45 +0000 2015|Parents can create narcissistic tendencies in their children. Here's how, via @PNASNews http://lat.ms/1AbI1X4
# 575096248824389632|Tue Mar 10 00:50:05 +0000 2015|"Sadly ... it has been a missed chance," one @WHO official says of testing Ebola drugs http://lat.ms/1wm7sZx
# 575056076145561600|Mon Mar 09 22:10:27 +0000 2015|Warning: The Monday after daylight saving time starts is most hazardous to your health. Here's why: http://lat.ms/1BqdRlG
# 575053909313634304|Mon Mar 09 22:01:50 +0000 2015|One company has canceled plans to test its Ebola drug because there aren't Ebola patients left. Others may follow http://lat.ms/1wm7sZx
# 575053026521661440|Mon Mar 09 21:58:20 +0000 2015|"People are not just born narcissists." Their parents raise them that way, @OhioState's @BradJBushman says. http://lat.ms/1AbI1X4
# 575052282657652736|Mon Mar 09 21:55:22 +0000 2015|It's hard to complain about lack of Ebola patients, but one upshot is that scientists can't test possible drugs http://lat.ms/1wm7sZx
# 575049588454858752|Mon Mar 09 21:44:40 +0000 2015|With Ebola crisis easing, efforts to test new drugs and vaccines are in jeopardy. Why? Too few patients http://lat.ms/1wm7sZx
# 575009507375452160|Mon Mar 09 19:05:24 +0000 2015|Air pollution? Obesity? Genetics? You can study them all via daylight saving time http://lat.ms/1A84HY3
# 574964265016291328|Mon Mar 09 16:05:37 +0000 2015|For scientists, daylight saving time is a great opportunity to conduct all kinds of research. http://lat.ms/1A84HY3
# 574254071185457153|Sat Mar 07 17:03:34 +0000 2015|After shifting fads, time for a clear-eyed look at fat in our diets http://lat.ms/1Gtx9e7
# 574194432301359105|Sat Mar 07 13:06:35 +0000 2015|Three light-therapy products to aid seasonal affective disorder http://lat.ms/1HbYe32
# 573980153946181632|Fri Mar 06 22:55:07 +0000 2015|A pill to burn calories? "We are quite excited about it," says @EmoryUniversity researcher. So are we!http://lat.ms/1B9Gsg3
# 573951959851388928|Fri Mar 06 21:03:05 +0000 2015|Health focus shifts to gut microbiome and nurturing 'good' bacteria http://lat.ms/1GrwjP1
# 573940028155518976|Fri Mar 06 20:15:40 +0000 2015|This compound tricks muscles into thinking they were getting regular, intensive exercise. Only in females. http://lat.ms/1B9Gsg3
# 573935522801934336|Fri Mar 06 19:57:46 +0000 2015|Don't get out of your chair just to work out: even intensive exercise may not help if you sit for long hours. http://lat.ms/1GrngO4
# 573934373453627392|Fri Mar 06 19:53:12 +0000 2015|Why do female killer whales--and humans--live long beyond child-bearing years? To lead. http://lat.ms/1McGw0s
# 573922644401090560|Fri Mar 06 19:06:36 +0000 2015|Patricia Bragg, a living testament to healthful habits http://lat.ms/1H7OGGg
# 573894688228425731|Fri Mar 06 17:15:30 +0000 2015|Could a puff of oxytocin keep the pounds away? Preliminary results are encouraging http://lat.ms/1wKRkBh
# 573719693795672064|Fri Mar 06 05:40:08 +0000 2015|Oxytocin turns men into cuddly, highly evolved salad-eaters. via @LATMelissaHealy http://lat.ms/1wKRkBh
# 573678648894570496|Fri Mar 06 02:57:02 +0000 2015|Boost his levels of the hormone oxytocin and he might evolve into a trim, salad-eating snuggle-bunny. http://lat.ms/1McmTr0
# 573678085104615424|Fri Mar 06 02:54:48 +0000 2015|Boost a healthy aging guy's testosterone and you might raise his risk of heart attack, says FDA. http://lat.ms/1EeQS0o
# 573676855372439553|Fri Mar 06 02:49:55 +0000 2015|A potential weight-loss, obesity prevention drug that only works for females? Sweet justice! http://lat.ms/1Kv6yR2
# 573676647834066944|Fri Mar 06 02:49:05 +0000 2015|A potential weight-loss, obesity prevention drug that only works for females? Sweet justice!
# 573645464794370048|Fri Mar 06 00:45:11 +0000 2015|RT @mmacvean: Delicious #goji drink. Not too sweet. From #Sonoma. @NatProdExpo @gojivitatea. #superberries http://pbs.twimg.com/media/B_XfRqpUwAALuSn.jpg
# 573579273035902977|Thu Mar 05 20:22:09 +0000 2015|RT @mmacvean: Is it #natural if it has these? W/ @MicheleRSimon @NatProdExpo #Expowest2015 http://pbs.twimg.com/media/B_XDOQbU8AARNdJ.jpg
# 573575143655497729|Thu Mar 05 20:05:45 +0000 2015|RT @mmacvean: .@MicheleRSimon talking to companies @NatProdExpo about not getting sued over #natural #Expowest2015 How to do the right thin…
# 573570160805613569|Thu Mar 05 19:45:57 +0000 2015|RT @mmacvean: .@srirachasauce goes everywhere. @country archer #beef jerky. @NatProdExpo #ExpoWest http://pbs.twimg.com/media/B_W5yF-UcAAWYWN.jpg
# 573570131227336705|Thu Mar 05 19:45:50 +0000 2015|RT @mmacvean: Will these get eating #chia? #chocolate covered. #ExpoWest2015 @NatProdExpo http://pbs.twimg.com/media/B_W37ZfVAAA7H4x.jpg
# 573570008392974336|Thu Mar 05 19:45:21 +0000 2015|RT @mmacvean: Ancient Greeks had word for #celiacdisease @GlutenFreeFind. Seminar @NatProdExpo
# 573569449455824896|Thu Mar 05 19:43:07 +0000 2015|RT @mmacvean: In #Anaheim @NatProdExpo #expowest. Let me know of cool new foods. http://pbs.twimg.com/media/B_WnX03U8AAuqOH.jpg
# 573300726061015040|Thu Mar 05 01:55:19 +0000 2015|Good news: The number of twins/triplets/multiples born as a result of IVF keeps falling. http://lat.ms/17RHiCB
# 573255122895179776|Wed Mar 04 22:54:06 +0000 2015|Uh-oh: Even a rigorous workout won't undo the ill effects of prolonged sitting. @ACCinTouch http://lat.ms/1M6N948
# 573254233610440705|Wed Mar 04 22:50:34 +0000 2015|Look around at 1 and 2-yr-olds. About 1.5% of them wouldn't be here without IVF. http://lat.ms/17RHiCB
# 573242145236242432|Wed Mar 04 22:02:32 +0000 2015|Supplements to boost "low T" increase risk of heart attacks &amp; strokes, @US_FDA warns. Think twice before taking. http://lat.ms/1M7UO4h
# 573238450629058561|Wed Mar 04 21:47:51 +0000 2015|The @US_FDA warns men of risks of taking prescription testosterone supplements to boost "low T" http://lat.ms/1M7UO4h
# 573233620036521985|Wed Mar 04 21:28:39 +0000 2015|63,286: The number of babies born in 2013 as a result of IVF and other fertility treatments. http://lat.ms/17RHiCB
# 572960829043310593|Wed Mar 04 03:24:41 +0000 2015|Guys: 1) your penis is fine (http://lat.ms/1DSisho); and 2) tired and not-always-up-for-sex isn't a disease (http://lat.ms/1EeQS0o)
# 572950925452681216|Wed Mar 04 02:45:20 +0000 2015|Not every study can win a @NobelPrize. But this one, on penis lengths, will be useful to many people @BJUIjournal http://lat.ms/1NecSeA
# 572938317420998656|Wed Mar 04 01:55:14 +0000 2015|Study proves that finger length and foot size DO NOT predict the length of a man's penis http://lat.ms/1NecSeA
# 572932117514076160|Wed Mar 04 01:30:36 +0000 2015|Height is indeed correlated with penis size, but the association is weak. Data from @BJUIjournal http://lat.ms/1NecSeA
# 572931994864263168|Wed Mar 04 01:30:06 +0000 2015|Researchers comb through measurements of more than 15,000 men to see what qualifies as a 'normal' penis http://lat.ms/1NecSeA
# 572927460213460992|Wed Mar 04 01:12:05 +0000 2015|5.2 inches: The average length of an erect penis. Here's the study that crunched the numbers http://lat.ms/1NecSeA
# 572575901025759232|Tue Mar 03 01:55:07 +0000 2015|74% of doctors surveyed said they have complied with parents' requests to 'spread out' childhood vaccines http://lat.ms/1vUFunE
# 572528136426004480|Mon Mar 02 22:45:19 +0000 2015|Doctors often delay vaccines for young children even though they believe it puts these kids at risk. Here's why http://lat.ms/1vUFunE
# 572509390789599232|Mon Mar 02 21:30:50 +0000 2015|Pediatricians and family medicine doctors feel trapped by parents who don't trust expert advice on vaccines http://lat.ms/1vUFunE
# 572504407927078913|Mon Mar 02 21:11:02 +0000 2015|Vaccine-wary parents pressure doctors to delay vaccines, and many go along despite serious reservations http://lat.ms/1vUFunE
# 572484115641081856|Mon Mar 02 19:50:24 +0000 2015|RT @LATerynbrown: Coming home after treating Ebola patients has its challenges, volunteer doctor says http://lat.ms/1Ck3GBZ
# 572441640289353728|Mon Mar 02 17:01:37 +0000 2015|RT @renelynch: Diet is only one part of the Primal lifestyle, @Mark_Sisson told me http://lat.ms/1vLRveV Read more about his quest for hea…
# 571852454754721792|Sun Mar 01 02:00:24 +0000 2015|Wind tunnel experiments reveal the REAL reason you have eyelashes: http://lat.ms/1wyKEkd
# 571808335680438272|Sat Feb 28 23:05:05 +0000 2015|Clinical trial of #Ebola drug ZMapp now underway in Liberia. Only some of the study participants will get it. http://lat.ms/1C9s3Cj
# 571758094373560320|Sat Feb 28 19:45:27 +0000 2015|Better late than never? US @NIAIDNews begins clinical trial of ZMapp in Liberia. http://lat.ms/1C9s3Cj
# 571672785589686272|Sat Feb 28 14:06:27 +0000 2015|Getting primal with Mark Sisson http://lat.ms/1DDdqFk
# 571671305675669504|Sat Feb 28 14:00:35 +0000 2015|A brief timeline shows how we're gluttons for diet fads http://lat.ms/1aBjQuZ
# 571415750285471745|Fri Feb 27 21:05:05 +0000 2015|Innovative sunglasses are a sight for active eyes http://lat.ms/1awBS1x
# 571392973826498560|Fri Feb 27 19:34:35 +0000 2015|Angels' Mike Trout stays one of baseball's best the old way: lots of work http://lat.ms/1aw7Lay
# 571358874873176065|Fri Feb 27 17:19:05 +0000 2015|Avatars often reflect a reality about their creators, study finds http://lat.ms/1avtEqC
# 571024949986635778|Thu Feb 26 19:12:11 +0000 2015|The "love hormone" oxytocin kills alcohol's buzz--who knew? Maybe a treatment for alcoholism &amp; other addictions? http://lat.ms/1E0wM9X
# 571024105031512064|Thu Feb 26 19:08:50 +0000 2015|Emulsifiers are everywhere in prepared food. A new study says they may cause colitis, pre-diabetes and obesity. http://lat.ms/180IHqp
# 569120035341406208|Sat Feb 21 13:02:44 +0000 2015|Workout on a Gyrotonic tower gives body what it longs for http://lat.ms/19PKxvy
# 568896025768779777|Fri Feb 20 22:12:36 +0000 2015|Once shunned, Greg LeMond returns to biking world and road to success http://lat.ms/19LV3UA
# 568848361488429056|Fri Feb 20 19:03:12 +0000 2015|'Forest bath' is way to let nature cleanse away stress http://lat.ms/19KVS03
# 568823057327919104|Fri Feb 20 17:22:39 +0000 2015|Let go of stress by creating your own spa environment http://lat.ms/1CUX76i
# 568645429602070528|Fri Feb 20 05:36:49 +0000 2015|RT @latimesscience: UCLA superbug outbreak: Why the medical scope used is hard to disinfect http://lat.ms/19G6a1p
# 568625391801229312|Fri Feb 20 04:17:12 +0000 2015|Solstice Canyon hike in Malibu takes in ruins of old estate http://lat.ms/1CQYG5o
# 568503585442394112|Thu Feb 19 20:13:11 +0000 2015|Gluten-free baking from Kristine Kidd http://lat.ms/19EfoLN
# 568224747886133248|Thu Feb 19 01:45:11 +0000 2015|Pot can change a brain circuit from being one that tells the body it's full to one that tells it to keep eating. http://lat.ms/1vGBce0
# 568185823298002944|Wed Feb 18 23:10:31 +0000 2015|Scientists use genetic engineering to thwart HIV with a big fake-out. Here's how: http://lat.ms/1MxNUXg
# 568165509641965568|Wed Feb 18 21:49:48 +0000 2015|RT @mmacvean: Some #ucla #usc research on #meditation. Helps sleep? Have you tried it? http://lat.ms/1vGNvqP
# 568164406401601536|Wed Feb 18 21:45:25 +0000 2015|THIS is why marijuana is bad for your diet. Thank the stoned mice @Yale who helped researchers figure it out http://lat.ms/1vGBce0
# 568141908054306816|Wed Feb 18 20:16:01 +0000 2015|Scientists fight HIV by passing the immune system. Instead, they use gene therapy to create decoy molecules http://lat.ms/1MxNUXg
# 568130603020918784|Wed Feb 18 19:31:05 +0000 2015|Gene therapy technique functions like an effective HIV vaccine in monkeys. via @Nature http://lat.ms/1MxNUXg
# 568126056093356032|Wed Feb 18 19:13:01 +0000 2015|Dozens of stoned lab mice help scientists trace the origins of the munchies. @Nature via @DeborahNetburn http://lat.ms/1vGBce0
# 568120505221427200|Wed Feb 18 18:50:58 +0000 2015|HIV researchers say a gene therapy technique protects monkeys from infection, via @Nature http://lat.ms/1MxNUXg
# 567515066866868224|Tue Feb 17 02:45:10 +0000 2015|A simple diet with just one rule worked about as well as the effective - but complicated - @American_Heart diet http://lat.ms/19pvgS7
# 567506268181782528|Tue Feb 17 02:10:12 +0000 2015|If you can eat 30 grams of fiber per day, you can lose weight. That's what happened in this @AnnalsofIM study http://lat.ms/19pvgS7
# 567463488759791616|Mon Feb 16 23:20:13 +0000 2015|When it comes to dieting, simple advice can be effective, @AnnalsofIM study shows http://lat.ms/19pvgS7
# 567463470799814656|Mon Feb 16 23:20:09 +0000 2015|Detailed diet rules produced only slightly better results than a much simpler alternative in new study http://lat.ms/19pvgS7
# 567461601369149440|Mon Feb 16 23:12:43 +0000 2015|Trying to lose weight? Try eating more fiber. Here's why: http://lat.ms/19pvgS7
# 567459398873022464|Mon Feb 16 23:03:58 +0000 2015|When less is more: Advice on losing weight. Simple diet worked about as well as complicated one. @AnnalsofIM http://lat.ms/19pvgS7
# 567400295735365632|Mon Feb 16 19:09:06 +0000 2015|Meditation booms as people seek a way to slow down http://lat.ms/1CAUHJW
# 566643819513262080|Sat Feb 14 17:03:08 +0000 2015|Anna Kendrick seeks pitch-perfect balance of work, workouts and sleep http://lat.ms/1CsyNsl
# 566420434221281282|Sat Feb 14 02:15:29 +0000 2015|Sad, but perhaps true: "Few individuals ever truly recover from obesity." Expert opinion in @TheLancetEndo http://lat.ms/1zAY4fj
# 566374973909245953|Fri Feb 13 23:14:51 +0000 2015|The truth about overcoming obesity is utterly grim. But someone had to say it. http://lat.ms/19f0gnF
# 566368753190187009|Fri Feb 13 22:50:08 +0000 2015|Once you are fat, "body weight seems to become biologically 'stamped in' and defended." http://lat.ms/1zAY4fj
# 566341937334976512|Fri Feb 13 21:03:34 +0000 2015|Acid reflux raises serious health concerns http://lat.ms/1CoY5HM
# 566327351534170113|Fri Feb 13 20:05:37 +0000 2015|Some heavy-hitting doctors debunk the idea that diet &amp; exercise alone can solve the obesity crisis. In @TheLancetEndo http://lat.ms/1zAY4fj
# 566301467188137985|Fri Feb 13 18:22:45 +0000 2015|Advice to "eat less, move more" is not enough to make obese people slim, experts argue in @TheLancetEndo http://lat.ms/1zAY4fj
# 566297522927190016|Fri Feb 13 18:07:05 +0000 2015|Little innovations make a big difference for riders http://lat.ms/1Co84gE
# 566054263441604608|Fri Feb 13 02:00:27 +0000 2015|Does your dog know how you're feeling? Perhaps so! They passed this emotional fluency test in Austria http://lat.ms/1CjU6w3
# 566007668335456256|Thu Feb 12 22:55:18 +0000 2015|Study identifies more diseases that cause smokers to die: breast &amp; prostate cancer, hypertension, kidney failure http://lat.ms/1CiC3nt
# 565982082732941312|Thu Feb 12 21:13:38 +0000 2015|RT @LATkarenkaplan: Can you tell which face is angry and which is sad? Dogs can. via @CurrentBiology http://lat.ms/1CjU6w3 http://t.co/2bh…
# 565961147820806145|Thu Feb 12 19:50:27 +0000 2015|Estimate of 480,000 smoking deaths per year understates the true toll of cigarettes in America, via @NEJM http://lat.ms/1CiC3nt
# 565937200098181120|Thu Feb 12 18:15:17 +0000 2015|How to stop a stroke in its tracks? Go in and grab the clot blocking blood flow to brain. http://lat.ms/1E4QxKi
# 565919665156005888|Thu Feb 12 17:05:37 +0000 2015|The health benefits of alcohol consumption are more limited than previously thought, researchers say http://lat.ms/1yhOMEP
# 565695599476232192|Thu Feb 12 02:15:15 +0000 2015|Unintended consequence of better federal oversight for organ transplants: Fewer hearts are actually transplanted? http://lat.ms/16SLUYm
# 565650225956933632|Wed Feb 11 23:14:57 +0000 2015|Smoking is even more deadly than you think. So says this special report in @NEJM http://lat.ms/1CiC3nt
# 565649089669627904|Wed Feb 11 23:10:26 +0000 2015|44%: The proportion of available donor hearts transplanted into patients in 1995. 29%: Equivalent figure for 2006. http://lat.ms/16SLUYm
# 565603786862120961|Wed Feb 11 20:10:25 +0000 2015|With more patients in need of heart transplants, you might more donor hearts would be accepted by doctors. But .... http://lat.ms/16SLUYm
# 565590014634242050|Wed Feb 11 19:15:42 +0000 2015|L'chaim. Sante. Salud. But only women ages 65 or older can truly drink to their health, study finds http://lat.ms/1yhOMEP
# 565572244228038658|Wed Feb 11 18:05:05 +0000 2015|Good news: Health benefits of drinking are real. Bad news: Only for women ages 65 and older. Study in @BMJ_Open http://lat.ms/1yhOMEP
# 565570746135891968|Wed Feb 11 17:59:08 +0000 2015|Drink to your health? Only if you're a woman who's at least 65 years old, says study in @BMJ_Open http://lat.ms/1yhOMEP
# 565568779355426816|Wed Feb 11 17:51:19 +0000 2015|Sad fact about heart transplants: Only 32% of available donor hearts find their way into patients. http://lat.ms/16SLUYm
# 565326941893709824|Wed Feb 11 01:50:20 +0000 2015|Fed-up doctors who drop unvaccinated patients are at odds with @AmerAcadPeds. http://lat.ms/1CdUfPb
# 565284264800178181|Tue Feb 10 23:00:45 +0000 2015|Vaccine ultimatum resulted in 50-100 additional kids getting MMR, says pediatrician who used it http://lat.ms/1CdUfPb
# 565236315734544384|Tue Feb 10 19:50:13 +0000 2015|"Patients who are not vaccinated are presenting a clear and present danger," says a pediatrician who won't see them http://lat.ms/1CdUfPb
# 565229483825700865|Tue Feb 10 19:23:05 +0000 2015|Smartphone apps keep pace with costly fitness trackers http://lat.ms/1IN4nHD
# 565217442910457856|Tue Feb 10 18:35:14 +0000 2015|In the battle of the fitness trackers, @Nike's Fuelband was worst (by far). Study by @miteshpatel in @JAMA_current http://lat.ms/1A9pqA4
# 565208815118061569|Tue Feb 10 18:00:57 +0000 2015|Which pedometer is best? @fitbit's One and Zip models were most consistently accurate in this @JAMA_current study http://lat.ms/1A9pqA4
# 565206296367218688|Tue Feb 10 17:50:56 +0000 2015|Can't afford a Fitbit? Free smartphone apps are just about as good, @JAMA_current report says http://lat.ms/1A9pqA4
# 565201605977702403|Tue Feb 10 17:32:18 +0000 2015|Some pediatricians have run out of patience with anti-vax parents &amp; drop them as patients http://lat.ms/1CdUfPb
# 564978398590947328|Tue Feb 10 02:45:21 +0000 2015|Among teens using contraception, researchers @USC &amp; @Harvard found no link between Gardasil and risk of STIs http://lat.ms/1vAS8YT
# 564969525947666432|Tue Feb 10 02:10:06 +0000 2015|Teens vaccinated against HPV got more sexually transmitted infections, but so did teens who weren't vaccinated http://lat.ms/1vAS8YT
# 564937039926525952|Tue Feb 10 00:01:00 +0000 2015|Parents can breathe easy: HPV vaccine does not make teens more likely to have sex. via @JAMAInternalMed http://lat.ms/1vAS8YT
# 564929999653072896|Mon Feb 09 23:33:02 +0000 2015|For teen girls, getting older is a risk factor for STIs. HPV vaccine isn't. Data in @JAMAInternalMed http://lat.ms/1vAS8YT
# 564914238612062208|Mon Feb 09 22:30:24 +0000 2015|RT @LATerynbrown: Measles parties in California? Via @KQEDhealth http://bit.ly/1Dd573M . Reminds me of "pox parties" from 2011 http://t.co…
# 564154180324294658|Sat Feb 07 20:10:12 +0000 2015|Smartphone-based diagnostic lab costs $34; desktop version costs $18,450 http://lat.ms/1zgOFJU
# 564105078630793216|Sat Feb 07 16:55:05 +0000 2015|This @Columbia invention certainly parts the "smart" in smartphone! http://lat.ms/1zgOFJU
# 564046809979314176|Sat Feb 07 13:03:33 +0000 2015|Snow Summit ski school at Big Bear turns out more confident skiers http://lat.ms/1xHnuau
# 563892426822410240|Sat Feb 07 02:50:05 +0000 2015|On Brian Williams: "Memory is prone to error and distortion," says @Harvard psychologist Daniel Schacter http://lat.ms/1KpNIal
# 563880150744694785|Sat Feb 07 02:01:18 +0000 2015|On a 10-point stress scale, low-income folks average 5.2 while higher-income folks average only 4.7. http://lat.ms/1CBtIQW
# 563858477790285824|Sat Feb 07 00:35:11 +0000 2015|Lightweight, low-power smartphone device was 100% accurate in diagnosing HIV in Rwanda field tests. http://lat.ms/1zgOFJU
# 563855497225584640|Sat Feb 07 00:23:21 +0000 2015|Need to diagnose a case of HIV in remote Rwanda? @Columbia engineers have an app for that!  http://lat.ms/1zgOFJU
# 563852470640971776|Sat Feb 07 00:11:19 +0000 2015|Memory expert @eloftus1 on @BWilliams: "This could easily be the development of a false memory." http://lat.ms/1KpNIal
# 563834839145938946|Fri Feb 06 23:01:15 +0000 2015|What makes Americans stressed out? Money, work, family responsibilities and health concerns. (Sound familiar?) http://lat.ms/1CBtIQW
# 563827994611822592|Fri Feb 06 22:34:03 +0000 2015|Vromage makes an art out of vegan cheeses made with nut milks http://lat.ms/1Ik7tmg
# 563820978220720128|Fri Feb 06 22:06:11 +0000 2015|Howie Mandel runs to be calm, works to help others with A-fib http://lat.ms/1IjY3qN
# 563787066580803584|Fri Feb 06 19:51:25 +0000 2015|Vegan January was full of good food and wise lessons http://lat.ms/1xBNvba
# 563786731515043840|Fri Feb 06 19:50:06 +0000 2015|The gender gap in stress -- 38% of men and 49% of women say money worries stress them out. http://lat.ms/1CBtIQW
# 563753457480630273|Fri Feb 06 17:37:52 +0000 2015|America suffers from a "stress inequality gap," much of it due to income inequality.  http://lat.ms/1CBtIQW
# 563474764921315328|Thu Feb 05 23:10:27 +0000 2015|Doctors inadvertently demonstrate how fecal transplants might help with weight loss. http://lat.ms/18SsTHc
# 563470867053957124|Thu Feb 05 22:54:58 +0000 2015|Fecal transplant cures c. diff infection, but it may have caused this woman to gain 40 pounds ... http://lat.ms/18SsTHc
# 563170245184339969|Thu Feb 05 03:00:24 +0000 2015|When it comes to vaccines, random online comments can be just as persuasive as information from the @CDCgov http://lat.ms/1F7zeca
# 563156321470799872|Thu Feb 05 02:05:04 +0000 2015|The good: People believed @CDCgov's advice about vaccines. The bad: They also believed random online comments http://lat.ms/1F7zeca
# 563146269267595264|Thu Feb 05 01:25:08 +0000 2015|Brain signals hint at why drug addicts make bad choices, via @LATsciguy http://lat.ms/1DHg7Vq
# 563145065724645378|Thu Feb 05 01:20:21 +0000 2015|Double whammy for cocaine addicts: The drug alters brain circuits that help us learn from our mistakes http://lat.ms/1DHg7Vq
# 563134552315408387|Thu Feb 05 00:38:34 +0000 2015|Clever produce snacks can turn a school bake sale into an UnBake Sale http://lat.ms/1I4qc4U
# 563133823014416384|Thu Feb 05 00:35:40 +0000 2015|On the Internet, the @CDCgov and random online commenters can be equally persuasive about vaccines http://lat.ms/1F7zeca
# 563093933602115584|Wed Feb 04 21:57:10 +0000 2015|New #glutenfree desserts from @KristineKidd Cornmeal blackberry cake was terrific. @CarolBlymire @CeliacAwareness. http://pbs.twimg.com/media/B9CC8s6CYAAcMFm.jpg
# 562806550415564803|Wed Feb 04 02:55:12 +0000 2015|8% of people surveyed said they'd rather give up 2 years of life than take a pill every day. Would you? http://lat.ms/1vrgGDR
# 562795210456195076|Wed Feb 04 02:10:09 +0000 2015|The ideal "dose" of jogging is a lot lower than you might think. http://lat.ms/1zyNclx
# 562773623040376833|Wed Feb 04 00:44:22 +0000 2015|@owlsrcute Hmmm, why?
# 562771564413079555|Wed Feb 04 00:36:11 +0000 2015|How much do you hate taking pills? In this study, 21% of people said they'd rather pay $1,000 a week instead http://lat.ms/1vrgGDR
# 562748725542809600|Tue Feb 03 23:05:26 +0000 2015|Couch potatoes and high-intensity runners were equally likely to die during the 12 years of this heart study: http://lat.ms/1zyNclx
# 562746747974582272|Tue Feb 03 22:57:34 +0000 2015|When it comes to jogging, less is more, study argues http://lat.ms/1x9ZPiK
# 562717177560985600|Tue Feb 03 21:00:04 +0000 2015|Think you don't have time to exercise? This new study says 1 to 1.4 hrs/week is ideal "dose" @ACCinTouch http://lat.ms/1zyNclx
# 562444154895335425|Tue Feb 03 02:55:10 +0000 2015|88% of FRUIT JUICES made for infants and toddlers contain added sugars. Why? http://lat.ms/1Almj7H
# 562429057183539200|Tue Feb 03 01:55:11 +0000 2015|A typical toddler savory snack has a higher concentration of sodium than potato chips eaten by adults http://lat.ms/1Almj7H
# 562391998624464896|Mon Feb 02 23:27:55 +0000 2015|Processed foods for America's youngest eaters may pave the way for cardiovascular disease years later http://lat.ms/1Almj7H
# 561525074264485889|Sat Jan 31 14:03:04 +0000 2015|Smart sports devices aim to step up performance http://lat.ms/1HxBQFf
# 561305694574747649|Fri Jan 30 23:31:20 +0000 2015|FDA has approved marketing of ADHD drug Vyvanse in treatment of binge eating disorder. http://lat.ms/1Ahet9S
# 561241508729221120|Fri Jan 30 19:16:17 +0000 2015|RT @aminawrite: Do liberals outlive conservatives? New study elicits debate: http://lat.ms/18Al60y #science #politics
# 561208360033206272|Fri Jan 30 17:04:34 +0000 2015|6 L.A. restaurants for vegans; there are 60 in L.A. http://lat.ms/1Hs6kbP
# 560993366327185409|Fri Jan 30 02:50:15 +0000 2015|48% -- the percentage of patients in need of organ transplants who actually get them.  http://lat.ms/18AkwzT
# 560978237313277956|Fri Jan 30 01:50:08 +0000 2015|Recipients of heart transplants gain 4.9 yrs of life (on average); folks who get kidneys get 4.4 extra years. http://lat.ms/18AkwzT
# 560943387483062272|Thu Jan 29 23:31:40 +0000 2015|Health experts throw cold water on juice cleanse http://lat.ms/1Hn10X6
# 560943383917506561|Thu Jan 29 23:31:39 +0000 2015|Juicing trend still going strong in 2015 http://lat.ms/1Hn135d
# 560941769647734784|Thu Jan 29 23:25:14 +0000 2015|On the fence about becoming an organ donor? This may help you make up your mind: http://lat.ms/18AkwzT
# 560937403909963777|Thu Jan 29 23:07:53 +0000 2015|2,270,859 -- The number of years of extra life lived by organ transplant recipients. http://lat.ms/18AkwzT
# 560936783060684802|Thu Jan 29 23:05:25 +0000 2015|The researchers who did this study expected Republicans to outlive Democrats. But that's not what happened: http://lat.ms/1BvRvwi
# 560933981374668801|Thu Jan 29 22:54:17 +0000 2015|Political ideology, but not party affiliation, is linked with longevity. Liberals lived longer than conservatives http://lat.ms/1BvRvwi
# 560692368932757508|Thu Jan 29 06:54:12 +0000 2015|RT @renelynch: Prepare to be in awe: How @fitcheerldr juggles three kids, a full-time job, *Ironman* training + blogging http://t.co/kNe8Pa…
# 560618516299382784|Thu Jan 29 02:00:44 +0000 2015|Researchers boost the power of the 'placebo effect' by giving fake drug a hefty price tag http://lat.ms/1JJBoBp
# 560592495026114561|Thu Jan 29 00:17:20 +0000 2015|If it costs more, it must be better? Trial of fake Parkinson's drug shows patients believe this is true http://lat.ms/1JJBoBp
# 560272324923244544|Wed Jan 28 03:05:06 +0000 2015|Attention smokers: What would it take to get you to kick the habit? How about $600 in shopping vouchers? http://lat.ms/1wzKMhU
# 560253477663014912|Wed Jan 28 01:50:12 +0000 2015|It pays to pay smokers to help them quit. Evidence from @BMJ_company  http://lat.ms/1wzKMhU
# 560245789939990529|Wed Jan 28 01:19:39 +0000 2015|Researchers find a substance that helps pregnant women quit smoking: MONEY  http://lat.ms/1wzKMhU
# 558974893111250945|Sat Jan 24 13:09:34 +0000 2015|Break from the bustle of L.A. with a hike in Elyria Canyon Park http://lat.ms/1GNhsQ9
# 558098042172481537|Thu Jan 22 03:05:16 +0000 2015|“No one should assume e-cigarettes are safe," says James Pankow @Portland_State. Here's one reason why: http://lat.ms/1APN52Y
# 558079127904079874|Thu Jan 22 01:50:07 +0000 2015|Vaping study finds 2.5 times as much formaldehyde in e-cigarette vapor vs tobacco cigarette smoke http://lat.ms/1APN52Y
# 558045397781073920|Wed Jan 21 23:36:05 +0000 2015|Would you like some formaldehyde with your e-cigarette? If so, you're in luck http://lat.ms/1APN52Y
# 558005315128791040|Wed Jan 21 20:56:49 +0000 2015|Poverty is no longer concentrated in inner-cities, and neither is childhood asthma http://lat.ms/1xYF8X0
# 557947109325148160|Wed Jan 21 17:05:31 +0000 2015|A majority of affluent and highly educated consumers don't consider posted calories when ordering http://lat.ms/1C6OvKX
# 557735630986563587|Wed Jan 21 03:05:11 +0000 2015|Want to boost your odds of losing weight, or quitting smoking? Get your spouse to do it with you: http://lat.ms/1GrZ7Ia
# 557726939793084416|Wed Jan 21 02:30:39 +0000 2015|A study finds low-income, less educated consumers are less likely to heed calorie postings http://lat.ms/1yH7haq
# 557722298485338114|Wed Jan 21 02:12:12 +0000 2015|A first look at consumers' response to calorie-posting looks discouraging. But it's progress. http://lat.ms/1yH7haq
# 557719542328467456|Wed Jan 21 02:01:15 +0000 2015|Low-income, less educated consumers are less likely to heed calorie postings http://lat.ms/1C6OvKX
# 557717990104637441|Wed Jan 21 01:55:05 +0000 2015|Another benefit of marriage: Your spouse can help you change your life for the better. http://lat.ms/1GrZ7Ia
# 557717244613230594|Wed Jan 21 01:52:07 +0000 2015|When something is better than nothing: Calories posted on fast food menus.  http://lat.ms/1C6OvKX
# 557677836145025026|Tue Jan 20 23:15:31 +0000 2015|If this research changes one thing about your pizza-eating habits, it should be to skip the pizza "snack" http://lat.ms/1ynxz0X
# 557645741154664448|Tue Jan 20 21:07:59 +0000 2015|Kids love pizza, but it doesn't love them back. http://lat.ms/1ynxz0X
# 557402226260717568|Tue Jan 20 05:00:21 +0000 2015|You might want to stand up to read this http://lat.ms/1J411L1
# 557334248622145537|Tue Jan 20 00:30:14 +0000 2015|Even if you exercise, sitting for long periods of time boosts your likelihood of declining health http://lat.ms/1J411L1
# 557302660014284800|Mon Jan 19 22:24:42 +0000 2015|Hey! Don't just sit there! Worry about how sitting affects your health! http://lat.ms/1J411L1
# 557279128521420802|Mon Jan 19 20:51:12 +0000 2015|So, how do I become vegan? http://lat.ms/1Glbcii
# 556452143293399040|Sat Jan 17 14:05:03 +0000 2015|Small, local and delicious health food thrives in L.A. area http://lat.ms/1Bhbkwd
# 556270021903933440|Sat Jan 17 02:01:22 +0000 2015|ADHD drug Vyvanse reduced binge-eating episodes from 4.5/week (on average) to nearly 0. Better than placebo. http://lat.ms/1E559K1
# 556226984125026305|Fri Jan 16 23:10:21 +0000 2015|New @US_FDA-approved weight loss device interrupts signals between the brain and the gut http://lat.ms/1xtH0qC
# 556179313041887234|Fri Jan 16 20:00:56 +0000 2015|Had a flu shot? Your (average) risk of getting sick enough to see a doctor is 23% lower than it would've been. http://lat.ms/1x6uC0X
# 556131311417819137|Fri Jan 16 16:50:11 +0000 2015|One upside to this year's bad flu season: Estimates of "vaccine effectiveness" can be made sooner http://lat.ms/1x6uC0X
# 556112660412891136|Fri Jan 16 15:36:04 +0000 2015|Gym Rat: Sharp-eyed teacher enhances Body Sculpt class at SC Fitness http://lat.ms/1BbuJhU
# 555906083731300353|Fri Jan 16 01:55:13 +0000 2015|The more you look, the more you find -- especially if you're @NASAJPL on the hunt for #methane http://lat.ms/1xZxLDo
# 555870828034662402|Thu Jan 15 23:35:07 +0000 2015|A bad shot is still better than no flu shot, @CDCgov experts say http://lat.ms/1x6uC0X
# 555863378070347776|Thu Jan 15 23:05:31 +0000 2015|Kids got the biggest boost from this year's flu shot. It reduced their risk of needing to see a doctor by 26% http://lat.ms/1x6uC0X
# 555855781325967360|Thu Jan 15 22:35:20 +0000 2015|Flu shot benefit for adults isn't big enough to be statistically significant (yet) but that could change http://lat.ms/1x6uC0X
# 555828966599446528|Thu Jan 15 20:48:47 +0000 2015|Drug looks promising as treatment for binge eating disorder. Bonus: It's already FDA-approved (to treat ADHD) http://lat.ms/1E559K1
# 555817992354025472|Thu Jan 15 20:05:10 +0000 2015|Would you let surgeons implant this device in your abdomen to help you lose weight? @US_FDA gives its blessing http://lat.ms/1xtH0qC
# 555814272752947204|Thu Jan 15 19:50:23 +0000 2015|Baby naps are at least as purposeful as they are peaceful http://lat.ms/1yijwIJ
# 555813464477007872|Thu Jan 15 19:47:11 +0000 2015|RT @LATMelissaHealy: Out-of-control eating can cause profound shame. An ADHD drug might stop the bingeing. http://lat.ms/1Ahet9S
# 555804798315134977|Thu Jan 15 19:12:44 +0000 2015|How bad is this year's flu shot? It reduces risk of getting sick enough to need a doctor by 23%, per @CDCgov http://lat.ms/1x6uC0X
# 555767713122222080|Thu Jan 15 16:45:23 +0000 2015|"Sleeping like a baby" is actually pretty purposeful work. Here's why researchers think so, via @PNASNews http://lat.ms/1yijwIJ
# 555752658448179200|Thu Jan 15 15:45:33 +0000 2015|MT @karihow: Brain cancer has taken so much from her, but woman embraces one gift it gave her: creativity.  http://www.latimes.com/local/great-reads/la-me-c1-brain-cancer-poet-20150114-story.html#page=1
# 555572142310686720|Thu Jan 15 03:48:15 +0000 2015|Out-of-control eating can cause profound shame. An ADHD drug might stop the bingeing. http://lat.ms/1Ahet9S
# 555570176251678721|Thu Jan 15 03:40:26 +0000 2015|A newly approved medical device disrupts hunger signals to prompt weight loss. http://lat.ms/1u5pGOf
# 555541246991953921|Thu Jan 15 01:45:29 +0000 2015|Ending the #Ebola outbreak in Liberia by June is a "realistic possibility" but not a "foregone conclusion" http://lat.ms/1yiiTPs
# 555495921971384320|Wed Jan 14 22:45:23 +0000 2015|Long work weeks may drive more than 2 million people to drink too much, researchers estimate http://lat.ms/1Iv5nwv
# 555454503827558400|Wed Jan 14 20:00:48 +0000 2015|If you spend at least 49 hours a week on your job, you may be more inclined toward "risky drinking" http://lat.ms/1Iv5nwv
# 555411561112936450|Wed Jan 14 17:10:09 +0000 2015|How being a workaholic may make you an alcoholic (or at least a risky drinker) @BMJ_company http://lat.ms/1Iv5nwv
# 555391461995593729|Wed Jan 14 15:50:17 +0000 2015|Researchers see a light at the end of the tunnel for Liberians dealing with #Ebola http://lat.ms/1yiiTPs
# 555136009491345408|Tue Jan 13 22:55:13 +0000 2015|Eyes may be the window to the soul but a computer program can judge your personality based on Facebook likes. http://lat.ms/1xW6wK2
# 555092465909514240|Tue Jan 13 20:02:11 +0000 2015|With help from Facebook, this computer program may be able to judge your personality as well as your spouse. http://lat.ms/1xW6wK2
# 555049298824806400|Tue Jan 13 17:10:39 +0000 2015|Bisphenol S has been replacing bisphenol A, but this study suggests it may be just as bad, if not worse: http://lat.ms/1y6HhFd
# 554832739808321536|Tue Jan 13 02:50:08 +0000 2015|Women and younger patients are more likely than others to be taking aspirin 'inappropriately' http://lat.ms/1BVAT4y
# 554826427728945153|Tue Jan 13 02:25:03 +0000 2015|Troubling link between bisphenol exposure &amp; prenatal brain development, from study in @PNASNews http://lat.ms/1y6HhFd
# 554821733421944833|Tue Jan 13 02:06:23 +0000 2015|If you "like" Snooki, Dr. Who or beer pong on Facebook, here's what that says about your personality http://lat.ms/1xW6wK2
# 554820157978476545|Tue Jan 13 02:00:08 +0000 2015|Aspirin may seem harmless, but for some people the risks (excessive bleeding) outweigh the benefits http://lat.ms/1BVAT4y
# 554811357980532737|Tue Jan 13 01:25:10 +0000 2015|Bisphenol levels that changed brain development in fetal fish are much lower than levels in the environment http://lat.ms/1y6HhFd
# 554803812826107907|Tue Jan 13 00:55:11 +0000 2015|Should YOU take aspirin to prevent a heart attack or stroke? Check here: http://1.usa.gov/1z2vUQ7 Story here: http://lat.ms/1BVAT4y
# 554803255327612928|Tue Jan 13 00:52:58 +0000 2015|Troubling link between bisphenols prenatal and brain development. @LATMelissaHealy via @PNASNews http://lat.ms/1y6HhFd
# 554800009225703424|Tue Jan 13 00:40:04 +0000 2015|12% of people taking aspirin to prevent first heart attack or stroke shouldn't be, study says http://lat.ms/1BVAT4y
# 553686448306913282|Fri Jan 09 22:55:10 +0000 2015|Bowhead whales live to be 200 years old. Can their genetic code tell us how they do it? http://lat.ms/146mjcY
# 553682789628129280|Fri Jan 09 22:40:38 +0000 2015|Did an erratic heartbeat inspire Beethoven's musical genius? Especially as his world went silent, maybe. http://lat.ms/1ANxvIX
# 553672832442302465|Fri Jan 09 22:01:04 +0000 2015|Try This!: 'Baby burpees' a great pregnancy exercise option http://lat.ms/1ACCcqa
# 553643694834724864|Fri Jan 09 20:05:17 +0000 2015|Kindly app lets strangers bond briefly over troubles http://lat.ms/1I3mDsk
# 553639927351902209|Fri Jan 09 19:50:19 +0000 2015|Would you want to live for 200 years? What if you had to be more like an Arctic-dwelling bowhead whale? http://lat.ms/146mjcY
# 553616966330494977|Fri Jan 09 18:19:05 +0000 2015|3 dietary lifestyles up close: Paleo, veganism and Slow Food movement http://lat.ms/1ABE6as
# 553601865170956288|Fri Jan 09 17:19:04 +0000 2015|Fitness resolution gets help with four ways to make workouts work http://lat.ms/1I2yqr3
# 553595850791084032|Fri Jan 09 16:55:10 +0000 2015|Instead of cutting back on the treats come January, shoppers seem to double down @CUFood_BrandLab http://lat.ms/1xJvDzw
# 553591798707126273|Fri Jan 09 16:39:04 +0000 2015|Out of the orange jumpsuit, Taylor Schilling stays calm and connected http://lat.ms/1ABcTEY
# 553369339064483840|Fri Jan 09 01:55:06 +0000 2015|How an "imaginary meal" could trick your body into burning fat. It worked in mice, still untested in people http://lat.ms/1AwEYwV
# 553327825991004161|Thu Jan 08 23:10:08 +0000 2015|What if e-cigarettes were taxed like regular cigarettes, and you couldn't smoke them in public? http://lat.ms/1IvuoFZ
# 553280378069610497|Thu Jan 08 20:01:36 +0000 2015|Cancer groups @AACR &amp; @ASCO sound open-minded about possible e-cigarette benefits for smokers, but they want proof http://lat.ms/1IvuoFZ
# 553270010903552000|Thu Jan 08 19:20:24 +0000 2015|It's January, but the contents of your shopping cart still say 'holiday.' @LATMelissaHealy via @PLOSONE http://lat.ms/1xJvDzw
# 553253708419858433|Thu Jan 08 18:15:37 +0000 2015|Wondering why your New Year's diet isn't working? Researchers have an idea: http://lat.ms/1xJvDzw
# 553242257550508032|Thu Jan 08 17:30:07 +0000 2015|Clever weight-loss idea from @SalkInstitute: Trick the body into burning fat by making it think it has eaten http://lat.ms/1AwEYwV
# 553242020802613248|Thu Jan 08 17:29:11 +0000 2015|Post-holiday food shopping keeps the merry going (and calories coming) http://lat.ms/1AwFz1S
# 553236886056361984|Thu Jan 08 17:08:46 +0000 2015|E-cigarettes should be presumed dangerous until proven otherwise, @AACR &amp; @ASCO argue: http://lat.ms/1IvuoFZ
# 553024563475660800|Thu Jan 08 03:05:05 +0000 2015|How soil from a grassy field in Maine might solve the problem of antibiotic resistance (at least for a long time) http://lat.ms/1Atz51f
# 553007246054264832|Thu Jan 08 01:56:16 +0000 2015|RT @LATkarenkaplan: Meet teixobactin, the best news in antibiotics in a LONG time. http://lat.ms/1Atz51f
# 553004453671215105|Thu Jan 08 01:45:10 +0000 2015|Clinical trials of teixobactin, a new antibiotic to fight superbugs, could begin in 2 years http://lat.ms/1Atz51f
# 552998141625397250|Thu Jan 08 01:20:05 +0000 2015|Meet teixobactin, the best news in antibiotics in a LONG time. http://lat.ms/1Atz51f
# 552642067269419009|Wed Jan 07 01:45:11 +0000 2015|Cold environments make it easier for cold viruses to make copies of themselves http://lat.ms/13UFer8
# 552604343728627712|Tue Jan 06 23:15:17 +0000 2015|Here's how cold (temperatures) help a cold (virus) multiply in your body, via @PNASNews http://lat.ms/13UFer8
# 552552786345615360|Tue Jan 06 19:50:24 +0000 2015|ICYMI: Scientists @JohnsHopkins explain how stem cells and 'bad luck' cause cancer http://lat.ms/1Aiva9Z
# 552508731813285889|Tue Jan 06 16:55:21 +0000 2015|That iPad on your bedside table will cost you about 20.6 minutes of sleep per night. via @DeborahNetburn http://lat.ms/1rZnTZE
# 552296019527225344|Tue Jan 06 02:50:06 +0000 2015|In the last week of 2014, deaths from flu &amp; pneumonia were just below 'epidemic' threshold, per @CDCgov http://lat.ms/1tKvNau
# 552287260688023552|Tue Jan 06 02:15:18 +0000 2015|43 states have 'widespread' flu activity as of Dec. 27 and 6 others have 'regional' spread. http://lat.ms/1tKvNau
# 552282196569231360|Tue Jan 06 01:55:11 +0000 2015|What do cold temperatures and cold viruses have in common? More than you might think. via @montemorin http://lat.ms/13UFer8
# 552282162167554048|Tue Jan 06 01:55:03 +0000 2015|Surprised? Small screens (on smart phones, iPads) disrupt kids' sleep more than large screens (ie TVs). http://lat.ms/1rZnTZE
# 552278399285485569|Tue Jan 06 01:40:05 +0000 2015|Screen time 'curfew' one hour before bed can help kids sleep better, @UCBerkeley researcher says http://lat.ms/1rZnTZE
# 552275965590917120|Tue Jan 06 01:30:25 +0000 2015|Flu activity in California was upgraded from 'sporadic' to 'regional' in the last week of 2014, @CDCgov says: http://lat.ms/1tKvNau
# 552271609919442946|Tue Jan 06 01:13:07 +0000 2015|This bad-news flu season keeps getting worse: http://lat.ms/1tKvNau
# 551364375177469952|Sat Jan 03 13:08:05 +0000 2015|Fitness champs, like Mohammad Ali and Kris Carr, come in all shapes, sizes http://lat.ms/1A5wCwh
# 551121394981822465|Fri Jan 02 21:02:34 +0000 2015|Misty Copeland knows how to keep a resolution http://lat.ms/1A1IbUZ
# 551105491586150400|Fri Jan 02 19:59:22 +0000 2015|Try This!: Jump in the pool for a three-move core workout http://lat.ms/1AjtNoL
# 551061372813860864|Fri Jan 02 17:04:04 +0000 2015|Dentists debate need to extract wisdom teeth http://lat.ms/1A0E5ws
# 550343396905058304|Wed Dec 31 17:31:05 +0000 2014|Despite menu changes over 18 years, fast food is still bad for you http://lat.ms/1zR1gJJ
# 550111638133964800|Wed Dec 31 02:10:09 +0000 2014|Watch out for H3N2 this flu season. Unfortunately, it's on a roll. http://lat.ms/1CS6Zjv
# 550076566387306497|Tue Dec 30 23:50:48 +0000 2014|@CeliacBeast @925mlbfan Hope your families are both on the mend soon!
# 550066354334990336|Tue Dec 30 23:10:13 +0000 2014|36 states have "widespread" flu activity, @CDCgov says. Is your state one of them? Check here: http://lat.ms/1CS6Zjv
# 550055555092742144|Tue Dec 30 22:27:18 +0000 2014|When @DrFriedenCDC warned that H3N2 could make this a bad flu season, he knew what he was talking about http://lat.ms/1CS6Zjv
# 549765645613940736|Tue Dec 30 03:15:18 +0000 2014|To keep diabetes under control, patients need more than doctors and prescriptions. http://lat.ms/1xuz9Qb
# 549744239547281412|Tue Dec 30 01:50:15 +0000 2014|Here's one way that going to war can pay off in the long-run for individual warriors via @montemorin http://lat.ms/171xnu6
# 549731688063172608|Tue Dec 30 01:00:22 +0000 2014|Diabetes patients with food insecurity or housing insecurity are only half as likely to have disease under control http://lat.ms/1xuz9Qb
# 549726573088505856|Tue Dec 30 00:40:03 +0000 2014|Doctors should look beyond the healthcare system to help their patients with Type 2 diabetes. via @JAMAInternalMed http://lat.ms/1xuz9Qb
# 549711492099375107|Mon Dec 29 23:40:07 +0000 2014|When money is tight for food and rent, keeping Type 2 diabetes under control is a bigger challenge. http://lat.ms/1xuz9Qb
# 549709175186812929|Mon Dec 29 23:30:55 +0000 2014|How food and housing insecurity translate into worse health for people with diabetes. via @JAMAInternalMed http://lat.ms/1xuz9Qb
# 548842249702735873|Sat Dec 27 14:06:03 +0000 2014|Cocktail concoctions that may have you drinking to your health http://lat.ms/1H4Bker
# 548570279031488512|Fri Dec 26 20:05:21 +0000 2014|For New Year's resolutions, go for gradual changes for a big effect http://lat.ms/16TOcqT
# 548524279675908097|Fri Dec 26 17:02:34 +0000 2014|Gear: Four watches that step up the time-telling game http://lat.ms/1CXefrx
# 548481369798483968|Fri Dec 26 14:12:03 +0000 2014|Lindsey Vonn says hard work and single-leg squats keyed comeback http://lat.ms/1CLPyRK
# 547795199720947712|Wed Dec 24 16:45:27 +0000 2014|Cardiologists wanted to see how their patients fared without them. The results were NOT what they expected. http://lat.ms/1CCKWdR
# 547572675988946944|Wed Dec 24 02:01:14 +0000 2014|Fact: Hypertension is much more common among blacks (42.1%) than  whites (28%) Latinos (26%) or Asians (24.7%) http://lat.ms/1HrVJZ8
# 547539029978537984|Tue Dec 23 23:47:32 +0000 2014|Smart phones are well-named. It appears they DO strengthen part of your brain, the somatosensory cortex. http://lat.ms/16OwcOE
# 547523373627371520|Tue Dec 23 22:45:19 +0000 2014|High blood pressure contributed to more than 362,000 American deaths in 2010, so get screened, experts say http://lat.ms/1HrVJZ8
# 547515803877523459|Tue Dec 23 22:15:14 +0000 2014|Would you abstain from sex for one year in order to donate blood? That's the ask from @US_FDA for MSM http://lat.ms/1sVjClh
# 547506917552435200|Tue Dec 23 21:39:55 +0000 2014|As the @US_FDA paves the way for some gay men to donate blood, activists call it a "first step" http://lat.ms/1sVjClh
# 547484387936595968|Tue Dec 23 20:10:24 +0000 2014|Curling up in bed with an e-book is NOT the same as curling up in bed with a REAL book. via @PNASNews http://lat.ms/16NsJ2V
# 547484366960869376|Tue Dec 23 20:10:19 +0000 2014|New cars may seem extravagant for teens, but the data shows they are safer @IP_BMJ http://lat.ms/1wah9n0
# 547449147419545602|Tue Dec 23 17:50:22 +0000 2014|Cardiologists (unwittingly) demonstrate that less can be more for heart patients @JAMAInternalMed http://lat.ms/1CCKWdR
# ...
# 155104247640367105|Fri Jan 06 01:51:48 +0000 2012|Kate Middleton's new cause: addiction and recovery http://lat.ms/x39cOS
# 155083999390339073|Fri Jan 06 00:31:21 +0000 2012|Cognitive decline may start in middle age, a study finds http://lat.ms/yJvsuD
# 155047707264811008|Thu Jan 05 22:07:08 +0000 2012|Some girls may think HPV vaccine protects against other STDs, too http://lat.ms/wgL3Cc
# 155027350055165952|Thu Jan 05 20:46:15 +0000 2012|Herpes vaccine study produces partial victory http://lat.ms/zHn8IE
# 154977474751635456|Thu Jan 05 17:28:03 +0000 2012|What you can learn from difficult sibling relationships http://lat.ms/wTShyx
# 154753930486759424|Thu Jan 05 02:39:46 +0000 2012|In child care, being active may take back seat to safety, academics http://lat.ms/zggxqn
# 154733439290064897|Thu Jan 05 01:18:21 +0000 2012|The American Dietetic Assn. gets a new name http://lat.ms/ynrj3m
# 154713262364176384|Wed Jan 04 23:58:10 +0000 2012|Mild kidney failure: Nick Cannon hospitalized; what is this disease? http://lat.ms/xmSoW0
# 154693072687595520|Wed Jan 04 22:37:57 +0000 2012|FDA limits some antibiotic use in food animals http://lat.ms/xEGwvB
# 154672887104671744|Wed Jan 04 21:17:44 +0000 2012|Nick Cannon hospitalized for 'mild' kidney failure: What is it? http://lat.ms/xmSoW0
# 154657086771445760|Wed Jan 04 20:14:57 +0000 2012|The DASH diet ranks best overall in U.S. News Best Diets 2012 http://lat.ms/wMbVRh
# 154642544855232512|Wed Jan 04 19:17:10 +0000 2012|Cancer death rates continue to fall http://lat.ms/xXLNZI
# 154629631545311232|Wed Jan 04 18:25:51 +0000 2012|Twin births skyrocket over last 30 years http://lat.ms/z2f6DE
# 154401756086939648|Wed Jan 04 03:20:21 +0000 2012|Childhood obesity ads spark controversy in Georgia: 'Horrible!' http://lat.ms/zcAAEG
# 154381490019512320|Wed Jan 04 01:59:50 +0000 2012|Sexual satisfaction highest in oldest, youngest women, study says http://lat.ms/xyBqVH
# 154361231547961344|Wed Jan 04 00:39:20 +0000 2012|China's H5N1 bird flu scare should be least of influenza worries http://lat.ms/ArUE8T
# 154344993534906368|Tue Jan 03 23:34:48 +0000 2012|Myocardial infarction:  Big minus for U.S. heart attack patients http://lat.ms/wOA2gt
# 154327542197792768|Tue Jan 03 22:25:27 +0000 2012|Too many calories, too little protein may mean more body fat http://lat.ms/zHbeun
# 154311585798701057|Tue Jan 03 21:22:03 +0000 2012|Weight-loss surgery reduces cardiovascular risks, study says http://lat.ms/w9r67u
# 153968441949290496|Mon Jan 02 22:38:31 +0000 2012|Physical activity and school performance: A closer look http://lat.ms/uE8Wed
# 152899003611222016|Fri Dec 30 23:48:57 +0000 2011|Silent strokes in the elderly may lead to memory loss http://lat.ms/v6vN36
# 152863345387651073|Fri Dec 30 21:27:16 +0000 2011|Bill Maher tweet mocks Tim Tebow, but does prayer enhance playing? http://lat.ms/sTdMyv
# 152842922977529857|Fri Dec 30 20:06:07 +0000 2011|Fencing may help improve some cognitive functions in older people http://lat.ms/rY36Xo
# 152793777755533312|Fri Dec 30 16:50:50 +0000 2011|Mistletoe may help kiss away some ills http://lat.ms/w3YIcw
# 152773528222056448|Fri Dec 30 15:30:22 +0000 2011|Why does my child get sick so often? http://lat.ms/slBT6e
# 152625389963968512|Fri Dec 30 05:41:43 +0000 2011|Tom Brady, Tony Romo and Colt McCoy: Common QB injuries http://lat.ms/vqNKOq
# 152609363662606337|Fri Dec 30 04:38:02 +0000 2011|Quitting smoking is tough, but not impossible http://lat.ms/unBR45
# 152590542033780738|Fri Dec 30 03:23:14 +0000 2011|Can you keep a secret? It may be just what you need to lose weight http://lat.ms/sQA5zd
# 152575501876207617|Fri Dec 30 02:23:29 +0000 2011|6,000 women a day hit menopause http://lat.ms/tywKxZ
# 152556891405426690|Fri Dec 30 01:09:31 +0000 2011|A little knowledge is a good thing for hangovers http://lat.ms/s3awgG
# 152521006676852736|Thu Dec 29 22:46:56 +0000 2011|Being obese could increase the risk of falling in older people http://lat.ms/vAGX8F
# 152505239021420544|Thu Dec 29 21:44:17 +0000 2011|Is Avastin a cost-effective treatment for ovarian cancer patients? http://lat.ms/svZ7rz
# 152490038314270720|Thu Dec 29 20:43:52 +0000 2011|Did Kobe Bryant give Yankees' Alex Rodriguez sound medical advice? http://lat.ms/uW8eD6
# 152216204130525184|Thu Dec 29 02:35:45 +0000 2011|Details of three face transplants offer a closer understanding http://lat.ms/vJzKt1
# 152180499543097344|Thu Dec 29 00:13:53 +0000 2011|Swine flu strain resistant to Tamiflu is spreading more easily http://lat.ms/tFf81Q
# 152160280703537152|Wed Dec 28 22:53:32 +0000 2011|How do we diet? With apps, healthful foods and smaller portions http://lat.ms/uXAOPf
# 152124426316546048|Wed Dec 28 20:31:04 +0000 2011|Consumer Reports rates top treadmills, ellipticals and pedometers http://lat.ms/w2e4Q3
# 152048827564687363|Wed Dec 28 15:30:40 +0000 2011|Teens aren't too old to boost their IQ, study finds http://lat.ms/uWPD3G
# 151830567560810496|Wed Dec 28 01:03:22 +0000 2011|Does shift work plus a poor diet equal an occupational hazard? http://lat.ms/v8esMD
# 151793813831163905|Tue Dec 27 22:37:20 +0000 2011|Smoking during pregnancy may be tied to children's vascular damage http://lat.ms/tM1UBF
# 151778440683593728|Tue Dec 27 21:36:14 +0000 2011|Healthcare workers question some ICU care decisions: Study http://lat.ms/sXwgIu
# 151743435928375296|Tue Dec 27 19:17:09 +0000 2011|The bond between mother and toddler could affect obesity later on http://lat.ms/tUfofj
# 151420838451752960|Mon Dec 26 21:55:15 +0000 2011|Pediatricians issue a call to aid children facing 'toxic stress' http://lat.ms/twClbd
# 150334643164553216|Fri Dec 23 21:59:06 +0000 2011|Kobe Bryant injures wrist: Lessons for him and for weekend warriors http://lat.ms/se2f7a
# 150287798539272192|Fri Dec 23 18:52:58 +0000 2011|Fathers' work schedules may be linked with their children's weight http://lat.ms/vhqWEQ
# 150271933714407424|Fri Dec 23 17:49:55 +0000 2011|Cigar company's Orange Bowl sponsorship is protested http://lat.ms/sWURi9
# 150236955270057984|Fri Dec 23 15:30:56 +0000 2011|Mental-health experts define 'recovery' http://lat.ms/shImmF
# 150088859890360320|Fri Dec 23 05:42:27 +0000 2011|Obesity epidemic may have roots in 1950s http://lat.ms/vcyYvO
# 150068501820870656|Fri Dec 23 04:21:33 +0000 2011|Conjoined twins share one body; can they be separated? http://lat.ms/umMSGL
# 150048211816558592|Fri Dec 23 03:00:56 +0000 2011|Supreme Court to hear arguments in March on healthcare law http://lat.ms/urkE5n
# 150033057703927808|Fri Dec 23 02:00:43 +0000 2011|Additive claims to be the boss of sugar, benefiting diabetics http://lat.ms/skQ9pB
# 150012714410971138|Fri Dec 23 00:39:52 +0000 2011|Coffee and athletic performance: Any effect? http://lat.ms/t2RY6o
# 149992439522930688|Thu Dec 22 23:19:18 +0000 2011|Giving babies salty food may create a lifelong preference http://lat.ms/sgHe33
# 149978058529570816|Thu Dec 22 22:22:10 +0000 2011|Wealthy nations with a lot of fast food: Destined to be obese? http://lat.ms/rZnDU5
# 149963208944402432|Thu Dec 22 21:23:09 +0000 2011|Music to go the extra mile http://lat.ms/t896ca
# 149947304164597761|Thu Dec 22 20:19:57 +0000 2011|Be mindful of where you keep your phone http://lat.ms/uEhcjA
# 149929445275340800|Thu Dec 22 19:08:59 +0000 2011|Wal-Mart recalls powdered infant formula http://lat.ms/uwSEts
# 149894886345281538|Thu Dec 22 16:51:40 +0000 2011|Thinner brains may be more susceptible to Alzheimer's disease http://lat.ms/tAQ6Dt
# 149874705871011840|Thu Dec 22 15:31:29 +0000 2011|Breast implant scare in France: U.S. doesn't have the same ones http://lat.ms/u4YiTP
# 149636535665426434|Wed Dec 21 23:45:04 +0000 2011|Gay marriage law appears to improve the health of gay men http://lat.ms/ujcRY3
# 149620464682147841|Wed Dec 21 22:41:13 +0000 2011|Her set of baseball cards highlights players' bizarre injuries http://lat.ms/vvWDVQ
# 149600114711855106|Wed Dec 21 21:20:21 +0000 2011|How much salt is in starchy foods young children eat? http://lat.ms/sIr9Y4
# 149320210103545856|Wed Dec 21 02:48:06 +0000 2011|Musicians may not be at higher risk for dying at 27, study says http://lat.ms/rRYL2h
# 149299893507325953|Wed Dec 21 01:27:23 +0000 2011|Is the 'Lie of the Year' about ending Medicare actually true? http://lat.ms/uYljGP
# 149285712410329088|Wed Dec 21 00:31:02 +0000 2011|Salt: Do health policymakers meet the limits they recommend? Guess http://lat.ms/vvHN0t
# 149265473052225536|Tue Dec 20 23:10:36 +0000 2011|Many police have sleep disorders, a risk to their health: study http://lat.ms/sclrrc
# 149250327659544576|Tue Dec 20 22:10:25 +0000 2011|HPV vaccination should be aimed at girls, study says http://lat.ms/ruBJhe
# 149235097265115136|Tue Dec 20 21:09:54 +0000 2011|Women's use of self-tanners may cut down on UV radiation exposure http://lat.ms/vnP5J3
# 149183585218342913|Tue Dec 20 17:45:13 +0000 2011|Drug poisoning deaths continue tragic climb http://lat.ms/rWgkJF
# 149164608312188928|Tue Dec 20 16:29:48 +0000 2011|Neti pot danger? Two die from amoeba infection http://lat.ms/ubXFLC
# 149149708806402048|Tue Dec 20 15:30:36 +0000 2011|Depression treatment: Better but still not great http://lat.ms/rTSkhC
# 148978617341329408|Tue Dec 20 04:10:44 +0000 2011|Youth arrests in the U.S. up in recent decades http://lat.ms/taUqiy
# 148958427903823873|Tue Dec 20 02:50:31 +0000 2011|Do you want to see what doctors write about you? Apparently, you do http://lat.ms/uRPHgn
# 148938269072162816|Tue Dec 20 01:30:25 +0000 2011|Making a resolution? Diet betting may offer incentive to lose weight http://lat.ms/rZtqfx
# 148922592361848832|Tue Dec 20 00:28:07 +0000 2011|Questions remain about vitamin D benefits and risks http://lat.ms/rVjvLC
# 148904352759816192|Mon Dec 19 23:15:38 +0000 2011|Friends start out with a lot in common, Facebook data show http://lat.ms/slMZNl
# 148886482118115328|Mon Dec 19 22:04:38 +0000 2011|Too many brain injuries spark a call to ban fighting in hockey http://lat.ms/u367oT
# 148866200787623936|Mon Dec 19 20:44:02 +0000 2011|Men who walk faster may be able to outpace the Grim Reaper http://lat.ms/sf8cDJ
# 148845742012907520|Mon Dec 19 19:22:44 +0000 2011|Young women's use of reproductive health services declines http://lat.ms/smPTbM
# 148062619977256961|Sat Dec 17 15:30:54 +0000 2011|Singer Etta James terminally ill: What is chronic leukemia? http://lat.ms/vh9DfV
# 147900801673723904|Sat Dec 17 04:47:53 +0000 2011|Thanks for the memory http://lat.ms/s6NnEj
# 147880567315243008|Sat Dec 17 03:27:29 +0000 2011|Christopher Hitchens' esophageal cancer, in his own words http://lat.ms/tyKqYy
# 147860307052736513|Sat Dec 17 02:06:58 +0000 2011|More doctors going the alternative route http://lat.ms/v8XDJr
# 147840123466285056|Sat Dec 17 00:46:46 +0000 2011|Going through some hard times may make people tougher http://lat.ms/tL7jTk
# 147823924267319297|Fri Dec 16 23:42:24 +0000 2011|Meet the chimps who helped researchers study human health http://lat.ms/vtk5oX
# 147805726868377600|Fri Dec 16 22:30:06 +0000 2011|Exercise drops off when teens transition to college, study finds http://lat.ms/s1JM2P
# 147790137177280514|Fri Dec 16 21:28:09 +0000 2011|Teen drinking, smoking continue to decline, but pot use is up http://lat.ms/ru0t59
# 147773877139939330|Fri Dec 16 20:23:32 +0000 2011|Finding the root of the problem with hair extensions http://lat.ms/tjxsmA
# 147758353098096641|Fri Dec 16 19:21:51 +0000 2011|Make it a drugstore Christmas http://lat.ms/sScK0E
# 147502913873383425|Fri Dec 16 02:26:49 +0000 2011|Biggest childhood obesity declines seen in New York City middle schools http://lat.ms/uHUiSS
# 147482723370545152|Fri Dec 16 01:06:36 +0000 2011|Fewer kids are exposed to unwanted sexual content online http://lat.ms/uiyU6O
# 147462487279796224|Thu Dec 15 23:46:11 +0000 2011|HPV test beats pap smear in cervical cancer screening http://lat.ms/tL0HfQ
# 147442051619880960|Thu Dec 15 22:24:59 +0000 2011|Biggest childhood obesity declines seen in New York City schools http://lat.ms/uHUiSS
# 147407807426199552|Thu Dec 15 20:08:54 +0000 2011|'Biggest Loser' winner John Rhode fears weight regain: How to keep weight off? http://lat.ms/vz3rFc
# 147387597424037888|Thu Dec 15 18:48:36 +0000 2011|Current practices protect human research subjects, panel says http://lat.ms/uBWPPO
# 147338038392000513|Thu Dec 15 15:31:40 +0000 2011|Are elevators really hazardous to your health? http://lat.ms/s0Fl6g
# 147146424130347008|Thu Dec 15 02:50:16 +0000 2011|Smoking? Not exercising? Here are some tips to get you through the holidays http://lat.ms/sxqBVu
# 147098116510842880|Wed Dec 14 23:38:18 +0000 2011|One in 4 women has been harmed by an intimate partner, CDC says http://lat.ms/sGfcvb
# 147047058740740097|Wed Dec 14 20:15:25 +0000 2011|Fewer people are getting married; how does marriage affect health? http://lat.ms/sDuG1r
# 146792493684506624|Wed Dec 14 03:23:52 +0000 2011|Charles Barkley slims down with Weight Watchers http://lat.ms/tL2ADI
# 146772277588008960|Wed Dec 14 02:03:32 +0000 2011|Teens don't find soft drinks so sweet if seeing sweat equivalents http://lat.ms/t4Bnf6
# 146752071213907968|Wed Dec 14 00:43:14 +0000 2011|Quality of life may improve for smokers who quit http://lat.ms/rQxBcD
# 146731310432526336|Tue Dec 13 23:20:45 +0000 2011|High-tech swimsuits may have given swimmers advantage, study says http://lat.ms/uB1gzs
# 146697303246381056|Tue Dec 13 21:05:37 +0000 2011|Does working make mothers happier and healthier? http://lat.ms/sqTg2f
# 146400676812029952|Tue Dec 13 01:26:56 +0000 2011|ADHD drugs don't increase heart risks in adults, study finds http://lat.ms/tVoCOb
# 146380434522124288|Tue Dec 13 00:06:29 +0000 2011|Treating ocular hypertension may reduce the risk of glaucoma: study http://lat.ms/rYwQmG
# 146345498826117120|Mon Dec 12 21:47:40 +0000 2011|Is that marzipan real or fake? There's a new way to test it http://lat.ms/ugtjn4
# 146329618792726529|Mon Dec 12 20:44:34 +0000 2011|World's tiniest infants doing fine now, but . . . http://lat.ms/uUXGqO
# 146309313588232192|Mon Dec 12 19:23:53 +0000 2011|Taking the stairs makes you more fit, saves you time, study says http://lat.ms/rqJ9Ip
# 145377975066566656|Sat Dec 10 05:43:04 +0000 2011|Miscarriage risks in focus after Michelle Duggar pregnancy loss http://lat.ms/utvf23
# 145357760018653185|Sat Dec 10 04:22:45 +0000 2011|Firms warned over sale of weight-loss hormone http://lat.ms/szf3mM
# 145337579145928704|Sat Dec 10 03:02:33 +0000 2011|Mode of delivery doesn't affect later maternal stress http://lat.ms/rPNDyc
# 145317432184156161|Sat Dec 10 01:42:30 +0000 2011|Drug combos could hold off advanced breast cancer http://lat.ms/sZMpLi
# 145283747510632449|Fri Dec 09 23:28:39 +0000 2011|Side effects may cause some women to quit breast cancer drugs early http://lat.ms/t0tQ3s
# 145267798606757888|Fri Dec 09 22:25:16 +0000 2011|Low-carb diets beat low-cal for cutting pounds and cancer risk http://lat.ms/tPXY3b
# 145250108806668288|Fri Dec 09 21:14:59 +0000 2011|Vermont keeps title of healthiest state, report shows http://lat.ms/tlpqtS
# 145235179814916097|Fri Dec 09 20:15:39 +0000 2011|The culprit in a cookie dough E. coli outbreak could be raw flour http://lat.ms/vFXizX
# 144990204414009344|Fri Dec 09 04:02:13 +0000 2011|Breast cancer and starch: Hold the pasta http://lat.ms/uPeCUG
# 144970054549770240|Fri Dec 09 02:42:09 +0000 2011|Weight-loss drug Qnexa is poised for FDA approval http://lat.ms/tun4GL
# 144952345170690052|Fri Dec 09 01:31:46 +0000 2011|Shift work: Good for your pocketbook, bad for your health http://lat.ms/srI28g
# 144936916838649857|Fri Dec 09 00:30:28 +0000 2011|Hold the pasta: Starchy food linked to breast cancer recurrence http://lat.ms/vopkPz
# 144917037414756354|Thu Dec 08 23:11:28 +0000 2011|Chronic pain is common child complaint, study finds http://lat.ms/sqbbYO
# 144881597869592576|Thu Dec 08 20:50:39 +0000 2011|Sporadic low-carb diets may help lower weight, insulin resistance http://lat.ms/vz4beE
# 144861369597050880|Thu Dec 08 19:30:16 +0000 2011|O.B. Ultra tampons are coming back, and the company apologizes with a song http://lat.ms/tu6n9S

# %% [markdown]
# #### Renaming columns of a CSV file

# %%
# The data set has been taken from UCI Machine Learning Repository.
# In this data set, the dependent variable is "target".
# It is a binary classification problem - to predict if the salary of a given person is less than or more than 50K.

df = pd.read_csv('./datasets/train.csv')

df.info()    # check info about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  31978 non-null  object
#  14  target          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.head()

# by default, index for a dataframe starts with 0
# Out:
#    age          workclass  fnlwgt education    education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital.status         occupation     relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital.gain  capital.loss  hours.per.week  native.country  target
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
dfNew = df.rename(columns = {'age': 'Age', 'workclass': 'Workclass', 'fnlwgt': 'Final wgt',
                     'education': 'Education', 'education.num': 'No. of years of education', 'marital.status': 'Marital Status',
                     'occupation': 'Occupation', 'relationship': 'Relationship', 'race': 'Race',
                     'sex': 'Sex', 'capital.gain': 'Capital Gain', 'capital.loss': 'Capital Loss', 'hours.per.week': 'Hours per week',
                     'native.country': 'Native Country', 'target': 'Target'
                    })

# renaming the columns :
# provide column names (in any order) in form of a dictionary inside rename() function

# %%
dfNew.head()
# Out:
#    Age          Workclass  Final wgt education    No. of years of education  \
# 0   39          State-gov      77516   Bachelors                         13
# 1   50   Self-emp-not-inc      83311   Bachelors                         13
# 2   38            Private     215646     HS-grad                          9
# 3   53            Private     234721        11th                          7
# 4   28            Private     338409   Bachelors                         13
#
#         Marital Status         occupation     Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital Gain  Capital Loss  Hours per week  Native Country  Target
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %% [markdown]
# Here you'll notice, 2 columns didn't get change ie. "education" & "occupation", because you'll find "education" has 2 spaces right after it and "occupation" has 1 space.

# %%
dfNew.columns
# Out:
# Index(['Age', 'Workclass', 'Final wgt', 'education  ',
#        'No. of years of education', 'Marital Status', 'occupation ',
#        'Relationship', 'Race', 'Sex', 'Capital Gain', 'Capital Loss',
#        'Hours per week', 'Native Country', 'Target'],
#       dtype='object')

# %% [markdown]
# This discrepency needs cleaning.<br>Python comes with a handy string function to strip function to strip white space called "strip()". When we pass this into rename we pass the function as the mapper parameter, and then indicate whether the axis should ne columns or index (row labels)

# %%
# here, we pass reference of str.strip function to the mapper (and, not calling strip function but just pasing it's reference. And, pandas will call it when needed)

dfNew = dfNew.rename(mapper=str.strip, axis='columns')
dfNew.head()
# Out:
#    Age          Workclass  Final wgt   education  No. of years of education  \
# 0   39          State-gov      77516   Bachelors                         13
# 1   50   Self-emp-not-inc      83311   Bachelors                         13
# 2   38            Private     215646     HS-grad                          9
# 3   53            Private     234721        11th                          7
# 4   28            Private     338409   Bachelors                         13
#
#         Marital Status          occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital Gain  Capital Loss  Hours per week  Native Country  Target
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %% [markdown]
# As we have stripped/truncated off of leading unwanted spaces, now we can change the names of any columns.

# %%
dfNew = dfNew.rename(columns={'education': 'Education', 'occupation': 'Occupation'})
dfNew.head()
# Out:
#    Age          Workclass  Final wgt   Education  No. of years of education  \
# 0   39          State-gov      77516   Bachelors                         13
# 1   50   Self-emp-not-inc      83311   Bachelors                         13
# 2   38            Private     215646     HS-grad                          9
# 3   53            Private     234721        11th                          7
# 4   28            Private     338409   Bachelors                         13
#
#         Marital Status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital Gain  Capital Loss  Hours per week  Native Country  Target
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %% [markdown]
# <b>Note:</b> Remember, though that the rename function isn't moifying the dataframe. In this case, df is same as it always was, there is just a copy in dfNew with the changes column names. We can check out to see for "df" below.

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education  ', 'education.num',
#        'marital.status', 'occupation ', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'target'],
#       dtype='object')

# %% [markdown]
# This same activity can also be achieved by assigning df.columns attribute to a list of column names and then perform operations like strip, etc. on it.<br>For instance,

# %%
cols = list(df.columns)

cols = [x.lower().strip() for x in cols]

df.columns = cols  # assigning "cols" list back to df.columns attribute

df.head()
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital.status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital.gain  capital.loss  hours.per.week  native.country  target
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %% [markdown]
# ****

# %% [markdown]
# ***In fact, there are other data sources that can be loaded into dataframes as well, including HTML web pages, databases, and other file formats.***
# ****

# %% [markdown]
# ## Querying a DataFrame

# %% [markdown]
# The first step in the process is to understand **Boolean masking**.<br>A Boolean masking is the heart of fast and efficient querying in NumPy and in Pandas, and it's analogous to bit masking which is used in other areas of computer science.<br><br>A Boolean mask is an array which can be thought of as 1-D like a series, or 2-D like a DataFrame, where each of the values of the array are either True or False.<br>This array is essentially overlaid on top of the other data structure that we can query, and any cell aligned with the true value will be admitted into our final result, and any cell aligned with the false value will not.<br><br>For instance, we'll deal with a dataset of cricketers.

# %%
# a dataset of cricketers in .txt format.
# !cat ./datasets/Cricket-Players.txt
# Out:
# Player Id	Player Surname	Player Other Names	Is Batter	Batter Hand Id	Batter Hand	Is Bowler	Bowler Hand Id	Bowler Hand	Pace/Spin	Bowler Style	Is Keeper	Gender Id	Gender
# 5	Razzaq	Abdul	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 11	Mahmood	Azhar	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 16	Raza	Hasan	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 17	Ali	Ghulam	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 18	Ahmad	Ijaz	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 20	Blewett	Greg	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 21	Bichel	Andrew	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 22	Bevan	Michael	Y	2	Left	Y	2	Left	Spin	Wrist	N	1	Male
# 23	Dale	Adam	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 25	Elliott	Matthew	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 26	Fleming	Damien	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 27	Gilchrist	Adam	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 28	Unknown		Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 29	Harvey	Ian	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 30	Hayden	Matthew	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 31	Healy	Ian	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 32	Hogg	Brad	Y	2	Left	Y	2	Left	Spin	Wrist	N	1	Male
# 35	Hamid	Mahmood	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 36	Akhtar	Manzoor	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 40	Wasim	Mohammad	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 41	Akram	Mohammad	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 44	Ahmed	Mushtaq	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 46	Khan	Moin	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 49	Latif	Rashid	Y	1	Right	Y	2	Left	Pace	Medium	N	1	Male
# 50	Anwar	Saeed	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 54	Elahi	Saleem	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 56	Mushtaq	Saqlain	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 59	Akhtar	Shoaib	Y	1	Right	Y	1	Right	Pace	Fast	N	1	Male
# 62	Younis	Waqar	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 63	Akram	Wasim	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 67	Yousuf	Mohammad	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 68	Kasprowicz	Michael	Y	1	Right	Y	1	Right	Pace	Fast	N	1	Male
# 69	Langer	Justin	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 71	Lee	Shane	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 73	MacGill	Stuart	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 74	Maher	Jimmy	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 75	Martyn	Damien	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 76	Miller	Colin	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 77	Lehmann	Darren	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 78	McGrath	Glen	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 82	Ponting	Ricky	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 84	Slater	Michael	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 87	Warne	Shane	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 88	Waugh	Steve	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 89	Wilson	Paul	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 90	Waugh	Mark	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 95	ul-Haq	Inzamam	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 98	Wasti	Wajahatullah	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 99	Ahmed	Shakeel	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 100	Stewart	Alec	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 101	Crawley	John	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 102	Butcher	Mark	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 103	Mullally	Alan	Y	1	Right	Y	2	Left	Pace	Medium	N	1	Male
# 105	Tudor	Alex	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 107	Atherton	Mike	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 108	Hussain	Nasser	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 109	Croft	Robert	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 110	Gough	Darren	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 111	Thorpe	Graham	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 112	Ramprakash	Mark	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 114	Hollioake	Ben	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 116	Cork	Dominic	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 123	Hollioake	Adam	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 124	Ealham	Mark	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 125	Giles	Ashley	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 126	Trescothick	Marcus	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 127	Knight	Nick	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 130	Atapattu	Marvan	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 131	Chandana	Upul	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 132	de Silva	Aravinda	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 133	Gunawardene	Avishka	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 134	Jayasuriya	Sanath	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 135	Kaluwitharana	Romesh	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 137	Muralidaran	Muttiah	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 140	Samaraweera	Thilan	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 141	Tillakaratne	Hashan	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 144	Zoysa	Nuwan	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 162	Jayawardene	Mahela	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 187	Collins	Pedro	Y	1	Right	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 188	Walsh	Courtney	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 190	Dillon	Mervyn	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 191	Jacobs	Ridley	Y	2	Left	Y	2	Left	Pace	Medium	Y	1	Male
# 192	Adams	Jimmy	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 195	Lara	Brian	Y	2	Left	Y	1	Right	Spin	Wrist	N	1	Male
# 197	Campbell	Sherwin	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 202	Blain	John	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 207	Hamilton	Gavin	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 215	Fleming	Stephen	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 216	Astle	Nathan	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 217	Horne	Matt	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 218	McMillan	Craig	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 219	Twose	Roger	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 220	Cairns	Chris	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 221	Parore	Adam	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 222	Harris	Chris	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 223	Nash	Dion	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 224	Vetorri	Daniel	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 226	Doull	Simon	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 231	Hossain	Shahriar	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 232	Hossain jnr	Mehrab	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 234	Mahmud	Khaled	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 237	Mashud	Khaled	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 239	Rafique	Mohammad	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 243	Islam	Manjural	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 246	Chanderpaul	Shivnarine	Y	2	Left	Y	1	Right	Spin	Wrist	N	1	Male
# 247	Powell	Ricardo	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 255	Ganguly	Sourav	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 256	Tendulkar	Sachin	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 257	Ramesh	Sadagoppan	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 258	Dravid	Rahul	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 260	Mongia	Nayan	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 261	Agarkar	Ajit	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 262	Kumble	Anil	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 263	Srinath	Javagal	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 264	Prasad	Venkatesh	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 265	Chopra	Nikhil	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 268	Campbell	Alistair	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 269	Flower	Andy	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 270	Flower	Grant	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 273	Carlisle	Stuart	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 276	Streak	Heath	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 279	Viljoen	Dirk	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 282	Whittall	Guy	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 284	Pollock	Shaun	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 286	Boje	Nicky	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 287	Boucher	Mark	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 289	Cullinan	Daryll	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 290	Donald	Allan	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 291	Elworthy	Steve	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 292	Gibbs	Herschelle	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 293	Kallis	Jacques	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 294	Kirsten	Gary	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 295	Klusener	Lance	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 297	Rhodes	Jonty	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 298	Katich	Simon	Y	2	Left	Y	2	Left	Spin	Wrist	N	1	Male
# 299	Arnold	Russell	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 301	de Silva	Chathuranga	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 304	Symonds	Andrew	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 306	Dilshan	Tillakaratne	Y	1	Right	Y	1	Right	Spin	Orthodox	Y	1	Male
# 307	Herath	Rangana	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 310	Rennie	Gavin	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 311	Strang	Bryan	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 312	Gripper	Trevor	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 315	Blignaut	Andy	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 316	Brent	Gary	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 317	Madondo	Trevor	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 319	Muller	Scott	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 321	Laxman	VVS	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 324	Singh	Harbhajan	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 326	Lee	Brett	Y	1	Right	Y	1	Right	Pace	Fast	N	1	Male
# 327	Malik	Shoaib	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 331	Dighe	Sameer	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 332	Spearman	Craig	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 333	Styris	Scott	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 334	Wisneski	Warren	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 335	Sinclair	Mathew	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 336	Wiseman	Paul	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 337	O'Connor	Shayne	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 339	Tuffey	Daryl	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 341	Hall	Andrew	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 342	Hayward	Mornantau	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 343	McKenzie	Neil	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 344	Telemachus	Roger	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 345	Terbrugge	David	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 346	Ntini	Makhaya	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 349	White	Craig	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 350	Flintoff	Andrew	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 351	Caddick	Andy	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 356	Hoggard	Matthew	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 357	Sangakkara	Kumar	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 359	Bashar	Habibul	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 360	Rokon	Al Sahariar	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 364	Sulzberger	Glen	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 365	Joseph	Sylvester	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 366	Samuels	Marlon	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 367	Nagamootoo	Mahendra	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 370	Stuart	Colin	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 371	Williams	Laurie	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 372	Nazir	Imran	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 373	Iqbal	Faisal	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 376	Singh	Yuvraj	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 377	Badani	Hemang	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 380	Odumbe	Maurice	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 381	Tikolo	Stephen	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 383	Shah	Ravindu	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 384	Odoyo	Thomas	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 386	Suji	Tony	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 387	Suji	Martin	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 390	Onyango	Lameck	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 393	Kamande	James	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 396	Hinds	Wavell	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 397	Browne	Courtney	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 399	Black	Marlon	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 400	Ganga	Daren	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 401	Sarwan	Ramnaresh	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 402	Friend	Travis	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 405	Marillier	Dougie	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 406	Cuffy	Cameron	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 407	Murphy	Brian	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 408	Bracken	Nathan	Y	1	Right	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 410	Hodge	Brad	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 411	Mackay	Gus	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 415	Vincent	Lou	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 416	Martin	Chris	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 418	Sidebottom (UK)	Ryan J	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 419	Ward	Ian	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 420	Khan	Younis	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 424	Nevin	Chris	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 426	Nel	Andre	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 427	Das	Shiv	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 428	Sehwag	Virender	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 430	Kemp	Justin	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 431	Sodhi	Reetinder	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 432	Nehra	Ashish	Y	1	Right	Y	2	Left	Pace	Medium	N	1	Male
# 433	Rudolph	Jacobus	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 435	Franklin	James	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 440	Oram	Jacob	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 443	Vaughan	Michael	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 444	Collingwood	Paul	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 445	Snape	Jeremy	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 446	Foster	James	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 447	Bangar	Sanjay	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 448	Jacobs	Arno	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 449	Smith	Graeme	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 451	Prince	Ashwell	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 452	Adams	Paul	Y	1	Right	Y	2	Left	Spin	Wrist	N	1	Male
# 453	Pretorius	Dewald	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 454	Hauritz	Nathan	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 455	Kent	Jon	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 457	Sami	Mohammad	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 458	Haq	Misbah ul	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 460	Afzaal	Usman	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 463	Ormond	Jimmy	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 464	Tufnell	Phil	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 473	Sahariar	Al	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 476	Muntasir	Fahim	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 477	Haque	Mazharul	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 482	Obuya	KD	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 489	Kapali	Alok	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 490	Dharmasena	Krishan	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 494	Farhat	Imran	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 500	Dunk	Ben	Y	2	Left	Y	1	Right	Spin	Orthodox	Y	1	Male
# 503	Wright	Craig McIntyre	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 504	Watson	Ryan Robert	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 506	Lyons	Ross Thomas	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 507	McCallum	Neil Francis Ian	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 508	Nel	Johannes Dewald	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 509	Poonia	Navdeep Singh	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 510	Rogers	Glen Allan	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 511	Smith	Colin John Ogilive	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 512	Watts	David Fraser	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 517	Kervezee	Alexen	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 519	Reekers	Darron	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 520	Szwarcynski	Eric	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 522	Razzak	Abdur	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 524	Esmurier	Jacob-Jan	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 525	Smits	Jereon	Y	1	Right	Y	1	Right	Pace	Fast-Medium	Y	1	Male
# 527	Laughlin	Ben	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 528	Coetzer	Kyle	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 531	Reifer	Floyd	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 600	Henderson	Colin	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 601	Brown	Allan	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 602	Bell	Matthew	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 4226	Seccombe	Wade	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 10205	Butler	Ian	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 10206	Richardson	Mark	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 10207	Adams	Andre	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 10208	Jones	Simon	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 10209	Key	Robert	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 10210	Harmison	Stephen	Y	1	Right	Y	1	Right	Pace	Fast	N	1	Male
# 10211	Jaffer	Wasim	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 10212	Patel	Parthiv	Y	2	Left	Y	2	Left	Pace	Medium	Y	1	Male
# 10213	Gayle	Chris	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 10220	Collymore	Corey	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 10221	Perera	Ruchira	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 10223	Dawson	Richard	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 10224	Kirtley	Robert	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 10225	Irani	Ronald	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 10227	Shah	Owais	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 10228	McCullum	Brendon	Y	1	Right	Y	1	Right	Pace	Fast-Medium	Y	1	Male
# 10230	Silva	Lindamlilage Pregeeth Chamara	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 10231	Kaif	Mohammad	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 10234	Umar	Taufeeq	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 10235	Kaneria	Danish	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 10238	Hooper	Carl	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 10242	Silverwood	Christopher	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 10243	Blackwell	Ian	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 10244	Ervine	Sean	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 10246	Hondo	Douglas	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 10247	Wishart	Craig	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 10248	Mongia	Dinesh	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 10249	Mills	Kyle	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 10250	Bond	Shane	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 10251	Hitchcock	Paul	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 10253	Zondeki	Monde	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 10255	Peterson	Robin	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 10259	Lawson	Jermaine	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 10260	Drakes	Vasberg	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 20004	Bahutule	Sairraj	Y	2	Left	Y	1	Right	Spin	Wrist	N	1	Male
# 20005	Kulkarni	Nilesh	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 20006	Gillespie	Jason	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 20044	Papps	Michael	Y	1	Right	Y	1	Right	Pace	Fast-Medium	Y	1	Male
# 20045	Mason	Michael	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 22050	Jones	Geraint	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 22051	Strauss	Andrew	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 22070	Bradshaw	Ian	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 22071	Bravo	Dwayne	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 22073	Deonarine	Narsingh	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 22074	Marshall	Xavier	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 22075	Morton	Runako	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 22076	Ramdin	Dinesh	Y	1	Right	Y	1	Right	Pace	Fast-Medium	Y	1	Male
# 22077	Sammy	Darren	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 22092	Pietersen	Kevin	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 22093	Bell	Ian	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 22099	de Villiers	Abraham	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 50006	Hussey	David	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 100039	McLean	Nixon	Y	2	Left	Y	1	Right	Pace	Fast	N	1	Male
# 100092	Dippenaar	Boeta	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 100102	Vaas	Chaminda	Y	2	Left	Y	2	Left	Pace	Fast	N	1	Male
# 100157	Sarkar	Hannan	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 100160	Hossain	Sanwar	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 100161	Imran	Tushar	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 100165	Baisya	Tapash	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 100173	Bagai	Ashish	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 100178	Davison	John	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 100195	van Troost	Luuk	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 100255	Noffke	Ashley	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 110014	Cosgrove	Mark	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 110015	Ferguson	Callum	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 130930	Klinger	Michael	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 140007	Reardon	Nathan	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 160006	Holland	Jon	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 170107	Gul	Umar	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 170108	Broad	Stuart	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 170109	Dalrymple	Jamie	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 170110	Yardy	Michael	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 170111	Joyce	Edmund	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 170112	Clarke	Rikki	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 170114	Onions	Graham	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 170116	Patel	Jeetan	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 190001	Badrinath	Subramaniam	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 190004	Kohli	Virat	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 190006	Krejza	Jason	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 190007	Siddle	Peter	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 190008	Bollinger	Doug	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 190021	Mishra	Amit	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 190022	Vijay	Murali	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 190023	Ryder	Jesse	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 190024	Southee	Tim	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 190026	Redmond	Aaron	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 190027	Elliott	Grant	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 190029	Tsotsobe	Lonwabo	Y	1	Right	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 190030	McDonald	Andrew	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 190031	van Jaarsveld	Vaughn	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 190033	Parnell	Wayne	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 190034	Harris	Ryan	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 190035	Guptill	Martin	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 190036	Broom	Neil	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 210008	Arafat	Yasir	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 210011	Rehman	Abdur	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 210014	Hilfenhaus	Ben	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 210015	Harwood	Shane	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 210017	Loye	Malachy Bernard	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 210018	Bopara	Ravindra Singh	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 210019	Voges	Adam	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 210024	Ireland	Anthony John	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 220001	Swann	Graham	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 220002	Patel	Samit Rohit	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 220033	Goswami	Jhulan	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 220034	Dhar	Rumeli	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 220035	Khadeer	Nooshin Al	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 220036	Chopra	Anjum	Y	2	Left	Y	1	Right	Pace	Medium	N	2	Female
# 220037	Deshpande	Anagha	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 220038	Thirushkamini	Em	Y	2	Left	Y	1	Right	Spin	Wrist	N	2	Female
# 220039	Malhotra	Reema	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 220040	Naik	Sulakshana	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 220041	Pradhan	Snehal	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 220042	Pujare	Seema	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 220043	Raj	Mithali	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 220044	Roy	Priyanka	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 220045	Sharma	Amita	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 220046	Sharma	Jaya	Y	2	Left	Y	1	Right	Pace	Medium	N	2	Female
# 220047	Sultana	Gouher	Y	1	Right	Y	2	Left	Spin	Orthodox	N	2	Female
# 220048	Jain	Karuna	Y	1	Right	Y	1	Right	Pace	Medium	Y	2	Female
# 220049	Kala	Hemlata	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 220050	Paranjpe	Sunetra	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 220051	Dimri	Preeti	Y	2	Left	Y	2	Left	Spin	Wrist	N	2	Female
# 220054	Fitzpatrick	Cathryn	Y	1	Right	Y	1	Right	Pace	Fast	N	2	Female
# 220061	Jonassen	Jess	Y	2	Left	Y	2	Left	Spin	Orthodox	N	2	Female
# 220066	Coyte	Sarah	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 220070	Mumtaz	Umrooj	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 220071	Mir	Sana	Y	1	Right	Y	1	Right	Spin	Orthodox	Y	2	Female
# 220074	Iqbal	Asmavia	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 220076	Mahroof	Bismah	Y	2	Left	Y	1	Right	Spin	Wrist	N	2	Female
# 220077	Khan	Javeria	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 220079	Abidi	Nain	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 220082	Jalil	Qanita	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 220083	Shah	Sajida	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 220085	Faiz	Sukhan	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 280001	Prior	Matthew	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 280002	Chawla	Piyush	Y	2	Left	Y	1	Right	Spin	Wrist	N	1	Male
# 280003	Masceranhas	Dimitri	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 290001	Mendis	Ajantha	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 290003	Ojha	Pragyan	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 290004	Ghosh	Dhiman	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 290006	Hasan	Raqibul	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 290007	Al Hasan	Shakib	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 290008	Geeves	Brett	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 300003	Brown	Douglas Robert	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 300004	Haq Khan	Rana Majid	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 300015	Rahim	Mushfiqur	Y	1	Right	Y	1	Right	Spin	Orthodox	Y	1	Male
# 300016	Iqbal	Tamin	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 300018	Borren	Peter William	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 300019	Jonkman	Mark	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 300021	Kashif	Mohammad	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 300025	ten Doeschate	Ryan	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 310006	Keen	Simon	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 320004	Mortaza	Mashrafe	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 320012	Trott	Jonathan	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 320014	Rampaul	Ravi	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 330004	Ashraful	Mohammad	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 330012	Hossain Monir	Anwar	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 330014	Omar	Javed	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 340004	Taylor	Jerome	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 340013	Dabengwa	Keith	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 340018	Rainsford	Edward	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 340022	Taylor	Brendan	Y	1	Right	Y	1	Right	Spin	Orthodox	Y	1	Male
# 340023	Utseya	Prosper	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 340024	Duffin	Terrence	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 340025	Chattergoon	Sewnarine	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 340027	Baugh	Carlton	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 340029	Powar	Ramesh Rajaram	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 340030	Singh	Rudra Pratap	Y	1	Right	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 340031	Sreesanth	Shanthakumaran	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 340032	Patel	Munaf Musa	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 340034	Uthappa	Robin	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 340045	Hasan	Saqibul	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 350104	Carey	Alex	Y	2	Left	Y	2	Left	Pace	Medium	Y	1	Male
# 360002	Hinds	Ryan	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 360030	Butt	Salman	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 360031	Hameed	Yasir	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 360032	Hafeez	Mohammad	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 360033	Akmal	Kamran	Y	1	Right	Y	1	Right	Spin	Orthodox	Y	1	Male
# 360034	ul-Hasan	Naved	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 360048	Powell	Darren	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 360049	Edwards	Fidel	Y	1	Right	Y	1	Right	Pace	Fast	N	1	Male
# 360052	Ontong	Justin Lee	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 360053	Smith	Dwayne	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 360056	Kamal	Asim	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 360068	Raina	Suresh	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 360071	Dhoni	Mahendra	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 370044	Doolan	Alex	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 370051	Pattinson	James	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 370095	Triscari	Gemma	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	2	Female
# 380167	Moor	Peter	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 380210	Munaweera	Dilshan	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 380221	Akmal	Umar	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 380229	Mithun	Mohammad	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 380296	Ingram	Peter J	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 380381	Tiffen	Haidee	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 380383	Browne	Nicola	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 380384	Burke	Sarah	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 380386	Devine	Sophie	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 380387	Fahey	Maria	Y	2	Left	Y	1	Right	Spin	Orthodox	N	2	Female
# 380388	McGlashan	Sara	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 380389	Watkins (nee Mason)	Aimee	Y	2	Left	Y	1	Right	Spin	Orthodox	N	2	Female
# 380390	Milburn	Rowan	Y	1	Right	Y	1	Right	Pace	Medium	Y	2	Female
# 380393	Tsukigawa	Sarah	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 380394	Watson	Helen	Y	2	Left	Y	1	Right	Pace	Medium	N	2	Female
# 380395	Priest	Rachel	Y	1	Right	Y	1	Right	Pace	Medium	Y	2	Female
# 380490	Nair	Karun	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 380497	Unadkat	Jaydev	Y	1	Right	Y	2	Left	Pace	Medium	N	1	Male
# 380553	Tiwary	Manoj	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 380558	Saha	Wriddiman	Y	1	Right	Y	1	Right	Spin	Orthodox	Y	1	Male
# 380568	Kitchen	Anaru	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 380573	Wagner	Neil	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 380585	Hendricks	Reeza	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 380599	Jadhav	Kedar	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 380722	Blackwood	Jermaine	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 380728	Dowrich	Shane	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 380735	Warrican	Jomel	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 380738	Haque	Anamul	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 380748	Sarkar	Soumya	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 380765	Balbirnie	Andrew	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 380774	Poynter	Stuart	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 380778	Thompson	Stuart	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 380779	Young	Craig	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 380804	Latham	Tom	Y	2	Left	Y	1	Right	Pace	Medium	Y	1	Male
# 380809	Wheeler	Ben	Y	1	Right	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 380817	Azam	Babar	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 380845	Karunaratne	Dimuth	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 380851	Pradeep	Nuwan	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 380854	Paranavitana	Tharanga	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 380891	Yadav	Umesh	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 380908	Phangiso	Aaron	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 380909	Pandey	Manish	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 390029	Jayawardene	Prasanna	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 390247	Jamshed	Nasir	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 390248	Shehzad	Ahmed	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 390249	Iffikhar	Rao	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 450003	Duminy	Jean Paul	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 450004	Morkel	Albie	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 450005	Morkel	Morne	Y	2	Left	Y	1	Right	Pace	Fast	N	1	Male
# 450006	Philander	Vernon	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 450007	Maddy	Darren	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 450008	Scholfield	Chris	Y	2	Left	Y	1	Right	Spin	Wrist	N	1	Male
# 450010	Wright	Luke	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 450012	McCullum	Nathan	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 450015	Sharma	Jogindar	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 450017	Pathan	Yousuf	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 450018	Sharma	Rohit	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 450019	Alam	Fawad	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 450020	ul-Haq	Misbah	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 450021	Wijekoon	Gayan	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 450022	Perera	Dilruwan	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 450023	Drummond	Gordon	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 450025	Sheik	Qasim	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 450027	Mishra	Tanmay	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 450028	Obanda	Alex	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 450029	Odhiambo	Nehemiah	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 450030	Ouma	Maurice	Y	1	Right	Y	1	Right	Spin	Orthodox	Y	1	Male
# 450032	Marumisa	Johnson	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 450033	Madsakdzda	Hamilton	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 450034	Chowdhury	Nadif	Y	1	Right	Y	2	Left	Pace	Medium	N	1	Male
# 450035	Mahmudullah	Riyad	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 450036	Siddique	Junaid	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 450037	Reza	Farhad	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 450038	Nazimuddin	Mohammed	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 450039	Rahman	Ziaur	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 450040	Tanvir	Sohail	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 450041	Harris	Paul	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 450042	Amla	Hashim	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 450044	Parchment	Brenton Anthony	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 450046	Sharma	Ishant	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 450047	Rogers	Chris	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 450048	Browne	Patrick	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 450050	Kumar	Praveen	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 450052	Amerasinghe	Merenna Koralge Don Ishara	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 450056	Benn	Suliemen	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 450057	Jaggernauth	Amit	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 450059	Casson	Beau	Y	1	Right	Y	2	Left	Spin	Wrist	N	1	Male
# 450060	Fletcher	Andre	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 450061	Perkins	William	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 450062	Roach	Kemar	Y	1	Right	Y	1	Right	Pace	Fast	N	1	Male
# 450063	Ronchi	Luke	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 450064	Findlay	Shawn	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 450065	Miller	Nkita	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 450066	Marsh	Shaun	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 460031	Bolton	Nicole	Y	2	Left	Y	1	Right	Spin	Orthodox	N	2	Female
# 460034	Chappell	Renee	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 460035	Elliott	Sarah	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 460037	Beams	Kristen	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 460038	Duffin	Jessica	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 460044	Haynes	Rachael	Y	2	Left	Y	2	Left	Pace	Medium	N	2	Female
# 460047	Hunter	Julie	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 460050	Moloney	Annie	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 460053	Smith	Clea	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 460055	Villani	Elyse	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 460075	Sthalekar	Lisa	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 460076	Aley	Sarah	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 460077	Andrews	Sarah	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 460078	Blackwell	Alex	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 460080	Blackwell	Kate	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 460085	Healy	Alyssa	Y	1	Right	Y	1	Right	Spin	Orthodox	Y	2	Female
# 460090	Poulton	Leah	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 460091	Perry	Ellyse	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 520003	Khalil	Mohammed	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 520004	Asif	Mohammed	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 520007	Hopes	James	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 520011	Tait	Shaun	Y	1	Right	Y	1	Right	Pace	Fast	N	1	Male
# 520013	White	Cameron	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 520015	Finch	Aaron	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 520017	Anjum	Iftekhar Rao	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 520029	Kumar	Vinay	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 520050	Wilson	Jeff	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 520051	Marshall	James	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 520053	Cumming	Craig	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 520054	Hamilton	Lance	Y	1	Right	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 520055	O'Brien	Iain	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 520056	Canning	Tama	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 520057	Stewart	Shannon	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 520058	Taylor	Ross	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 520065	Chowdhury	Aftab Ahmed	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 520067	Haque Jnr	Enamul	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 520068	Hossain	Nazmul	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 520069	Hossain	Shahadat	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 520070	Iqbal	Nafees	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 520071	Nafees	Shahriar	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 520072	Gillespie	Mark	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 520075	Saleh	Rajin	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 520076	Lewis	Jon	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 520078	Tremlett	Chris	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 520080	Plunkett	Liam	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 520081	Panesar	Monty	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 520118	Chibhabha	Chamu	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 520120	Kasteni	Friday	Y	2	Left	Y	2	Left	Pace	Medium	Y	1	Male
# 520122	Mawoyo	Tino	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 520314	Bates	Suzie	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 520329	Martin	Katey	Y	1	Right	Y	1	Right	Pace	Fast-Medium	Y	2	Female
# 520330	Candy	Rachel	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 520332	Doolan	Lucy	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 520334	Lind	Victoria	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 520335	McNeill	Beth	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 520337	Perry	Elizabeth	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 520341	Dodd	Anna	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 540001	Evans	Craig	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 540002	Ewing	Gavin	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 540003	Matsikenyeri	Stuart	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 540004	Price	Ray	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 540005	Mahwire	Blessing	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 540006	Karthik	Murali	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 540007	Salvi	Arishkar	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 540008	Pathan	Irfan	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 540009	Sibanda	Vusi	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 540010	Balaji	Arjun	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 540011	Gavaskar	Rohan	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 540012	Haddin	Brad	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 540013	Hussey	Michael	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 540014	Kulasekara	Mudiyanselage	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 540015	Lokuarachchi	Kaushai	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 540016	Fernando	Dilhara	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 540021	Jayantha	Saman	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 540023	Chigumbura	Elton	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 540024	Maregwede	Alester	Y	1	Right	Y	1	Right	Spin	Orthodox	Y	1	Male
# 540025	Panyangara	Tinashe	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 540026	Mupariwa	Tawande	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 540027	Nkala	Mluleki	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 540029	Mwayenga	Waddington	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 540030	Malinga	Lasith	Y	1	Right	Y	1	Right	Pace	Fast	N	1	Male
# 540036	Hopkins	Gareth	Y	1	Right	Y	1	Right	Pace	Fast-Medium	Y	1	Male
# 540037	Marshall	Hamish	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 540038	Mahmood	Sajid	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 540046	Staples	Richard	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 540047	Ali	Aijaz	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 540048	Alexander	Rohan	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 540050	Desai	Jignesh	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 540051	Johnson	Howard	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 540052	Johnson	Mark	Y	2	Left	Y	1	Right	Spin	Orthodox	Y	1	Male
# 540053	Lambert	Clayton	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 540054	Messiah	Steve	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 540056	Javed	Nasir	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 540057	Zia	Rashid	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 540058	Reid	Charles	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 540059	Romero	Leon	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 540060	Solanki	Vikram	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 540061	Wharf	Alex	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 540062	Maharoof	Farveez	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 540065	Karthik	Dinesh	Y	1	Right	Y	1	Right	Spin	Orthodox	Y	1	Male
# 540066	Gambhir	Guatam	Y	2	Left	Y	1	Right	Spin	Wrist	N	1	Male
# 560018	Bulow	Melissa	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 560024	Pike	Kirsten	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 560026	Fields	Jodie	Y	1	Right	Y	1	Right	Pace	Medium	Y	2	Female
# 560030	Rolton	Karen	Y	2	Left	Y	2	Left	Pace	Medium	N	2	Female
# 560033	Ebsary	Lauren	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 560040	Nitschke	Shelley	Y	2	Left	Y	2	Left	Spin	Orthodox	N	2	Female
# 560041	Sampson	Emma	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 610017	Read	Chris	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 610037	Langeveldt	Charl	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 690006	Rasel	Syed	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 690007	Cullen	Dan	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 690129	Behrendorff	Jason	Y	1	Right	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 690148	Burns	Erin	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 690154	Britt	Kris	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 690155	Coleman	Leonie	Y	1	Right	Y	1	Right	Pace	Medium	Y	2	Female
# 690227	Mennie	Joe	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 690305	Graham	Heather	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 700002	Clark	Stuart	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 700010	Lewis	Michael	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 700011	Johnson	Mitchell	Y	2	Left	Y	2	Left	Pace	Fast	N	1	Male
# 700012	Jaques	Philp	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 700013	Botha	Johan	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 700015	Tharanga	Upal	Y	2	Left	Y	1	Right	Pace	Fast-Medium	Y	1	Male
# 700016	Kapugedara	Chamara	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 700017	Vandort	Michael	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 700018	Bandara	Malinga	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 700019	Fulton	Peter	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 700020	How	Jamie	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 700024	van der Wath	Johannes	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 700026	Steyn	Dale	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 700027	Dorey	Brett	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 700028	Ganegama	Akalanka	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 700033	Tshabalala	Thandi	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 700034	Bosman	Lungile Loots	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 720158	Farrell	Rene	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 720187	Gunn	Jenny	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 720202	Edwards	Charlotte	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 720203	Atkins	Caroline	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 720204	Birch	Rosaline	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 720205	Davis	Stephanie	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 720206	Greenway	Lydia	Y	2	Left	Y	2	Left	Pace	Medium	N	2	Female
# 720207	Guha	Isa	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 720209	Marsh	Laura	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 720210	Morgan	Beth	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 720212	Smit	Jane	Y	1	Right	Y	1	Right	Pace	Medium	Y	2	Female
# 720213	Taylor	Claire	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 720214	Taylor	Sarah	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 740003	Watson	Shane	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 740004	Batty	Richard	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 740005	Anderson	James	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 740006	Campbell	Ryan	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 740007	Mubarak	Jehan	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 740008	Nissanka	Prabath	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 740009	Gunaratne	Pulasthi	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 740010	de Silva	Sujeewa	Y	1	Right	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 740011	Love	Martin	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 750001	Williams	Brad	Y	1	Right	Y	1	Right	Pace	Fast	N	1	Male
# 750002	Buddhika	Charitha	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 750004	Clarke	Michael	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 750006	Gamage	Chamilla	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 750009	Lefebvre	Roland	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 750012	Raja	Abdeel	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 750013	De Leede	Timotheus	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 750014	Kloppenburg	Jan Feiko	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 750015	Nijman	Ruud	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 750016	Schiferli	Edgar	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 750017	Scholte	Reinout	Y	1	Right	Y	1	Right	Pace	Fast-Medium	Y	1	Male
# 750018	Statham	Nick	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 750019	van Noortwijk	Klaas-Jan	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 750022	van Bunge	Daan	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 750025	Vermeulen	Mark	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 750026	Taibu	Tatenda	Y	1	Right	Y	1	Right	Pace	Fast-Medium	Y	1	Male
# 750029	Kotze	Deon	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 750030	Burger	Louis	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 750031	Karg	Morne	Y	1	Right	Y	1	Right	Pace	Fast-Medium	Y	1	Male
# 750032	Kotze	Bjorn	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 750033	Burger	Andries	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 750034	Burger	Sarel	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 750035	Keulder	Danie	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 750037	Murgatroyd	Bryan	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 750038	Swanepoel	Stephan	Y	1	Right	Y	1	Right	Pace	Fast-Medium	Y	1	Male
# 750039	van Schoor	Melt	Y	1	Right	Y	1	Right	Pace	Fast-Medium	Y	1	Male
# 750042	van Rooi	Burton	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 750043	Janse Van Vuuren	Rudolph	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 750044	Karim	Aasif	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 750045	Obuya	Collins	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 750046	Angara	Joseph	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 750047	Modi	Hitesh	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 750048	Obuya	David	Y	1	Right	Y	1	Right	Pace	Fast-Medium	Y	1	Male
# 750049	Ongondo	Peter	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 750050	Patel	Brijal	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 750055	Bernard	Dave	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 750056	Smith	Devon	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 750059	Banks	Omari	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 750061	Hurley	Ryan	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 750063	Kumar	Tapash	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 750064	Hossain	Habibul	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 750096	Lynn	Chris	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 750263	Chatara	Tendai	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 750366	Ferling	Holly	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 800007	Osborne	Erin	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 810013	Ali	Kabir	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 840033	Millanta	Sharon	Y	2	Left	Y	1	Right	Pace	Medium	N	2	Female
# 860006	Mooney	Bethany	Y	2	Left	Y	1	Right	Pace	Medium	Y	2	Female
# 860017	Strano	Molly	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 860018	Nash	Brendon	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 860021	Flynn	Daniel	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 860024	Pulford	Kate	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 860025	Burrows	Abby	Y	2	Left	Y	1	Right	Pace	Medium	N	2	Female
# 860026	Brunt	Katherine	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 860027	Griffiths	Lauren	Y	1	Right	Y	1	Right	Pace	Medium	Y	2	Female
# 860028	Rainford-Brent	Ebony-Jewel	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# ...
# 2960006	Gabriel	Shannon	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 2960007	Permaul	Veerasammy	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 2960008	Chandrika	Rajindra	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 2960009	Lyth	Adam	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 2960010	Wood	Mark Andrew	Y	1	Right	Y	1	Right	Pace	Fast	N	1	Male
# 2960012	Stoinis	Marcus	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 2960014	McBrine	Andy	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 2960017	Billings	Sam	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 2960019	Willey	David	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 2960020	Vince	James	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 2960021	Topley	Reece	Y	1	Right	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 2960022	Handscomb	Peter	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3050035	Ali	Hasan	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3060006	Gayakwad	Rajeshwari	Y	1	Right	Y	2	Left	Spin	Orthodox	N	2	Female
# 3060007	Mandhana	Smriti	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 3060008	Pandey	Shikha	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3060009	Yadav	Kuldeep	Y	2	Left	Y	2	Left	Spin	Wrist	N	1	Male
# 3060010	Sharma	Deepti	Y	2	Left	Y	1	Right	Spin	Orthodox	N	2	Female
# 3060011	Vanitha	Vellaswamy	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3060012	Rana	Sheh	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3060014	Kalpana	Ravi	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3060016	Newton	Thamsyn	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3060017	Rowe	Hannah	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3060019	Peterson	Anna	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 3060020	Davis	Felicity Leydon	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3060023	Fourie	Yolani	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 3060024	Khaka	Ayabonga	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3060026	Ranaweera	Inoka	Y	2	Left	Y	1	Right	Spin	Orthodox	N	2	Female
# 3060027	Hansika	Nipuni	Y	2	Left	Y	1	Right	Unknown	Unknown	N	2	Female
# 3060028	Dasanayake	Sugandika	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3060029	Sanjeewani	Anushka	Y	1	Right	Y	1	Right	Pace	Medium	Y	2	Female
# 3060030	Kumari	Sugandika	Y	2	Left	Y	2	Left	Spin	Orthodox	N	2	Female
# 3060031	Mendis	Imalka	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3060032	Kulasooriya	Achini	Y	2	Left	Y	1	Right	Pace	Medium	N	2	Female
# 3060033	Kanchana	Ama	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3060034	Madhavi	Harshitha	Y	2	Left	Y	1	Right	Pace	Medium	N	2	Female
# 3060035	Gunawardena	Chathurani	Y	1	Right	Y	1	Right	Unknown	Unknown	N	2	Female
# 3060036	Shehani	Malsha	Y	1	Right	Y	1	Right	Unknown	Unknown	N	2	Female
# 3060041	Blundell	Tom	Y	1	Right	Y	1	Right	Spin	Orthodox	Y	1	Male
# 3060045	Javed	Iran	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3060049	Tripathi	Rahul	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3060050	Chaudhary	Shivam	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 3060051	Sundar	Washington	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 3060052	Rana	Nitish	Y	2	Left	Y	1	Right	Spin	Wrist	N	1	Male
# 3060053	Poddar	Govind	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 3060054	Gowsami	Shreevats	Y	2	Left	Y	1	Right	Spin	Wrist	Y	1	Male
# 3060055	Shah	Rahil	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 3060056	Karnewar	Akshay	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 3060057	Khejroliya	Kulwant	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 3060058	Patel	Kushang	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3060059	Khan	Avesh	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3060062	Chapman	Mark	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 3060063	Seifert	Tim Louis	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 3060066	Dunkley	Sophia	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 3080009	Mann	Gurkeerat Singh	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 3080010	Dhawan	Rishi	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3080012	Paris	Joel	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 3080014	Head	Travis	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 3080015	Tye	Andrew	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3080016	Pandya	Hardik Himanshu	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3080018	Zampa	Adam	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 3080020	Sayers	Chadd	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3080021	Bancroft	Cameron	Y	1	Right	Y	2	Left	Pace	Medium	N	1	Male
# 3080023	Azam	Mohammad Babar	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 3080025	Wasim	Syed Imad	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 3080026	Amir	Mohammad	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 3080030	Morris	Chris	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3080036	Hasan	Nurul	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3080037	Sajib	Saqlain	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 3080038	Carter	Jonathon Lyndon	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 3080040	de Silva	Dhananjaya	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 3080041	Fernando	Vishwa	Y	1	Right	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 3080043	Sandakan	Lakshan	Y	1	Right	Y	2	Left	Spin	Wrist	N	1	Male
# 3080045	Silva	Kusal	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3080046	Mendis	Kusal	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3080049	Fernando	Avishka	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3080050	Siriwardana	Milinda	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 3080051	Gunathilaka	Danushka	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 3080052	Parera	Angelo	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 3080054	Pathirana	Sachith	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 3080056	Shanaka	Dasun	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3080057	Rajitha	Kasun	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3080062	Terry	Sean	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 3080064	McCarthy	Barry	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3080065	Chase	Peter	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3080066	Anderson	John	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 3080067	Bavuma	Temba	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3080068	Pretorius	Dwaine	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3080069	Cook	Stephen	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3080070	Maharaj	Keshav	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 3080071	Vilas	Dane	Y	1	Right	Y	1	Right	Unknown	Unknown	Y	1	Male
# 3080075	Rizwan	Mohammad	Y	1	Right	Y	1	Right	Spin	Wrist	Y	1	Male
# 3080076	(Sub)	Substitution Fielder	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3080078	Swepson	Mitchell Joseph	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 3080085	Iyer	Shreyas	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 3080086	Sub	.	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3080087	Hasan	Mehedi	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 3080088	Sub	.	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 3080089	Ball	Jake	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3080090	Sub	A	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3080092	Islam	Shafiul	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3110052	Klaasen	Heinrich	Y	1	Right	N	1	Right	Spin	Orthodox	N	1	Male
# 3110056	Mulder	Wiaan	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3110057	Pandya	Krunal	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 3110058	Pant	Rashabh	Y	2	Left	N	1	Right	Unknown	Unknown	Y	1	Male
# 3110059	Siraj	Mohammed	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3200081	Wareham	Georgia	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 3250020	Farrant	Natasha	Y	2	Left	Y	2	Left	Pace	Medium	N	2	Female
# 3290010	Gunaratne	Asela DAS	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 3300024	Jones	Amy	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3300025	Garth	Kim	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3300029	Sanjaya	Vikum	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3440001	de Klerk	Nadine	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3440002	Ntozakhe	Raisibe	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 3440005	Fatima	Ghulam	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 3440008	Akhtar	Waheeda	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3440009	Ebrahim	Dion	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3470008	Boyce	Reniece	Y	1	Right	Y	1	Right	Pace	Medium	Y	2	Female
# 3470012	Walters	Felicia	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3470013	Joshi	Mansi	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3470014	Parween	Nuzhat	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3550132	Ecclestone	Sophie	Y	1	Right	Y	2	Left	Spin	Orthodox	N	2	Female
# 3550181	Ahmed	Rumana	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 3550183	Khadija	Tul	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 3550184	Archer	Jofra	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3550185	Khan	Rashid	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 3550410	Glenn	Sarah	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 3550419	Mali	Zintle	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 3550421	Sekhukhune	Tumi	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3550464	Chahar	Deepak	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3550465	Markande	Mayank	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 3550466	Ahmed	Khaleel	Y	1	Right	Y	2	Left	Pace	Medium	N	1	Male
# 3550473	Saini	Navdeep	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3550578	Ur Rahman	Mujeeb	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 3550581	Shinwari	Usman	Y	1	Right	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 3550630	Silva	Roshen	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 3550631	Kumara	Lahiru	Y	2	Left	Y	1	Right	Pace	Fast	N	1	Male
# 3550632	Chameera	Dushmantha	Y	1	Right	Y	1	Right	Pace	Fast	N	1	Male
# 3550833	Mair	Rosemary Alison	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3630015	Shaw	Prithvi	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 3630016	Gill	Shubman	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 3630067	Banton	Tom	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 3760003	Malan	Dawid	Y	2	Left	Y	1	Right	Spin	Wrist	N	1	Male
# 3760005	Stoneman	Mark	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 3760006	Curran	Thomas Kevin	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3760008	Markram	Aiden Kyle	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 3760009	Ngidi	Lungi	Y	1	Right	Y	1	Right	Pace	Fast	N	1	Male
# 3760011	Klaasen	Henrich	Y	1	Right	Y	1	Right	Pace	Medium	Y	1	Male
# 3760016	Asif	Bilal	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 3760020	Abbas	Mohammad	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3760026	Pant	Rishabh	Y	2	Left	Y	1	Right	Spin	Wrist	Y	1	Male
# 3760031	Agarwal	Mayank	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 3760032	Karunaratne	Chamika	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3760033	Kaul	Siddarth	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3760035	Masood	Shan	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 3760036	Ali	Abid	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 3760038	Hasnain	Mohammad	Y	1	Right	Y	1	Right	Pace	Fast	N	1	Male
# 3760041	Zazai	Hazratullah	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 3760042	Shahidi	Hashmatullah	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 3760043	Shah	Rahmat	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 3760046	Nurse	Ashley Renaldo	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 3760047	Hetmyer	Shimron Odilon	Y	2	Left	Y	1	Right	Spin	Wrist	N	1	Male
# 3760048	Hope	Shai Diego	Y	1	Right	Y	1	Right	Spin	Orthodox	Y	1	Male
# 3760049	Brathwaite	Carlos Ricardo	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3760051	Cottrell	Sheldon Shane	Y	1	Right	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 3760052	Thomas	Oshane Romaine	Y	2	Left	Y	1	Right	Pace	Fast	N	1	Male
# 3760053	Fernando	Oshada	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 3760065	Lewis	Evin	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 3760066	Pooran	Nicholas	Y	2	Left	Y	1	Right	Spin	Orthodox	Y	1	Male
# 3760070	Dawson	Liam	Y	1	Right	Y	2	Left	Spin	Orthodox	N	1	Male
# 3760072	Perera	Thisara	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3760076	Das	Liton	Y	1	Right	Y	1	Right	Spin	Orthodox	Y	1	Male
# 3760082	Stone	Oliver Peter	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3760084	Burns	Rory	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 3760085	Denly	Joe	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 3890001	Rance	Seth	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 3890002	Bruce	Thomas	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 3890003	Curran	Sam	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 3890007	Hemalatha	Dayalan	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3890016	Parida	Sukanya	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3890017	George	Katie	Y	1	Right	Y	2	Left	Pace	Medium	N	2	Female
# 3890018	Smith	Bryony	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3890019	Farrant	Tash	Y	2	Left	Y	2	Left	Pace	Medium	N	2	Female
# 3890025	Ali	Muneeba	Y	2	Left	Y	1	Right	Pace	Medium	N	2	Female
# 3890026	Pervaiz	Natalia	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3890027	Sohail	Omaima	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 3890028	Anwer	Aiman	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 3890029	Searle	Robyn Searle	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3890030	Maritz	Lara	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3890031	Stokell	Rebecca	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3890032	Reddy	Arundhati	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 3960002	van der Dussen	Rassie	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 3980001	Mire	Solomon	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3980004	Chisoro	Tendai	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 3980005	Muzaurabani	Blessing	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3980006	Zaman	Fakhar	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 3980007	Talat	Hussain	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3980008	Ali	Asif	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 3980010	Ashraf	Afaheem	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 3980011	Afridi	Shaheen	Y	2	Left	Y	2	Left	Pace	Fast-Medium	N	1	Male
# 3980016	Murray	Ryan	Y	1	Right	Y	1	Right	Spin	Orthodox	Y	1	Male
# 3980017	Masakadza	Wellington	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 3980018	Mavuta	Brandon	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 3980019	Zhuwao	Cephas	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 3980020	Farhan	Sahibzada	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 4090001	Shah	Naseem	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 4090003	Khan	Musa	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 4090004	Raval	Jeet	Y	2	Left	Y	1	Right	Spin	Wrist	N	1	Male
# 4090005	Jamieson	Kyle Alex	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 4090006	Phillips	Glenn Dominic	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 4090007	van Biljon	Pite Johannes	Y	1	Right	Y	1	Right	Pace	Medium	N	1	Male
# 4090008	Smuts	Jon Jon Trevor	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 4090009	Sipamla	Lubabalo Lutho	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 4090011	Nortje	Anrich	Y	1	Right	Y	1	Right	Pace	Fast	N	1	Male
# 4090012	Malan	Janneman Nieuwoudt	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 4090013	Verreynne	Kyle	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 4090014	Dupavillon	Daryn Niles	Y	1	Right	Y	1	Right	Pace	Fast-Medium	N	1	Male
# 4100001	Hasaranga	Wanindu	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 4100002	Rajapaksa	Bhanuka	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 4100003	Jayasuriya	Shehan	Y	2	Left	Y	1	Right	Spin	Orthodox	N	1	Male
# 4100004	Ahmad	Iftikhar	Y	1	Right	Y	1	Right	Spin	Orthodox	N	1	Male
# 4100005	Shah	Khushdil	Y	2	Left	Y	2	Left	Spin	Orthodox	N	1	Male
# 4350008	Khatun	Murshida	Y	2	Left	Y	1	Right	Pace	Fast-Medium	N	2	Female
# 4350088	Deol	Harleen	Y	1	Right	Y	2	Left	Spin	Wrist	N	2	Female
# 4350089	Verma	Shefali	Y	1	Right	Y	1	Right	Pace	Fast	N	2	Female
# 4380006	Ramharack	Karishma	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 4380007	Gajnabi	Shabika	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 4380008	Grimmond	Sheneta	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 4380022	Mlaba	Nonkululeko	Y	1	Right	Y	1	Right	Spin	Wrist	N	1	Male
# 4380026	Natarajan	Thangarasu	Y	2	Left	Y	2	Left	Pace	Medium	N	1	Male
# 4390057	Fernando	Inoshi	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 4390058	Karunarathna	Hansima	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 4390131	Ghosh	Richa	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 4390259	Kerr	Jessica	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 4390260	Dilhari	Kavisha	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 4390261	Kulasuriya	Achini	Y	2	Left	Y	1	Right	Pace	Medium	N	2	Female
# 4390262	Sandeepani	Sathya	Y	1	Right	Y	1	Right	Spin	Orthodox	N	2	Female
# 4390263	Thimeshani	Umasha	Y	1	Right	Y	1	Right	Spin	Wrist	N	2	Female
# 4390269	Ghosh	Panna	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 4390270	Mostary	Sobhana	Y	1	Right	Y	1	Right	Pace	Medium	N	2	Female
# 4850002	Conway	Devon Phillip	Y	2	Left	Y	1	Right	Pace	Medium	N	1	Male
# 4920001	Halliday	Brooke	Y	2	Left	Y	1	Right	Pace	Medium	N	2	Female
# 4920006	Jonas	Fran	Y	1	Right	Y	2	Left	Spin	Orthodox	N	2	Female

# %%
import pandas as pd

# Converting the above cricket dataset into CSV format.
# Note that the delimiter (as observed in .txt file) is a "tabspace" or a "\t".
cricketDF = pd.read_csv(r'./datasets/Cricket-Players.txt', delimiter = '\t')
cricketDF.to_csv(r'./datasets/Cricket-Players.csv', index = None)

# clean up a couple of poorly named columns, like we did earlier
cricketDF.columns = [x.strip() for x in cricketDF.columns]

cricketDF = cricketDF.rename(columns = {'Player Other Names': 'Player First Name'})

cricketDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1612 entries, 0 to 1611
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Player Id          1612 non-null   int64
#  1   Player Surname     1612 non-null   object
#  2   Player First Name  1611 non-null   object
#  3   Is Batter          1612 non-null   object
#  4   Batter Hand Id     1612 non-null   int64
#  5   Batter Hand        1612 non-null   object
#  6   Is Bowler          1612 non-null   object
#  7   Bowler Hand Id     1612 non-null   int64
#  8   Bowler Hand        1612 non-null   object
#  9   Pace/Spin          1612 non-null   object
#  10  Bowler Style       1612 non-null   object
#  11  Is Keeper          1612 non-null   object
#  12  Gender Id          1612 non-null   int64
#  13  Gender             1612 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 176.4+ KB

# %%
# cricketDF is now a DataFrame
cricketDF.head()
# Out:
#    Player Id Player Surname Player First Name Is Batter  Batter Hand Id  \
# 0          5         Razzaq             Abdul         Y               1
# 1         11        Mahmood             Azhar         Y               1
# 2         16           Raza             Hasan         Y               1
# 3         17            Ali            Ghulam         Y               1
# 4         18          Ahmad              Ijaz         Y               1
#
#   Batter Hand Is Bowler  Bowler Hand Id Bowler Hand Pace/Spin Bowler Style  \
# 0       Right         Y               1       Right      Pace       Medium
# 1       Right         Y               1       Right      Pace  Fast-Medium
# 2       Right         Y               1       Right      Pace       Medium
# 3       Right         Y               1       Right      Pace       Medium
# 4       Right         Y               1       Right      Pace       Medium
#
#   Is Keeper  Gender Id Gender
# 0         N          1   Male
# 1         N          1   Male
# 2         N          1   Male
# 3         N          1   Male
# 4         N          1   Male

# %% [markdown]
# ****
# Boolean masks are created by applying operators directly to the pandas Series or DataFrame objects. For instance, in order to broadcast the cricketers whose bowler-style is "Medium" :

# %%
bowStyMask = cricketDF['Bowler Style'] == 'Medium'
bowStyMask

# so here, we'll project the bowler styler column using the indexing operator and apply equality operator, ==, with a value of 'Medium'.
# This is essentially broadcasting a comparison operator, i.e. ==, with the results being returned as Boolean Series. The resultant Series is indexed where the value of each cell is either True or False.
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 1607     True
# 1608     True
# 1609     True
# 1610     True
# 1611    False
# Name: Bowler Style, Length: 1612, dtype: bool

# %% [markdown]
# The result of broadcasting a comparison operator is a Boolean mask - true or false depending upon the results of comparison.
# Underneath, pandas is applying the comparison operator through vectorisation (so efficiently and in-parallel) to all of the values in the array. The result is a Series, since only one column is being operated on, filled with either True or False values.
#
# Now after forming the boolean mask, you can lay it on top of the data to "hide" the data that is not needed ie. values represented by all of the False values.<br>This is done by using .where( ) function on the original DataFrame.

# %%
cricketDF.where(bowStyMask).head(10)

# Notice in below resulting dataframe, it keeps the original indexed values. Only data which met the condition was retained.
# While all of the rows which  fail the condition have NaN data instead, but such rows were not dropped from the dataframe.
# Out:
#    Player Id Player Surname Player First Name Is Batter  Batter Hand Id Batter Hand  ... Bowler Hand  Pace/Spin Bowler Style Is Keeper Gender Id Gender
# 0        5.0         Razzaq             Abdul         Y             1.0       Right  ...       Right       Pace       Medium         N       1.0   Male
# 1        NaN            NaN               NaN       NaN             NaN         NaN  ...         NaN        NaN          NaN       NaN       NaN    NaN
# 2       16.0           Raza             Hasan         Y             1.0       Right  ...       Right       Pace       Medium         N       1.0   Male
# 3       17.0            Ali            Ghulam         Y             1.0       Right  ...       Right       Pace       Medium         N       1.0   Male
# 4       18.0          Ahmad              Ijaz         Y             1.0       Right  ...       Right       Pace       Medium         N       1.0   Male
# 5       20.0        Blewett              Greg         Y             1.0       Right  ...       Right       Pace       Medium         N       1.0   Male
# 6        NaN            NaN               NaN       NaN             NaN         NaN  ...         NaN        NaN          NaN       NaN       NaN    NaN
# 7        NaN            NaN               NaN       NaN             NaN         NaN  ...         NaN        NaN          NaN       NaN       NaN    NaN
# 8       23.0           Dale              Adam         Y             2.0        Left  ...       Right       Pace       Medium         N       1.0   Male
# 9        NaN            NaN               NaN       NaN             NaN         NaN  ...         NaN        NaN          NaN       NaN       NaN    NaN
#
# [10 rows x 14 columns]

# %%
# the next step is, if we don't want the NaN data we use dropna() function to drop such rows.
# 
# you'll notice row #1, #6, #7, #9, and so on gets dropped.

cricketDF.where(bowStyMask).dropna().head(10)
# Out:
#     Player Id Player Surname Player First Name Is Batter  Batter Hand Id Batter Hand  ... Bowler Hand  Pace/Spin Bowler Style Is Keeper Gender Id Gender
# 0         5.0         Razzaq             Abdul         Y             1.0       Right  ...       Right       Pace       Medium         N       1.0   Male
# 2        16.0           Raza             Hasan         Y             1.0       Right  ...       Right       Pace       Medium         N       1.0   Male
# 3        17.0            Ali            Ghulam         Y             1.0       Right  ...       Right       Pace       Medium         N       1.0   Male
# 4        18.0          Ahmad              Ijaz         Y             1.0       Right  ...       Right       Pace       Medium         N       1.0   Male
# 5        20.0        Blewett              Greg         Y             1.0       Right  ...       Right       Pace       Medium         N       1.0   Male
# 8        23.0           Dale              Adam         Y             2.0        Left  ...       Right       Pace       Medium         N       1.0   Male
# 11       27.0      Gilchrist              Adam         Y             2.0        Left  ...        Left       Pace       Medium         N       1.0   Male
# 13       29.0         Harvey               Ian         Y             1.0       Right  ...       Right       Pace       Medium         N       1.0   Male
# 14       30.0         Hayden           Matthew         Y             2.0        Left  ...       Right       Pace       Medium         N       1.0   Male
# 15       31.0          Healy               Ian         Y             1.0       Right  ...       Right       Pace       Medium         Y       1.0   Male
#
# [10 rows x 14 columns]

# %% [markdown]
# **Notice that index row does not include 1, 6, 7 and so on...**<br><br>
# Well, this where( ) fucntion is not used often. Instead, an another shorthand syntax to carry out similar activity, which combines where( ) and dropna( ), is :

# %%
cricketDF[cricketDF['Bowler Style'] == 'Medium'].head(10)
# Out:
#     Player Id Player Surname Player First Name Is Batter  Batter Hand Id Batter Hand  ... Bowler Hand  Pace/Spin Bowler Style Is Keeper Gender Id Gender
# 0           5         Razzaq             Abdul         Y               1       Right  ...       Right       Pace       Medium         N         1   Male
# 2          16           Raza             Hasan         Y               1       Right  ...       Right       Pace       Medium         N         1   Male
# 3          17            Ali            Ghulam         Y               1       Right  ...       Right       Pace       Medium         N         1   Male
# 4          18          Ahmad              Ijaz         Y               1       Right  ...       Right       Pace       Medium         N         1   Male
# 5          20        Blewett              Greg         Y               1       Right  ...       Right       Pace       Medium         N         1   Male
# 8          23           Dale              Adam         Y               2        Left  ...       Right       Pace       Medium         N         1   Male
# 11         27      Gilchrist              Adam         Y               2        Left  ...        Left       Pace       Medium         N         1   Male
# 13         29         Harvey               Ian         Y               1       Right  ...       Right       Pace       Medium         N         1   Male
# 14         30         Hayden           Matthew         Y               2        Left  ...       Right       Pace       Medium         N         1   Male
# 15         31          Healy               Ian         Y               1       Right  ...       Right       Pace       Medium         Y         1   Male
#
# [10 rows x 14 columns]

# %% [markdown]
# Let's review this indexing operator on DataFrame, it now does 2 things:
#
# I. Can be called with a string parameter to project a single column

# %%
cricketDF['Player Surname'].head()
# Out:
# 0     Razzaq
# 1    Mahmood
# 2       Raza
# 3        Ali
# 4      Ahmad
# Name: Player Surname, dtype: object

# %%
# Or, can be called with a list of columns as strings

cricketDF[["Player Surname", "Bowler Style"]].head()
# Out:
#   Player Surname Bowler Style
# 0         Razzaq       Medium
# 1        Mahmood  Fast-Medium
# 2           Raza       Medium
# 3            Ali       Medium
# 4          Ahmad       Medium

# %% [markdown]
# II. Can be called with a boolean mask

# %%
cricketDF[cricketDF["Batter Hand"] == "Right"].head(10)
# Out:
#     Player Id Player Surname Player First Name Is Batter  Batter Hand Id Batter Hand  ... Bowler Hand  Pace/Spin Bowler Style Is Keeper Gender Id Gender
# 0           5         Razzaq             Abdul         Y               1       Right  ...       Right       Pace       Medium         N         1   Male
# 1          11        Mahmood             Azhar         Y               1       Right  ...       Right       Pace  Fast-Medium         N         1   Male
# 2          16           Raza             Hasan         Y               1       Right  ...       Right       Pace       Medium         N         1   Male
# 3          17            Ali            Ghulam         Y               1       Right  ...       Right       Pace       Medium         N         1   Male
# 4          18          Ahmad              Ijaz         Y               1       Right  ...       Right       Pace       Medium         N         1   Male
# 5          20        Blewett              Greg         Y               1       Right  ...       Right       Pace       Medium         N         1   Male
# 6          21         Bichel            Andrew         Y               1       Right  ...       Right       Pace  Fast-Medium         N         1   Male
# 10         26        Fleming            Damien         Y               1       Right  ...       Right       Pace  Fast-Medium         N         1   Male
# 12         28        Unknown               NaN         Y               1       Right  ...       Right       Pace  Fast-Medium         N         1   Male
# 13         29         Harvey               Ian         Y               1       Right  ...       Right       Pace       Medium         N         1   Male
#
# [10 rows x 14 columns]

# %% [markdown]
# And, each of these is mimicing functionality from either `.loc( )` or `.where( ).dropna( )`

# %% [markdown]
# ****
# ### Viewing and Selecting data
#
# #### 1. `.describe()`
#
# `.describe()` method operates on a dataframe.<br>It returns certain statistical info about a dataframe, but it includes columns of numeric datatype only.

# %%
pokemonDF = pd.read_csv('./datasets/pokemon.csv')        # reading dataset of pokemons

pokemonDF.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
pokemonDF.index   # ".index" attribute shows that dataframe has 800 pokemons in total, with index starting from 0.
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
pokemonDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
pokemonDF.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
pokemonDF.mean()     # calculates and display mean of every column
# Out:
# /Users/barmanr/.pyenv/versions/3.7.8/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# #             400.50000
# HP             69.25875
# Attack         79.00125
# Defense        73.84250
# Sp. Atk        72.82000
# Sp. Def        71.90250
# Speed          68.27750
# Generation      3.32375
# Legendary       0.08125
# dtype: float64

# %% [markdown]
# #### 2. `.head()`
# It displays the top 5 rows/data of a dataframe. Alternately, if passed an integer argument, it'll display that many rows.

# %%
pokemonDF.head()      # top 5 rows of data
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
pokemonDF.head(8)     # top 8 rows of data
# Out:
#    #              Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1         Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2           Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3          Venusaur  Grass  Poison  80      82       83      100      100
# 3  4     Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5        Charmander   Fire     NaN  39      52       43       60       50
# 5  6        Charmeleon   Fire     NaN  58      64       58       80       65
# 6  7         Charizard   Fire  Flying  78      84       78      109       85
# 7  8  Mega Charizard X   Fire  Dragon  78     130      111      130       85
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False
# 5     80           1      False
# 6    100           1      False
# 7    100           1      False

# %% [markdown]
# #### 3. `.tail()`
# It displays the bottom 5 rows/data.

# %%
pokemonDF.tail(8)      # bottom 8 rows, if an int argument is specified
# Out:
#        #                Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 792  793             Xerneas    Fairy     NaN  126     131       95      131
# 793  794             Yveltal     Dark  Flying  126     131       95      131
# 794  795  Zygarde Half Forme   Dragon  Ground  108     100      121       81
# 795  796             Diancie     Rock   Fairy   50     100      150      100
# 796  797        Mega Diancie     Rock   Fairy   50     160      110      160
# 797  798      Hoopa Confined  Psychic   Ghost   80     110       60      150
# 798  799       Hoopa Unbound  Psychic    Dark   80     160       60      170
# 799  800           Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 792       98     99           6       True
# 793       98     99           6       True
# 794       95     95           6       True
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# #### 4. `pd.crosstab()`

# %%
pd.crosstab(pokemonDF["Name"], pokemonDF["Type 1"]).head()
# Out:
# Type 1                 Bug  Dark  Dragon  Electric  Fairy  Fighting  Fire  \
# Name
# Abomasnow                0     0       0         0      0         0     0
# Abra                     0     0       0         0      0         0     0
# Absol                    0     1       0         0      0         0     0
# Accelgor                 1     0       0         0      0         0     0
# Aegislash Blade Forme    0     0       0         0      0         0     0
#
# Type 1                 Flying  Ghost  Grass  Ground  Ice  Normal  Poison  \
# Name
# Abomasnow                   0      0      1       0    0       0       0
# Abra                        0      0      0       0    0       0       0
# Absol                       0      0      0       0    0       0       0
# Accelgor                    0      0      0       0    0       0       0
# Aegislash Blade Forme       0      0      0       0    0       0       0
#
# Type 1                 Psychic  Rock  Steel  Water
# Name
# Abomasnow                    0     0      0      0
# Abra                         1     0      0      0
# Absol                        0     0      0      0
# Accelgor                     0     0      0      0
# Aegislash Blade Forme        0     0      1      0

# %% [markdown]
# #### 5. `.groupby()`

# %%
pokemonDF.groupby(["Name"]).mean()
# Out:
#                            #     HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Abomasnow              511.0   90.0    92.0     75.0     92.0     85.0   60.0
# Abra                    69.0   25.0    20.0     15.0    105.0     55.0   90.0
# Absol                  393.0   65.0   130.0     60.0     75.0     60.0   75.0
# Accelgor               679.0   80.0    70.0     40.0    100.0     60.0  145.0
# Aegislash Blade Forme  751.0   60.0   150.0     50.0    150.0     50.0   60.0
# ...                      ...    ...     ...      ...      ...      ...    ...
# Zoroark                633.0   60.0   105.0     60.0    120.0     60.0  105.0
# Zorua                  632.0   40.0    65.0     40.0     80.0     40.0   65.0
# Zubat                   47.0   40.0    45.0     35.0     30.0     40.0   55.0
# Zweilous               696.0   72.0    85.0     70.0     65.0     70.0   58.0
# Zygarde Half Forme     795.0  108.0   100.0    121.0     81.0     95.0   95.0
#
#                        Generation  Legendary
# Name
# Abomasnow                     4.0        0.0
# Abra                          1.0        0.0
# Absol                         3.0        0.0
# Accelgor                      5.0        0.0
# Aegislash Blade Forme         6.0        0.0
# ...                           ...        ...
# Zoroark                       5.0        0.0
# Zorua                         5.0        0.0
# Zubat                         1.0        0.0
# Zweilous                      5.0        0.0
# Zygarde Half Forme            6.0        1.0
#
# [799 rows x 9 columns]

# %% [markdown]
# #### 6. `.plot()` and `.hist()`

# %%
pokemonDF["Attack"].plot()
# Out:
# <AxesSubplot:>

# %%
pokemonDF["Attack"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ****
# ## Selecting out a "random" sample from a dataframe
#
# You may neeed to select a random(means, shuffled) sample from the dataset (referred as Sampling).<br>This practice is followed/adopted during segregating a dataset in terms of train dataset, validation dataset, test dataset.
#
# > if `frac=0.4` => only 40% dataset will firstly be randomly selected/sampled and then shuffling will perform.
#
# > if `frac=1` => complete datset will be shuffled.

# %%
pokemonDF.sample(frac=0.4)    # that's why only 320 rows, i.e. 40% of 800 rows, are being worked upon and displayed here.
# Out:
#        #            Name   Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 132  133         Scyther      Bug    Flying   70     110       80       55
# 575  576        Simipour    Water       NaN   75      98       63       98
# 668  669         Litwick    Ghost      Fire   50      30       55       65
# 217  218       Wobbuffet  Psychic       NaN  190      33       58       33
# 409  410  Mega Salamence   Dragon    Flying   95     145      130      120
# ..   ...             ...      ...       ...  ...     ...      ...      ...
# 131  132        Mr. Mime  Psychic     Fairy   40      45       65      100
# 657  658      Galvantula      Bug  Electric   70      77       60       97
# 113  114         Marowak   Ground       NaN   60      80      110       50
# 626  627      Carracosta    Water      Rock   74     108      133       83
# 96    97             Muk   Poison       NaN  105     105       75       65
#
#      Sp. Def  Speed  Generation  Legendary
# 132       80    105           1      False
# 575       63    101           5      False
# 668       55     20           5      False
# 217       58     33           2      False
# 409       90    120           3      False
# ..       ...    ...         ...        ...
# 131      120     90           1      False
# 657       60    108           5      False
# 113       80     45           1      False
# 626       65     32           5      False
# 96       100     50           1      False
#
# [320 rows x 12 columns]

# %% [markdown]
# ****
# ### Combining multiple boolean masks in Pandas
#
# Generally in bit masking, in other areas of computer science, this is done with "and" (if both masks must be True), or "or" (if only one needs to be True).

# %%
(cricketDF['Batter Hand'] == "Right") and (cricketDF['Is Keeper'] == 'Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-a9864f8b1c51> in <module>
# ----> 1 (cricketDF['Batter Hand'] == "Right") and (cricketDF['Is Keeper'] == 'Y')
#
# ~/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1533     def __nonzero__(self):
#    1534         raise ValueError(
# -> 1535             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1536             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1537         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# Actually, this doesn't work in Pandas because python underneath does not know how to compare two series using 'and' or 'or' operator.
#
# So in Pandas, pipe ( | ) and ampersand ( & ) operators are used to combine multiple boolean-mask operations:
#
# | : OR operation
#
# & : AND operation
#
# **Note:** *wrap individual terms (that are performing boolean-mask operations) inside parenthesis.*

# %%
batAndKeep = (cricketDF['Batter Hand'] == "Right") & (cricketDF['Is Keeper'] == 'Y')

# for instance, cricketers who are a keeper as well as a batsman

# %%
cricketDF[batAndKeep]

# so there are 99 such cricketers
# Out:
#       Player Id Player Surname Player First Name Is Batter  Batter Hand Id Batter Hand  ... Bowler Hand  Pace/Spin Bowler Style Is Keeper Gender Id  Gender
# 15           31          Healy               Ian         Y               1       Right  ...       Right       Pace       Medium         Y         1    Male
# 101         237         Mashud            Khaled         Y               1       Right  ...       Right       Pace       Medium         Y         1    Male
# 125         287        Boucher              Mark         Y               1       Right  ...       Right       Pace       Medium         Y         1    Male
# 138         306        Dilshan      Tillakaratne         Y               1       Right  ...       Right       Spin     Orthodox         Y         1    Male
# 191         397         Browne          Courtney         Y               1       Right  ...       Right       Pace       Medium         Y         1    Male
# ...         ...            ...               ...       ...             ...         ...  ...         ...        ...          ...       ...       ...     ...
# 1486    3470008          Boyce           Reniece         Y               1       Right  ...       Right       Pace       Medium         Y         2  Female
# 1516    3760011        Klaasen           Henrich         Y               1       Right  ...       Right       Pace       Medium         Y         1    Male
# 1531    3760048           Hope        Shai Diego         Y               1       Right  ...       Right       Spin     Orthodox         Y         1    Male
# 1540    3760076            Das             Liton         Y               1       Right  ...       Right       Spin     Orthodox         Y         1    Male
# 1569    3980016         Murray              Ryan         Y               1       Right  ...       Right       Spin     Orthodox         Y         1    Male
#
# [99 rows x 14 columns]

# %% [markdown]
# ****
# ### Indexing DataFrames
#
# Both Series and DataFrames, can have indices applied to them. The index is essentially a row level label.
#
# In pandas the rows correspond to axis zero.
#
# Indices can either be autogenerated, such as when creating a new Series without an index, in which case we get numeric values, or they can be set explicitly, like when we use dictionary object to create the Series, or when we load data from CSV file and set appropriate parameters.
#
# Another approach to use **set_index( )** function.<br>This function takes a list of columns and promotes those columns to an index.<br>
# The set_index( ) function is a destructive process, and it does not keep the current index.<br>If you want to keep the current index, you need to create a new column and copy into it values from the index attribute.

# %%
# firstly, importing pandas and the dataset.
# and, assigning "Player Id" as the indexing column
import pandas as pd
cricketDF = pd.read_csv('./datasets/Cricket-Players.csv', index_col=0)
cricketDF.head()
# Out:
#           Player Surname Player Other Names Is Batter  Batter Hand Id Batter Hand Is Bowler  ...  Bowler Hand Pace/Spin Bowler Style Is Keeper Gender Id  Gender
# Player Id                                                                                    ...
# 5                 Razzaq              Abdul         Y               1       Right         Y  ...        Right      Pace       Medium         N         1    Male
# 11               Mahmood              Azhar         Y               1       Right         Y  ...        Right      Pace  Fast-Medium         N         1    Male
# 16                  Raza              Hasan         Y               1       Right         Y  ...        Right      Pace       Medium         N         1    Male
# 17                   Ali             Ghulam         Y               1       Right         Y  ...        Right      Pace       Medium         N         1    Male
# 18                 Ahmad               Ijaz         Y               1       Right         Y  ...        Right      Pace       Medium         N         1    Male
#
# [5 rows x 13 columns]

# %% [markdown]
# Let's index the dataframe by "Player Other Names". So preserve the  "Player Id" into new column.<br>
# This can be done by using the indexing operator on the string that has the column label.
#
# Then, use set_index( ) to set index of the column to chance of admit.

# %%
# copy the indexed data into its own column
cricketDF['Player Id'] = cricketDF.index

# set index index to another column
cricketDF = cricketDF.set_index('Player Other Names')

cricketDF.head()
# Out:
#                    Player Surname Is Batter  Batter Hand Id Batter Hand Is Bowler  ...  Bowler Style Is Keeper Gender Id Gender Player Id
# Player Other Names                                                                 ...
# Abdul                      Razzaq         Y               1       Right         Y  ...        Medium         N         1   Male         5
# Azhar                     Mahmood         Y               1       Right         Y  ...   Fast-Medium         N         1   Male        11
# Hasan                        Raza         Y               1       Right         Y  ...        Medium         N         1   Male        16
# Ghulam                        Ali         Y               1       Right         Y  ...        Medium         N         1   Male        17
# Ijaz                        Ahmad         Y               1       Right         Y  ...        Medium         N         1   Male        18
#
# [5 rows x 13 columns]

# %% [markdown]
# Notice above that, the new index created from an existing column bears a name (the original name of the column itself).
#
# In turn, you can get rid of the index completely (and return to original indexing state) by calling fucntion reset_index( ). This promotes the index into a column and creates a default numbered index.

# %%
cricketDF = cricketDF.reset_index()
cricketDF.head()
# Out:
#   Player Other Names Player Surname Is Batter  Batter Hand Id Batter Hand Is Bowler  ...  Pace/Spin Bowler Style Is Keeper Gender Id Gender  Player Id
# 0              Abdul         Razzaq         Y               1       Right         Y  ...       Pace       Medium         N         1   Male          5
# 1              Azhar        Mahmood         Y               1       Right         Y  ...       Pace  Fast-Medium         N         1   Male         11
# 2              Hasan           Raza         Y               1       Right         Y  ...       Pace       Medium         N         1   Male         16
# 3             Ghulam            Ali         Y               1       Right         Y  ...       Pace       Medium         N         1   Male         17
# 4               Ijaz          Ahmad         Y               1       Right         Y  ...       Pace       Medium         N         1   Male         18
#
# [5 rows x 14 columns]

# %% [markdown]
# #### Multi-level indexing of DataFrames
#
# Pandas also feature multi-level indexing. This is similar to composite keys in relational database systems.
#
# To create a multi-level index, simply call set_index( ) and pass it a list of columns that are interested for promoting to an index.

# %%
cricketDF = cricketDF.set_index(['Batter Hand', 'Bowler Style'])
cricketDF
# Out:
#                          Player Other Names Player Surname Is Batter  Batter Hand Id Is Bowler  ...  Pace/Spin Is Keeper Gender Id  Gender  Player Id
# Batter Hand Bowler Style                                                                        ...
# Right       Medium                    Abdul         Razzaq         Y               1         Y  ...       Pace         N         1    Male          5
#             Fast-Medium               Azhar        Mahmood         Y               1         Y  ...       Pace         N         1    Male         11
#             Medium                    Hasan           Raza         Y               1         Y  ...       Pace         N         1    Male         16
#             Medium                   Ghulam            Ali         Y               1         Y  ...       Pace         N         1    Male         17
#             Medium                     Ijaz          Ahmad         Y               1         Y  ...       Pace         N         1    Male         18
# ...                                     ...            ...       ...             ...       ...  ...        ...       ...       ...     ...        ...
#             Medium                    Panna          Ghosh         Y               1         Y  ...       Pace         N         2  Female    4390269
#             Medium                  Sobhana        Mostary         Y               1         Y  ...       Pace         N         2  Female    4390270
# Left        Medium            Devon Phillip         Conway         Y               2         Y  ...       Pace         N         1    Male    4850002
#             Medium                   Brooke       Halliday         Y               2         Y  ...       Pace         N         2  Female    4920001
# Right       Orthodox                   Fran          Jonas         Y               1         Y  ...       Spin         N         2  Female    4920006
#
# [1612 rows x 12 columns]

# %% [markdown]
# Well now the question arises as to how to query a multi-indeed dataframe?
#
# As the loc attribute o the dataframe can take multiple arguments. And it could query both the row and the columns. So, when using a multi-index we must provide the arguments in order by the level we wsh to query.
#
# Inside of the index, each column is called a level and the outermost column is level zero.

# %%
cricketDF.loc['Right', 'Medium']
# Out:
# /Users/barmanr/.pyenv/versions/3.7.8/lib/python3.7/site-packages/ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
#                          Player Other Names Player Surname Is Batter  Batter Hand Id Is Bowler  ...  Pace/Spin Is Keeper Gender Id  Gender  Player Id
# Batter Hand Bowler Style                                                                        ...
# Right       Medium                    Abdul         Razzaq         Y               1         Y  ...       Pace         N         1    Male          5
#             Medium                    Hasan           Raza         Y               1         Y  ...       Pace         N         1    Male         16
#             Medium                   Ghulam            Ali         Y               1         Y  ...       Pace         N         1    Male         17
#             Medium                     Ijaz          Ahmad         Y               1         Y  ...       Pace         N         1    Male         18
#             Medium                     Greg        Blewett         Y               1         Y  ...       Pace         N         1    Male         20
# ...                                     ...            ...       ...             ...       ...  ...        ...       ...       ...     ...        ...
#             Medium                  Hansima   Karunarathna         Y               1         Y  ...       Pace         N         2  Female    4390058
#             Medium                    Richa          Ghosh         Y               1         Y  ...       Pace         N         2  Female    4390131
#             Medium                  Jessica           Kerr         Y               1         Y  ...       Pace         N         2  Female    4390259
#             Medium                    Panna          Ghosh         Y               1         Y  ...       Pace         N         2  Female    4390269
#             Medium                  Sobhana        Mostary         Y               1         Y  ...       Pace         N         2  Female    4390270
#
# [505 rows x 12 columns]

# %% [markdown]
# Above result is exactly same as the result that would have been generated when the **un-indexed** "cricketDF" dataframe must have been queried on the condition like :<br>`cricketDF[(cricketDF['Batter Hand']) == 'Right' & (cricketDF['Bowler Style'] == 'Medium')]`
#
# This would too return a 505 x 12 dataframe

# %%
# Compare 2 kinds of Bowler Styles - Orthodox & Fast-Medium, typically who are right-handed batsmen.

# In this case, a list of tuples is passed into loc. Each tuple should have 2 elements,
# the first value corresponds to first index and the second element corresponds to second index.
cricketDF.loc[ [('Right', 'Orthodox'), ('Right', 'Fast-Medium')] ]
# Out:
#                          Player Other Names Player Surname Is Batter  Batter Hand Id Is Bowler  ...  Pace/Spin Is Keeper Gender Id Gender  Player Id
# Batter Hand Bowler Style                                                                        ...
# Right       Orthodox                Saqlain        Mushtaq         Y               1         Y  ...       Spin         N         1   Male         56
#             Orthodox                  Colin         Miller         Y               1         Y  ...       Spin         N         1   Male         76
#             Orthodox                  Ricky        Ponting         Y               1         Y  ...       Spin         N         1   Male         82
#             Orthodox                 Ashley          Giles         Y               1         Y  ...       Spin         N         1   Male        125
#             Orthodox                Muttiah    Muralidaran         Y               1         Y  ...       Spin         N         1   Male        137
# ...                                     ...            ...       ...             ...       ...  ...        ...       ...       ...    ...        ...
#             Fast-Medium              Naseem           Shah         Y               1         Y  ...       Pace         N         1   Male    4090001
#             Fast-Medium                Musa           Khan         Y               1         Y  ...       Pace         N         1   Male    4090003
#             Fast-Medium           Kyle Alex       Jamieson         Y               1         Y  ...       Pace         N         1   Male    4090005
#             Fast-Medium      Lubabalo Lutho        Sipamla         Y               1         Y  ...       Pace         N         1   Male    4090009
#             Fast-Medium         Daryn Niles     Dupavillon         Y               1         Y  ...       Pace         N         1   Male    4090014
#
# [560 rows x 12 columns]

# %% [markdown]
# ****
# ### Dealing with Missing Values in DataFrames
#
# Earlier we saw a preview of how Pandas handles missing values using the None type and Numpy NaN values. Missing values are pretty common in data cleaning tasks.
#
# For instance, if you're running a survey and a respondent didn't answer a question, the missing value is actually an omission. This kind of missing data is called **Missing at Random** if there are other variables that might be used to predict the variable which is missing.<br>
# Often it's found that, missing data (for eg, interest in being involved in a research study), has some correlation with other data like gender or ethnicity. If there's no relationship to other variables, then we call this data **Missing Completely at Random**.
#
# Pandas is pretty good at detecting missing values directly from underlying data formats like CSV files. Although most missing values are often formatted as NaN, NULL, None, or N/A, sometimes missing values are not labeled so clearly. For example, social scientists often use the value of 99 in binary categories to indicate that it's a missing value.
#
# The Pandas read_csv( ) function has a parameter called na_values that allows us to specify the format of missing values. It allows scalar string lists or dictionaries to be used.

# %%
import pandas as pd
# let's create a dummy dataframe, consisting of student's marks in different categories

marks = pd.DataFrame({'Student Name': ['Arman','Akshat','Tanya','Neha','Jason','Vishrut','Rishabh','Prachi','Pradeep','Sakshi'],
                      'Assignment': [57.14,95.05,83.70,float('nan'),91.32,95.00,72.8,84.0,90.14, 92.55],
                      'Tutorial': [34.09,105.49,83.17,float('nan'),93.64,92.62,108.4,float('nan'),93.0,97.5],
                      'Midterm': [64.38,67.50,float('nan'),49.38,95.00,93.12,56.25,60.0,47.5,51.25],
                      'Finals': [52.5,68.33,48.6,80.45,73.89,80.56,73.89,68.06,float('nan'),56.11]
                     })
marks
# Out:
#   Student Name  Assignment  Tutorial  Midterm  Finals
# 0        Arman       57.14     34.09    64.38   52.50
# 1       Akshat       95.05    105.49    67.50   68.33
# 2        Tanya       83.70     83.17      NaN   48.60
# 3         Neha         NaN       NaN    49.38   80.45
# 4        Jason       91.32     93.64    95.00   73.89
# 5      Vishrut       95.00     92.62    93.12   80.56
# 6      Rishabh       72.80    108.40    56.25   73.89
# 7       Prachi       84.00       NaN    60.00   68.06
# 8      Pradeep       90.14     93.00    47.50     NaN
# 9       Sakshi       92.55     97.50    51.25   56.11

# %% [markdown]
# - Use the function .isnull( ) to create a boolean mask of the whole dataframe (places "True" at those places where an NaN is found).<br>This effectively broadcasts the isnull( ) to every cell of data.

# %%
marks.isnull()
# notice that indexes #2, #3, etc. shows True because it contains a NaN value.
# Out:
#    Student Name  Assignment  Tutorial  Midterm  Finals
# 0         False       False     False    False   False
# 1         False       False     False    False   False
# 2         False       False     False     True   False
# 3         False        True      True    False   False
# 4         False       False     False    False   False
# 5         False       False     False    False   False
# 6         False       False     False    False   False
# 7         False       False      True    False   False
# 8         False       False     False    False    True
# 9         False       False     False    False   False

# %% [markdown]
# - Use .fillna( ) function to fill all the missing values with 0

# %%
marks.fillna(0)
# Out:
#   Student Name  Assignment  Tutorial  Midterm  Finals
# 0        Arman       57.14     34.09    64.38   52.50
# 1       Akshat       95.05    105.49    67.50   68.33
# 2        Tanya       83.70     83.17     0.00   48.60
# 3         Neha        0.00      0.00    49.38   80.45
# 4        Jason       91.32     93.64    95.00   73.89
# 5      Vishrut       95.00     92.62    93.12   80.56
# 6      Rishabh       72.80    108.40    56.25   73.89
# 7       Prachi       84.00      0.00    60.00   68.06
# 8      Pradeep       90.14     93.00    47.50    0.00
# 9       Sakshi       92.55     97.50    51.25   56.11

# %% [markdown]
# - Use function .dropna( ) which drops any rows with missing data (ie. has values like NaN, null, etc.)

# %%
marks.dropna(inplace=True)

# the attribute, inplace=True , will not return a copy of "marks" dataframe. Instead, it would modifies the value.

marks   # so, indexes #2, #3, #7, #8 are finally dropped
# Out:
#   Student Name  Assignment  Tutorial  Midterm  Finals
# 0        Arman       57.14     34.09    64.38   52.50
# 1       Akshat       95.05    105.49    67.50   68.33
# 4        Jason       91.32     93.64    95.00   73.89
# 5      Vishrut       95.00     92.62    93.12   80.56
# 6      Rishabh       72.80    108.40    56.25   73.89
# 9       Sakshi       92.55     97.50    51.25   56.11

# %% [markdown]
# ****

# %% [markdown]
# ## Example: Manipulating DataFrame

# %%
import pandas as pd

# loading the US Presidents dataset
presidents = pd.read_csv('./datasets/presidents.csv')

# cleaning up the columns off of whitespaces
cols = presidents.columns
presidents.columns = [x.strip() for x in cols]

presidents.head()
# Out:
#    Presidency          President                                 Wikipedia Entry  ...              Portrait                  Thumbnail     Home State
# 0           1  George Washington  http://en.wikipedia.org/wiki/George_Washington  ...  GeorgeWashington.jpg  thmb_GeorgeWashington.jpg       Virginia
# 1           2         John Adams         http://en.wikipedia.org/wiki/John_Adams  ...         JohnAdams.jpg         thmb_JohnAdams.jpg  Massachusetts
# 2           3   Thomas Jefferson   http://en.wikipedia.org/wiki/Thomas_Jefferson  ...   Thomasjefferson.gif   thmb_Thomasjefferson.gif       Virginia
# 3           4      James Madison      http://en.wikipedia.org/wiki/James_Madison  ...      JamesMadison.gif      thmb_JamesMadison.gif       Virginia
# 4           5       James Monroe       http://en.wikipedia.org/wiki/James_Monroe  ...       JamesMonroe.gif       thmb_JamesMonroe.gif       Virginia
#
# [5 rows x 9 columns]

# %% [markdown]
# ### Use of .apply( ) function
# Let's seperate "President" column into "First Name" and "Last Name".<br>*One of a solution is below...*

# %%
# the .apply() function on a dataframe will take some arbitrary function and apply it to either a Series (a single column) or DataFrame across all rows or columns.
# here, let's write a function that splits a string into 2 pieces using a single row of data

def splitname(row):
    # "row" is a single Series object which is a single row indexed by column values
    row['First Name'] = row["President"].split(" ")[0]
    row['Last Name'] = row["President"].split(" ")[-1]
    return row

presidents = presidents.apply(splitname, axis='columns')
presidents.head()
# Out:
#    Presidency          President                                 Wikipedia Entry Took office  ...                  Thumbnail     Home State First Name   Last Name
# 0           1  George Washington  http://en.wikipedia.org/wiki/George_Washington  30/04/1789  ...  thmb_GeorgeWashington.jpg       Virginia     George  Washington
# 1           2         John Adams         http://en.wikipedia.org/wiki/John_Adams   4/03/1797  ...         thmb_JohnAdams.jpg  Massachusetts       John       Adams
# 2           3   Thomas Jefferson   http://en.wikipedia.org/wiki/Thomas_Jefferson   4/03/1801  ...   thmb_Thomasjefferson.gif       Virginia     Thomas   Jefferson
# 3           4      James Madison      http://en.wikipedia.org/wiki/James_Madison   4/03/1809  ...      thmb_JamesMadison.gif       Virginia      James     Madison
# 4           5       James Monroe       http://en.wikipedia.org/wiki/James_Monroe   4/03/1817  ...       thmb_JamesMonroe.gif       Virginia      James      Monroe
#
# [5 rows x 11 columns]

# %%
del(presidents['First Name'])
del(presidents['Last Name'])

# deleting First Name and Last Name column

# %% [markdown]
# ### Use of .extract( ) function
#
# .extract( ) takes a regex as input and specifically requires you to set capture groups that correspond to the output columns a user is interested in.<br>Extract function is built into the str function of the Series object, so it can be called using Series.str.extract(pattern).
#
# For example, to extract firstname and lastname from "Presidents" column; we can write a pattern regex and use it in .extract( )

# %%
# this regex has three sets of parenthesis:
# first group : it's a group named as "First". It anchors from beginning to any string. Reads any number of alphanumeric characters and returns it
# second group : it's a look-ahead only. Reads whitespace. Does not return any matched characters.
# third group : it's a group named as "Last". It anchors at the back of any string. Reads any number of characters.
pattern = "(?P<First>^[\w]*)(?:.* )(?P<Last>[\w]*$)"

names = presidents["President"].str.extract(pattern).head()
names
# Out:
#     First        Last
# 0  George  Washington
# 1    John       Adams
# 2  Thomas   Jefferson
# 3   James     Madison
# 4   James      Monroe

# %%
# and, this can be copied into main dataframe
presidents['First Name'] = names['First']
presidents['Last Name'] = names['Last']
presidents.head()
# Out:
#    Presidency          President                                 Wikipedia Entry Took office  ...                  Thumbnail     Home State First Name   Last Name
# 0           1  George Washington  http://en.wikipedia.org/wiki/George_Washington  30/04/1789  ...  thmb_GeorgeWashington.jpg       Virginia     George  Washington
# 1           2         John Adams         http://en.wikipedia.org/wiki/John_Adams   4/03/1797  ...         thmb_JohnAdams.jpg  Massachusetts       John       Adams
# 2           3   Thomas Jefferson   http://en.wikipedia.org/wiki/Thomas_Jefferson   4/03/1801  ...   thmb_Thomasjefferson.gif       Virginia     Thomas   Jefferson
# 3           4      James Madison      http://en.wikipedia.org/wiki/James_Madison   4/03/1809  ...      thmb_JamesMadison.gif       Virginia      James     Madison
# 4           5       James Monroe       http://en.wikipedia.org/wiki/James_Monroe   4/03/1817  ...       thmb_JamesMonroe.gif       Virginia      James      Monroe
#
# [5 rows x 11 columns]

# %% [markdown]
# #### Use of .to_datetime( ) function
#
# This function cleans up the datetime format. For example,

# %%
presidents["Took office"] = pd.to_datetime(presidents["Took office"])

presidents[["President", "Took office"]].head()
# Out:
#            President Took office
# 0  George Washington  1789-04-30
# 1         John Adams  1797-04-03
# 2   Thomas Jefferson  1801-04-03
# 3      James Madison  1809-04-03
# 4       James Monroe  1817-04-03

# %% [markdown]
# ****
# # Merging DataFrames
#
# Multiple dataframes can also be merged horizontally or concatenated vertically.
#
# Let's explain some concepts about Venn Diagrams.
#
# A Venn diagram is traditionally used to show set membership. For example, the circle on the left is the **population of students** at a University, the circle on the right is the **population of staff** at a University, and the overlapping region in the middle are all of those students who are also staff. There is also an overlap between these two populations.
#
# When it comes to translating this to Pandas, we can think of the case where we might have these two populations as indices in separate DataFrames (maybe with the label of person name). When we want to join the DataFrames together, we have some choices to make. First, what do we want a list of all the people regardless of whether they're staff or student, and all of the information we can get on them? In database terminology, this is called a **Full Outer join**. In set theory, it's called a **Union**. In the Venn diagram, it represents everyone in any circle.<br>See below image for understanding...
#
# #### Full Outer Join ie. Union
# ![Full Outer Join ie. Union](./datasets/images/union.jpg)
#
# If we want only those people who are both staff and students - (perhaps being a staff member and the student involves getting a tuition waiver and we want to calculate the cost of this). In database terminology, this is called an **Inner join**, or in set theory, the **Intersection**. It's represented in the Venn diagram as an overlapping part in each circle.
#
# #### Inner Join ie. Intersection
# ![Inner Join ie. Intersection](datasets/images/intersection.jpg)
#
#
# ****
# Let's create dataframes to understand this. Here, we'll create dataframes of staffs and students to understand about Union, Intersection, Add and Subtract operations.

# %%
import pandas as pd

staff_df = pd.DataFrame([{'Name': 'Anurag Singh', 'Role': 'Director of HR'},
                         {'Name': 'Mamta Chaddha', 'Role': 'Proctur'},
                         {'Name': 'Kelvin Mathur', 'Role': 'Grader'}])

staff_df = staff_df.set_index('Name')

student_df = pd.DataFrame([{'Name': 'Kiara Seth', 'School': 'Arts'},
                         {'Name': 'Anurag Singh', 'School': 'Law'},
                         {'Name': 'Kelvin Mathur', 'School': 'Engineering'}])

student_df = student_df.set_index('Name')

print(staff_df)
print(student_df)
# Out:
#                          Role
# Name
# Anurag Singh   Director of HR
# Mamta Chaddha         Proctur
# Kelvin Mathur          Grader
#                     School
# Name
# Kiara Seth            Arts
# Anurag Singh           Law
# Kelvin Mathur  Engineering

# %% [markdown]
# Hence notice here, there is an overlap in these dataframes - Kelvin & Anurag are staffs as well as students. Importantly, both dataframes are indexed along the 'Name' column
#
# ## Use of .merge( ) function
# _(by default, "how" parameter is set to "inner", meaning for the inner join.)_
#
# ##### METHOD-1 (using indices)
#
# **Union - full outer join**

# %%
pd.merge(staff_df, student_df, how="outer", left_index=True, right_index=True)
# Out:
#                          Role       School
# Name
# Anurag Singh   Director of HR          Law
# Kelvin Mathur          Grader  Engineering
# Kiara Seth                NaN         Arts
# Mamta Chaddha         Proctur          NaN

# %% [markdown]
# ***
# **Intersection - inner join**

# %%
pd.merge(staff_df, student_df, how="inner", left_index=True, right_index=True)
# Out:
#                          Role       School
# Name
# Anurag Singh   Director of HR          Law
# Kelvin Mathur          Grader  Engineering

# %% [markdown]
# ***
# Now there are 2 other common use cases when merging dataframes and both are examples of **set addition**.
#
# **Left join** - list of all staff regardless whether they were students or not. But, if they were students we would also populate their student details as well.

# %%
pd.merge(staff_df, student_df, how="left", left_index=True, right_index=True)
# Out:
#                          Role       School
# Name
# Anurag Singh   Director of HR          Law
# Mamta Chaddha         Proctur          NaN
# Kelvin Mathur          Grader  Engineering

# %% [markdown]
# ***
# **Right join** - list of all students regardless whether they were students or not. But, if they were staff we would also populate their staff details as well.

# %%
pd.merge(staff_df, student_df, how="right", left_index=True, right_index=True)
# Out:
#                          Role       School
# Name
# Kiara Seth                NaN         Arts
# Anurag Singh   Director of HR          Law
# Kelvin Mathur          Grader  Engineering

# %% [markdown]
# #### METHOD-2 (using "on" parameter)
#
# Another way of joining dataframes is by using columns and not the indices. Here there is a parameter called "on", which is assigned with a column that both the dataframe have as the joining column.

# %%
# just resetting the indices of both dataframes.
staff_df = staff_df.reset_index()
student_df = student_df.reset_index()

# right-join using "on" parameter
pd.merge(staff_df, student_df, how="right", on="Name")
# Out:
#             Name            Role       School
# 0     Kiara Seth             NaN         Arts
# 1   Anurag Singh  Director of HR          Law
# 2  Kelvin Mathur          Grader  Engineering

# %% [markdown]
# ****
# #### Conflicts during merging of DataFrames

# %%
staff_df = pd.DataFrame([{"Name": "Rishi", "Role": "Associate Manager", "Location": "Jhandewala 19B"},
                         {"Name": "Deepak", "Role": "Director of HR", "Location": "Mayur Vihar estate"},
                         {"Name": "Harshit", "Role": "Students Dean", "Location": "Dwarka sector 2"}
                        ])

student_df = pd.DataFrame([{'Name': 'Deepak', 'School': 'Business', 'Location': '13H sector 9 Simla'},
                           {'Name': 'Anurag', 'School': 'Law', 'Location': 'Jhandewala'},
                           {'Name': 'Rishi', 'School': 'Engineering', 'Location': 'Nehru Palace'}])

# Seek out the staff info regardless of whether they were students or not.
# But if they are students, seek out their student details as well. So, we can do a left join on the column Name.
pd.merge(staff_df, student_df, how="left", on="Name")

# here, Location_x and Location_y refers to Location cloumn in left and right dataframes, respectively.
# Out:
#       Name               Role          Location_x       School          Location_y
# 0    Rishi  Associate Manager      Jhandewala 19B  Engineering        Nehru Palace
# 1   Deepak     Director of HR  Mayur Vihar estate     Business  13H sector 9 Simla
# 2  Harshit      Students Dean     Dwarka sector 2          NaN                 NaN

# %% [markdown]
# ****
# #### Multi-indexing and multiple columns
#
# It's quite possible that the first name for students and staff might overlap, but the last name might not. In this case, we use a list of multiple columns that should be used to join keys from both dataframes on the on parameter. Note that, column name(s) assigned to the "on" parameter needs to exist in both dataframes.

# %%
staff_df = pd.DataFrame([{"First Name": "Rishi", "Last Name": "Mehrotra", "Role": "Associate Manager"},
                         {"First Name": "Harshit", "Last Name": "Kulkarni", "Role": "Course Instructor"},
                         {"First Name": "Simran", "Last Name": "Arora", "Role": "Grader"}
                        ])

student_df = pd.DataFrame([{"First Name": "Harshit", "Last Name": "Singh", "School": "Business"},
                           {"First Name": "Rajat", "Last Name": "Agarwal", "School": "Arts"},
                           {"First Name": "Simran", "Last Name": "Arora", "School": "Engineering"}])

pd.merge(staff_df, student_df, how="inner", on=["First Name", "Last Name"])

# Here, Harshit Kulkarni and Harshit Singh don't match on both keys since thet have different last names.
# So we would expect that an inner join does not include these individuals in the output, and only Simran Arora will be retained.
# Out:
#   First Name Last Name    Role       School
# 0     Simran     Arora  Grader  Engineering

# %% [markdown]
# ***
# Joining dataframes through merging is incredibly common; needing to know how to pull data from different sources, clean it, and join it for analysis is an important skill. This is staple not only for pandas, but of database technologies as well.
# ***
#
# **Note :**
# > *If we think of merging as joining "horizontally", meaning we join on similar values in a column found in two dataframes.<br>On other hand, concatenating is joing "vertically", meaning we put dataframes in top or at the bottom of each other.<br><br>
# As an example, you have a dataset that tracks some information over the years. And each year's record is maintained as a seperate CSV and every CSV for every year's record has the exactly same columns. If you want to put all the data from all years' record together, it can be concatenated.*
# ****
#
# <b>A simple demo about .concat( ) function</b>
#
# Source : https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html
#
# Let's concatenate the *staff_df* and *students_df* dataframes. By defult, concatenation is always an "outer" join.  If you're concatenating 2 dataframes that do not have identical columns, and choose the outer method, some cells will be NaN. If you choose to do inner, then some observations will be dropped due to NaN values. It can be thought as analogous to the left and right joins of the merge( ) function.

# %%
frames = [staff_df, student_df]
pd.concat(frames, keys=["staff", "students"])     # by default, this one is "outer" join
# Out:
#            First Name Last Name               Role       School
# staff    0      Rishi  Mehrotra  Associate Manager          NaN
#          1    Harshit  Kulkarni  Course Instructor          NaN
#          2     Simran     Arora             Grader          NaN
# students 0    Harshit     Singh                NaN     Business
#          1      Rajat   Agarwal                NaN         Arts
#          2     Simran     Arora                NaN  Engineering

# %%
pd.concat(frames, join="inner", keys=["staff", "students"])    # "inner" join
# Out:
#            First Name Last Name
# staff    0      Rishi  Mehrotra
#          1    Harshit  Kulkarni
#          2     Simran     Arora
# students 0    Harshit     Singh
#          1      Rajat   Agarwal
#          2     Simran     Arora

# %% [markdown]
# ****

# %% [markdown]
# # Making the code 'PANDORABLE'
#
# Python programmers often suggest that there are many ways the language can be used to solve a particular problem; but some are more appropriate than others. The best solutions are celebrated as idiomatic Python.
#
# A sort of sub-language within Python, Pandas has its own set of idioms - such as, using vectorization wherever possible and not using iterative loops if not needed. Several developers and users within the Pandas community have used the term **pandorable** for these idioms.<br>Well, here we'll see how to make your code pandorable.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./datasets/census.csv')       # US census' data. It's a large dataset with numerous columns.
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 0         -0.193196          0.381066          0.582002         -0.467369
# 1         -2.915927         -3.012349          2.265971         -2.530799
# 2         17.647293         21.845705         19.243287         17.197872
# 3         -2.500690         -7.056824         -3.904217        -10.543299
# 4         -5.068871         -6.201001         -0.177537          0.177258
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# 0     1.030015     0.826644     1.383282     1.724718     0.712594
# 1     7.606016    -2.626146    -2.722002     2.592270    -2.187333
# 2    15.844176    18.559627    22.727626    20.317142    18.293499
# 3    -4.874741    -2.758113    -7.167664    -3.978583   -10.543299
# 4    -5.088389    -4.363636    -5.403729     0.754533     1.107861
#
# [5 rows x 100 columns]

# %% [markdown]
# ### Method Chaining
#
# The general idea behind method chaining is that every method on an object returns a reference to that object. The advantage of it is that...many different operations on a dataframe can be condensed together into one line/statement of code.
#
# For example, we will take above dataset and try to do method chaining to make it look pandorable.
#
# **I. PANDORABLE method :**

# %%
(df.where(df['SUMLEV'] == 50)
 .dropna()
 .set_index(['STNAME', 'CTYNAME'])
 .rename(columns={'ESTIMATESBASE2010': 'Estimates Base 2010'}))

# Let's walthrough this chaining example....
# Firstly, we use the where() function on the dataframe and pass in a boolean mask which is only true for those rows where the SUMLEV == 50.
# This indicates in our source data that the data is summarized at the county level.
# On the result of the where() function, we evaluate the dropna to drop the missing values.
# Remember that .where() doesn't drop missing values by default.
# Then we set an index on the result of that. In this case I've set it to the state name followed by the county name.
# Finally, renaming a column to make it more readable.

# Note that instead of writing this on a single line, I began the
# statement with a parenthesis, which tells python I'm going to span the statement over multiple lines for readability.
# Out:
#                            SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County       50.0     3.0       6.0    1.0     1.0
#         Baldwin County       50.0     3.0       6.0    1.0     3.0
#         Barbour County       50.0     3.0       6.0    1.0     5.0
#         Bibb County          50.0     3.0       6.0    1.0     7.0
#         Blount County        50.0     3.0       6.0    1.0     9.0
# ...                           ...     ...       ...    ...     ...
# Wyoming Sweetwater County    50.0     4.0       8.0   56.0    37.0
#         Teton County         50.0     4.0       8.0   56.0    39.0
#         Uinta County         50.0     4.0       8.0   56.0    41.0
#         Washakie County      50.0     4.0       8.0   56.0    43.0
#         Weston County        50.0     4.0       8.0   56.0    45.0
#
#                            CENSUS2010POP  Estimates Base 2010  \
# STNAME  CTYNAME
# Alabama Autauga County           54571.0              54571.0
#         Baldwin County          182265.0             182265.0
#         Barbour County           27457.0              27457.0
#         Bibb County              22915.0              22919.0
#         Blount County            57322.0              57322.0
# ...                                  ...                  ...
# Wyoming Sweetwater County        43806.0              43806.0
#         Teton County             21294.0              21294.0
#         Uinta County             21118.0              21118.0
#         Washakie County           8533.0               8533.0
#         Weston County             7208.0               7208.0
#
#                            POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# STNAME  CTYNAME
# Alabama Autauga County             54660.0          55253.0          55175.0
#         Baldwin County            183193.0         186659.0         190396.0
#         Barbour County             27341.0          27226.0          27159.0
#         Bibb County                22861.0          22733.0          22642.0
#         Blount County              57373.0          57711.0          57776.0
# ...                                    ...              ...              ...
# Wyoming Sweetwater County          43593.0          44041.0          45104.0
#         Teton County               21297.0          21482.0          21697.0
#         Uinta County               21102.0          20912.0          20989.0
#         Washakie County             8545.0           8469.0           8443.0
#         Weston County               7181.0           7114.0           7065.0
#
#                            ...  RDOMESTICMIG2011  RDOMESTICMIG2012  \
# STNAME  CTYNAME            ...
# Alabama Autauga County     ...          7.242091         -2.915927
#         Baldwin County     ...         14.832960         17.647293
#         Barbour County     ...         -4.728132         -2.500690
#         Bibb County        ...         -5.527043         -5.068871
#         Blount County      ...          1.807375         -1.177622
# ...                        ...               ...               ...
# Wyoming Sweetwater County  ...          1.072643         16.243199
#         Teton County       ...         -1.589565          0.972695
#         Uinta County       ...        -17.755986         -4.916350
#         Washakie County    ...        -11.637475         -0.827815
#         Weston County      ...        -11.752361         -8.040059
#
#                            RDOMESTICMIG2013  RDOMESTICMIG2014  \
# STNAME  CTYNAME
# Alabama Autauga County            -3.012349          2.265971
#         Baldwin County            21.845705         19.243287
#         Barbour County            -7.056824         -3.904217
#         Bibb County               -6.201001         -0.177537
#         Blount County             -1.748766         -2.062535
# ...                                     ...               ...
# Wyoming Sweetwater County         -5.339774        -14.252889
#         Teton County              19.525929         14.143021
#         Uinta County              -6.902954        -14.215862
#         Washakie County           -2.013502        -17.781491
#         Weston County             12.372583          1.533635
#
#                            RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  \
# STNAME  CTYNAME
# Alabama Autauga County            -2.530799     7.606016    -2.626146
#         Baldwin County            17.197872    15.844176    18.559627
#         Barbour County           -10.543299    -4.874741    -2.758113
#         Bibb County                0.177258    -5.088389    -4.363636
#         Blount County             -1.369970     1.859511    -0.848580
# ...                                     ...          ...          ...
# Wyoming Sweetwater County        -14.248864     1.255221    16.243199
#         Teton County              -0.564849     0.654527     2.408578
#         Uinta County             -12.127022   -18.136812    -5.536861
#         Washakie County            1.682288   -11.990126    -1.182592
#         Weston County              6.935294   -12.032179    -8.040059
#
#                            RNETMIG2013  RNETMIG2014  RNETMIG2015
# STNAME  CTYNAME
# Alabama Autauga County       -2.722002     2.592270    -2.187333
#         Baldwin County       22.727626    20.317142    18.293499
#         Barbour County       -7.167664    -3.978583   -10.543299
#         Bibb County          -5.403729     0.754533     1.107861
#         Blount County        -1.402476    -1.577232    -0.884411
# ...                                ...          ...          ...
# Wyoming Sweetwater County    -5.295460   -14.075283   -14.070195
#         Teton County         21.160658    16.308671     1.520747
#         Uinta County         -7.521840   -14.740608   -12.606351
#         Washakie County      -2.250385   -18.020168     1.441961
#         Weston County        12.372583     1.533635     6.935294
#
# [3142 rows x 98 columns]

# %% [markdown]
# **II. TRADITIONAL method :**
#
# Here's a non-pandorable way of writing code.

# %%
df = df[df['SUMLEV'] == 50]     # use the overlaod indexing operator [] which drops NaN values

df.set_index(['STNAME', 'CTYNAME'], inplace=True)    # setting the new index for df

df.rename(columns = {'ESTIMATESBASE2020': 'Estimates Base 2010'})   # renaming a column name
# Out:
#                            SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County         50       3         6      1       1
#         Baldwin County         50       3         6      1       3
#         Barbour County         50       3         6      1       5
#         Bibb County            50       3         6      1       7
#         Blount County          50       3         6      1       9
# ...                           ...     ...       ...    ...     ...
# Wyoming Sweetwater County      50       4         8     56      37
#         Teton County           50       4         8     56      39
#         Uinta County           50       4         8     56      41
#         Washakie County        50       4         8     56      43
#         Weston County          50       4         8     56      45
#
#                            CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County             54571              54571            54660
#         Baldwin County            182265             182265           183193
#         Barbour County             27457              27457            27341
#         Bibb County                22915              22919            22861
#         Blount County              57322              57322            57373
# ...                                  ...                ...              ...
# Wyoming Sweetwater County          43806              43806            43593
#         Teton County               21294              21294            21297
#         Uinta County               21118              21118            21102
#         Washakie County             8533               8533             8545
#         Weston County               7208               7208             7181
#
#                            POPESTIMATE2011  POPESTIMATE2012  ...  \
# STNAME  CTYNAME                                              ...
# Alabama Autauga County               55253            55175  ...
#         Baldwin County              186659           190396  ...
#         Barbour County               27226            27159  ...
#         Bibb County                  22733            22642  ...
#         Blount County                57711            57776  ...
# ...                                    ...              ...  ...
# Wyoming Sweetwater County            44041            45104  ...
#         Teton County                 21482            21697  ...
#         Uinta County                 20912            20989  ...
#         Washakie County               8469             8443  ...
#         Weston County                 7114             7065  ...
#
#                            RDOMESTICMIG2011  RDOMESTICMIG2012  \
# STNAME  CTYNAME
# Alabama Autauga County             7.242091         -2.915927
#         Baldwin County            14.832960         17.647293
#         Barbour County            -4.728132         -2.500690
#         Bibb County               -5.527043         -5.068871
#         Blount County              1.807375         -1.177622
# ...                                     ...               ...
# Wyoming Sweetwater County          1.072643         16.243199
#         Teton County              -1.589565          0.972695
#         Uinta County             -17.755986         -4.916350
#         Washakie County          -11.637475         -0.827815
#         Weston County            -11.752361         -8.040059
#
#                            RDOMESTICMIG2013  RDOMESTICMIG2014  \
# STNAME  CTYNAME
# Alabama Autauga County            -3.012349          2.265971
#         Baldwin County            21.845705         19.243287
#         Barbour County            -7.056824         -3.904217
#         Bibb County               -6.201001         -0.177537
#         Blount County             -1.748766         -2.062535
# ...                                     ...               ...
# Wyoming Sweetwater County         -5.339774        -14.252889
#         Teton County              19.525929         14.143021
#         Uinta County              -6.902954        -14.215862
#         Washakie County           -2.013502        -17.781491
#         Weston County             12.372583          1.533635
#
#                            RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  \
# STNAME  CTYNAME
# Alabama Autauga County            -2.530799     7.606016    -2.626146
#         Baldwin County            17.197872    15.844176    18.559627
#         Barbour County           -10.543299    -4.874741    -2.758113
#         Bibb County                0.177258    -5.088389    -4.363636
#         Blount County             -1.369970     1.859511    -0.848580
# ...                                     ...          ...          ...
# Wyoming Sweetwater County        -14.248864     1.255221    16.243199
#         Teton County              -0.564849     0.654527     2.408578
#         Uinta County             -12.127022   -18.136812    -5.536861
#         Washakie County            1.682288   -11.990126    -1.182592
#         Weston County              6.935294   -12.032179    -8.040059
#
#                            RNETMIG2013  RNETMIG2014  RNETMIG2015
# STNAME  CTYNAME
# Alabama Autauga County       -2.722002     2.592270    -2.187333
#         Baldwin County       22.727626    20.317142    18.293499
#         Barbour County       -7.167664    -3.978583   -10.543299
#         Bibb County          -5.403729     0.754533     1.107861
#         Blount County        -1.402476    -1.577232    -0.884411
# ...                                ...          ...          ...
# Wyoming Sweetwater County    -5.295460   -14.075283   -14.070195
#         Teton County         21.160658    16.308671     1.520747
#         Uinta County         -7.521840   -14.740608   -12.606351
#         Washakie County      -2.250385   -18.020168     1.441961
#         Weston County        12.372583     1.533635     6.935294
#
# [3142 rows x 98 columns]

# %% [markdown]
# ## When an Idiom (or, "Pandorable" code) is helpful ?
#
# #### Lets understand this with an example :
#
# Now, the significance of any good idiom is to understand whether it is helpful or not. To understand this, you can actually time both methods (Pandorable and Traditional method) and see which one runs faster.
#
# We can put the approach into a function and pass the function into the timeit function to count the time the parameter number allows us to choose how many times we want to run the function. Here we will just set it to 10.

# %%
# hence, bringing the timing functionality from the timeit module.

import timeit

# %% [markdown]
# **I. our 1st approach.**

# %%
def first_approach():
    global df
    return (df.where(df['SUMLEV']==50)
             .dropna()
             .set_index(['STNAME','CTYNAME'])
             .rename(columns={'ESTIMATESBASE2010': 'Estimates Base 2010'}))

# Read in our dataset
df = pd.read_csv('datasets/census.csv')

# And now lets run it
timeit.timeit(first_approach, number=10)
# Out:
# 0.29698424800881185

# %% [markdown]
# **II. our 2nd approach.**

# %%
def second_approach():
    global df
    new_df = df[df['SUMLEV']==50]
    new_df.set_index(['STNAME','CTYNAME'], inplace=True)
    return new_df.rename(columns={'ESTIMATESBASE2010': 'Estimates Base 2010'})

# Read in our dataset anew
df = pd.read_csv('datasets/census.csv')

# And now lets run it
timeit.timeit(second_approach, number=10)
# Out:
# 0.051387972984230146

# %% [markdown]
# Clearly, the **2nd approach is much faster!**
# So, this is a particular example of a classic time readability trade off.
#
# Noticeably, keep in mind that idioms may have performance issues despite being stylistic - so one must consider this as well during data cleaning or analysis exercise.
#
# ****
#
# Python has a function called map, which is sort of a basis for functional programming in the language. When you want to use map in Python, you pass it some function you want called, and some iterable, like a list, that you want the function to be applied to. The results of that function are then called against each item in the list and there's a resulting list of all of the evaluations of that function.<br>
# Some sources for map( ), refer here :
# - https://docs.python.org/3/library/functions.html#map
# - https://realpython.com/python-map-function/
#
#
# Pandas has something similar, which is called **applymap( )**.<br>
# In applymap, you provide some function which should operate on each cell of a dataframe and the return set is itself a dataframe.
#
# ****
#
# #### Lets look at an another pandas idiom -
#
# Let's take a look at the census DataFrame.<br>In this DataFrame, we have five columns for population estimates, with each column corresponding with one year of estimates.
# <br><br>
# For example, to create some new columns for minimum or maximum values, the apply( ) function would be helpful.
#
# First, we need to write a function which takes in a particular row of data, finds a minimum and maximum values, and returns a new row of data from that - can call this function min_max( ), this is pretty straight forward.<br>We can create some small slice of a row by projecting the population columns. Then use the NumPy min( ) and max( ) functions, and create a new series with a label values representing the new values that we want to apply.

# %%
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    return pd.Series({'min': np.min(data), 'max': np.max(data)})

df.apply(min_max, axis="columns")
# Out:
#           min      max
# 0     4785161  4858979
# 1       54660    55347
# 2      183193   203709
# 3       26489    27341
# 4       22512    22861
# ...       ...      ...
# 3188    43593    45162
# 3189    21297    23125
# 3190    20822    21102
# 3191     8316     8545
# 3192     7065     7234
#
# [3193 rows x 2 columns]

# %% [markdown]
# Well, instead of returning a seperate series to display the min and max, those 2 new columns can also be added in the original dataframe to store min and max values.<br>This can be achieved as shown below...

# %%
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    row['max'] = np.max(data)    # Create a new column-entry for max
    row['min'] = np.min(data)    # Create a new column-entry for min
    return row

df.apply(min_max, axis="columns")
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# 0           4779736            4780127          4785161  ...
# 1             54571              54571            54660  ...
# 2            182265             182265           183193  ...
# 3             27457              27457            27341  ...
# 4             22915              22919            22861  ...
# ...             ...                ...              ...  ...
# 3188          43806              43806            43593  ...
# 3189          21294              21294            21297  ...
# 3190          21118              21118            21102  ...
# 3191           8533               8533             8545  ...
# 3192           7208               7208             7181  ...
#
#       RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  RNETMIG2011  \
# 0             0.381066          0.582002         -0.467369     1.030015
# 1            -3.012349          2.265971         -2.530799     7.606016
# 2            21.845705         19.243287         17.197872    15.844176
# 3            -7.056824         -3.904217        -10.543299    -4.874741
# 4            -6.201001         -0.177537          0.177258    -5.088389
# ...                ...               ...               ...          ...
# 3188         -5.339774        -14.252889        -14.248864     1.255221
# 3189         19.525929         14.143021         -0.564849     0.654527
# 3190         -6.902954        -14.215862        -12.127022   -18.136812
# 3191         -2.013502        -17.781491          1.682288   -11.990126
# 3192         12.372583          1.533635          6.935294   -12.032179
#
#       RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015      max      min
# 0        0.826644     1.383282     1.724718     0.712594  4858979  4785161
# 1       -2.626146    -2.722002     2.592270    -2.187333    55347    54660
# 2       18.559627    22.727626    20.317142    18.293499   203709   183193
# 3       -2.758113    -7.167664    -3.978583   -10.543299    27341    26489
# 4       -4.363636    -5.403729     0.754533     1.107861    22861    22512
# ...           ...          ...          ...          ...      ...      ...
# 3188    16.243199    -5.295460   -14.075283   -14.070195    45162    43593
# 3189     2.408578    21.160658    16.308671     1.520747    23125    21297
# 3190    -5.536861    -7.521840   -14.740608   -12.606351    21102    20822
# 3191    -1.182592    -2.250385   -18.020168     1.441961     8545     8316
# 3192    -8.040059    12.372583     1.533635     6.935294     7234     7065
#
# [3193 rows x 102 columns]

# %% [markdown]
# apply( ) is an extremely important tool in Pandas toolkit.
# Typically, apply( ) can be seen being used with **lambda** functions.
#
# Above example can be reinstated with help of lambdas as :
#
# *A **lambda** is just an unnamed function in Python.<br>In this case it takes a single parameter, x, and returns a single value i.e. the maximum over all columns associated with row x.*

# %%
rows = ['POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013','POPESTIMATE2014', 'POPESTIMATE2015']
# Now we'll just apply this across the dataframe with a lambda
df.apply(lambda x: np.max(x[rows]), axis=1).head()
# Out:
# 0    4858979
# 1      55347
# 2     203709
# 3      27341
# 4      22861
# dtype: int64

# %% [markdown]
# The beauty of the apply( ) function is that it allows flexibility in doing whatever manipulation that you desire as, the function you pass into apply can be any customized however when needed.
#
# #### Example :
# As an example, let's say we want to divide the states into 4 categories:<br>•Northeast  •Midwest  •South  •West.<br>
# To do this, firstly we can write a customized function i.e. get_state_region( ) that returns the region based on the state.

# %%
def get_state_region(x):
    northeast = ['Connecticut', 'Maine', 'Massachusetts', 'New Hampshire', 
                 'Rhode Island','Vermont','New York','New Jersey','Pennsylvania']
    midwest = ['Illinois','Indiana','Michigan','Ohio','Wisconsin','Iowa',
               'Kansas','Minnesota','Missouri','Nebraska','North Dakota',
               'South Dakota']
    south = ['Delaware','Florida','Georgia','Maryland','North Carolina',
             'South Carolina','Virginia','District of Columbia','West Virginia',
             'Alabama','Kentucky','Mississippi','Tennessee','Arkansas',
             'Louisiana','Oklahoma','Texas']
    west = ['Arizona','Colorado','Idaho','Montana','Nevada','New Mexico','Utah',
            'Wyoming','Alaska','California','Hawaii','Oregon','Washington']
    
    if x in northeast:
        return "Northeast"
    elif x in midwest:
        return "Midwest"
    elif x in south:
        return "South"
    else:
        return "West"

# %% [markdown]
# Now, create a new column called Region - which shows the state's region.<br>It can be done by using the apply( ) function over get_state_region customised function.<br>
# (The customized function
# will work on the state name column STNAME. So we will set the apply function on the state name column and pass the customized function into the apply function)

# %%
df['state_region'] = df['STNAME'].apply(lambda x: get_state_region(x))
# "state_region" is a new column.

df[['STNAME','state_region']].head()
# Out:
#     STNAME state_region
# 0  Alabama        South
# 1  Alabama        South
# 2  Alabama        South
# 3  Alabama        South
# 4  Alabama        South

# %% [markdown]
# ****
#
# # Splitting
#
# Sometimes we want to select data based on groups and understand aggregated data on a group level. We have seen that even though Pandas allows us to iterate over every row in a dataframe, it is generally very slow to do so. Fortunately, Pandas has a **groupby( ) function** to speed up such task. The idea behind the groupby( ) function is that it takes some dataframe, splits it into chunks based on some key values, applies computation on those chunks, then combines the results back together into another dataframe. In pandas this is refered to as **the split-apply-combine pattern**.<br>
# _Here are few examples of how splitting works to process data._
#
# _Consider US's census data..._
#
# **Example 1:**

# %%
import pandas as pd
import numpy as np

# reading the US's census data
df = pd.read_csv('datasets/census.csv')

# including the state level summarizations, which have Sum Level == 50
df = df[df['SUMLEV']==50]
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 1         -2.915927         -3.012349          2.265971         -2.530799
# 2         17.647293         21.845705         19.243287         17.197872
# 3         -2.500690         -7.056824         -3.904217        -10.543299
# 4         -5.068871         -6.201001         -0.177537          0.177258
# 5         -1.177622         -1.748766         -2.062535         -1.369970
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# 1     7.606016    -2.626146    -2.722002     2.592270    -2.187333
# 2    15.844176    18.559627    22.727626    20.317142    18.293499
# 3    -4.874741    -2.758113    -7.167664    -3.978583   -10.543299
# 4    -5.088389    -4.363636    -5.403729     0.754533     1.107861
# 5     1.859511    -0.848580    -1.402476    -1.577232    -0.884411
#
# [5 rows x 100 columns]

# %% [markdown]
# Let's get a list of the unique states, and then iterate over all the states and for each state we shall reduce the data frame and calculate the average.
#
# This task will be run for 3 times.<br>To do this, use the cell magic function %%timeit and jupyter notebook will display the avarage value.
#
# **I. 1st Approach**

# %%
# %%timeit -n 3

for state in df['STNAME'].unique():
    avg = np.average(df.where(df['STNAME']==state).dropna()['CENSUS2010POP'])    # calculate the average using numpy for this particular state
    print('Counties in state ' + state + ' have an average population of ' + str(avg))      # print it to the screen
    

    
# scroll down at the bottom of output to see that takes it a fair bit of time to finish.
# Out:
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# ...
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# 1.24 s ± 37.9 ms per loop (mean ± std. dev. of 7 runs, 3 loops each)

# %% [markdown]
# **II. 2nd Approach - using groupby( ) function**

# %%
# %%timeit -n 3
# For this approach, we start by telling pandas we're interested in grouping by state name, this is the "split"
for group, frame in df.groupby('STNAME'):
    # Notice that, there are 2 values set here. groupby() returns a tuple, where the first value is the
    # value of the key we were trying to group by, in this case a specific state name, and the second one is
    # projected dataframe that was found for that group
    
    # Now we include our logic in the "apply" step, which is to calculate an average of the census2010pop
    avg = np.average(frame['CENSUS2010POP'])
    print('Counties in state ' + group + 
          ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# ...
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# Counties in state Illinois have an average population of 125790.50980392157
# Counties in state Indiana have an average population of 70476.10869565218
# Counties in state Iowa have an average population of 30771.262626262625
# Counties in state Kansas have an average population of 27172.55238095238
# Counties in state Kentucky have an average population of 36161.39166666667
# Counties in state Louisiana have an average population of 70833.9375
# Counties in state Maine have an average population of 83022.5625
# Counties in state Maryland have an average population of 240564.66666666666
# Counties in state Massachusetts have an average population of 467687.78571428574
# Counties in state Michigan have an average population of 119080.0
# Counties in state Minnesota have an average population of 60964.65517241379
# Counties in state Mississippi have an average population of 36186.54878048781
# Counties in state Missouri have an average population of 52077.62608695652
# Counties in state Montana have an average population of 17668.125
# Counties in state Nebraska have an average population of 19638.075268817203
# Counties in state Nevada have an average population of 158855.9411764706
# Counties in state New Hampshire have an average population of 131647.0
# Counties in state New Jersey have an average population of 418661.61904761905
# Counties in state New Mexico have an average population of 62399.36363636364
# Counties in state New York have an average population of 312550.03225806454
# Counties in state North Carolina have an average population of 95354.83
# Counties in state North Dakota have an average population of 12690.396226415094
# Counties in state Ohio have an average population of 131096.63636363635
# Counties in state Oklahoma have an average population of 48718.844155844155
# Counties in state Oregon have an average population of 106418.72222222222
# Counties in state Pennsylvania have an average population of 189587.74626865672
# Counties in state Rhode Island have an average population of 210513.4
# Counties in state South Carolina have an average population of 100551.39130434782
# Counties in state South Dakota have an average population of 12336.060606060606
# Counties in state Tennessee have an average population of 66801.1052631579
# Counties in state Texas have an average population of 98998.27165354331
# Counties in state Utah have an average population of 95306.37931034483
# Counties in state Vermont have an average population of 44695.78571428572
# Counties in state Virginia have an average population of 60111.29323308271
# Counties in state Washington have an average population of 172424.10256410256
# Counties in state West Virginia have an average population of 33690.8
# Counties in state Wisconsin have an average population of 78985.91666666667
# Counties in state Wyoming have an average population of 24505.478260869564
# 11.6 ms ± 1.44 ms per loop (mean ± std. dev. of 7 runs, 3 loops each)

# %% [markdown]
# Well just notice the huge difference in speed!!!<br>Approach-2 is almost 2 times faster than approach-1.
#
# groupby( ) also accepts functions to segement the data instead of one or more columns.<br>
# Source : https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html
#
# ****
#
# *Lets consider an another example*....<br>**Example 2 :**
#
# Consider there's a big batch job with lots of processing and you want to work on only a third or so of the states at a given time.<br>We could create some function which returns a number between 0 and 2 based on the first character of the state name. Then we can tell groupby to use this function to split up our data frame.<br>It's important to note that in order to do this you need to set the index of the data frame to be the column that you want to groupby first.
#
# We'll create some new function called set_batch_number( ) and if the first letter of the parameter is a capital "M" we'll return a 0. If it's a capital "Q" we'll return a 1 and otherwise we'll return a 2. Then we'll pass this function to the data frame.

# %%
df = df.set_index('STNAME')

def set_batch_number(item):
    if item[0]<'M':
        return 0
    if item[0]<'Q':
        return 1
    return 2

# The dataframe is supposed to be grouped by according to the batch number. And each batch group can be looped through.
for group, frame in df.groupby(set_batch_number):
    print('There are ' + str(len(frame)) + ' records in group ' + str(group) + ' for processing.')
# Out:
# There are 1177 records in group 0 for processing.
# There are 1134 records in group 1 for processing.
# There are 831 records in group 2 for processing.

# %% [markdown]
# Notice that this time a column name is not passed to the groupby( ).<br>Instead, we have set the index of the dataframe to be STNAME, and if no column identifier is passed, the groupby( ) will automatically use the index.
# *****
#
# **Example 3 :**
#
# There is a dataset of housing, from Airbnb.<br>In this dataset there are two columns of interest, one is the cancellation_policy and the other is the review_scores_value.
#
# ***Question is - how to groupby these 2 columns ?***

# %%
df = pd.read_csv("./datasets/listings.csv")
df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...                 NaN
# 1  The room is in Roslindale, a diverse and prima...  ...                 9.0
# 2  The LOCATION: Roslindale is a safe and diverse...  ...                10.0
# 3  Roslindale is a lovely little neighborhood loc...  ...                10.0
# 4  I love the proximity to downtown, the neighbor...  ...                10.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                t
# 2                f     NaN                NaN                f
# 3                f     NaN                NaN                f
# 4                f     NaN                NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             t
# 3            moderate                             f
# 4            flexible                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#    reviews_per_month
# 0                NaN
# 1               1.30
# 2               0.47
# 3               1.00
# 4               2.25
#
# [5 rows x 95 columns]

# %% [markdown]
# **1st Approach :** to promote these 2 columns to a multiindex and just call groupby( )<br>
# When we have a multiindex we need to pass in the levels we are interested in grouping by.<br>
# By default, groupby( ) does not preassume to groupby on which levels.

# %%
df = df.set_index(["cancellation_policy", "review_scores_value"])

for group, frame in df.groupby(level=(0,1)):
    print(group)
# Out:
# ('flexible', 2.0)
# ('flexible', 4.0)
# ('flexible', 5.0)
# ('flexible', 6.0)
# ('flexible', 7.0)
# ('flexible', 8.0)
# ('flexible', 9.0)
# ('flexible', 10.0)
# ('moderate', 2.0)
# ('moderate', 4.0)
# ('moderate', 6.0)
# ('moderate', 7.0)
# ('moderate', 8.0)
# ('moderate', 9.0)
# ('moderate', 10.0)
# ('strict', 2.0)
# ('strict', 3.0)
# ('strict', 4.0)
# ('strict', 5.0)
# ('strict', 6.0)
# ('strict', 7.0)
# ('strict', 8.0)
# ('strict', 9.0)
# ('strict', 10.0)
# ('super_strict_30', 6.0)
# ('super_strict_30', 7.0)
# ('super_strict_30', 8.0)
# ('super_strict_30', 9.0)
# ('super_strict_30', 10.0)

# %% [markdown]
# Now, what if we wanted to group by the cancelation policy and review scores, but separate out all the 10's from those under 10? In this case, we could use a function to manage the groupings.

# %%
def grouping_fun(item):
    # Check the "review_scores_value" portion of the index. item is in the format of (cancellation_policy, review_scores_value) i.e. a tuple
    if item[1] == 10.0:
        return (item[0], "10.0")
    else:
        return (item[0], "not 10.0")

for group, frame in df.groupby(by=grouping_fun):
    print(group)
# Out:
# ('flexible', '10.0')
# ('flexible', 'not 10.0')
# ('moderate', '10.0')
# ('moderate', 'not 10.0')
# ('strict', '10.0')
# ('strict', 'not 10.0')
# ('super_strict_30', '10.0')
# ('super_strict_30', 'not 10.0')

# %% [markdown]
# ****
#
# There are 3 broad categories of data processing to happen during the apply step:
#
# • Aggregation of group data
#
# • Transformation of group data
#
# • Filtration of group data
#
# ## Aggregation
#
# The most straight forward apply step is the aggregation of data, and uses the method agg( ) on the groupby object. Thus far we have only iterated through the groupby object, unpacking it into a label (the group name) and a dataframe. But with agg( ) we can pass in a dictionary of the columns we are interested in aggregating along with the function we are looking to apply to aggregate.
#
# **Example :** Let's groupby the cancellation_policy and find the average review_scores_value by group

# %%
df = df.reset_index()

df.groupby("cancellation_policy").agg({"review_scores_value": np.average})

# This does not seem to work i.e. displays up NaNs. The issue is actually in the function that we sent to aggregate.
# np.average does not ignore NaNs.
# Out:
#                      review_scores_value
# cancellation_policy
# flexible                             NaN
# moderate                             NaN
# strict                               NaN
# super_strict_30                      NaN

# %% [markdown]
# So, it's better to use np.nanmean

# %%
df.groupby("cancellation_policy").agg({"review_scores_value": np.nanmean})
# Out:
#                      review_scores_value
# cancellation_policy
# flexible                        9.237421
# moderate                        9.307398
# strict                          9.081441
# super_strict_30                 8.537313

# %% [markdown]
# Also, we can extend this dictionary to aggregate by multiple functins or multiple columns.

# %%
df.groupby("cancellation_policy").agg({"review_scores_value": (np.nanmean,np.nanstd),
                                      "reviews_per_month": np.nanmean})
# Out:
#                     review_scores_value           reviews_per_month
#                                 nanmean    nanstd           nanmean
# cancellation_policy
# flexible                       9.237421  1.096271          1.829210
# moderate                       9.307398  0.859859          2.391922
# strict                         9.081441  1.040531          1.873467
# super_strict_30                8.537313  0.840785          0.340143

# %% [markdown]
# *Let's do a walkthrough of above cell...*<br>
# First we're doing a groupby on the dataframe object by the column "cancellation_policy". This creates a new GroupBy object. Then we are invoking the agg( ) function on that object. The agg function is going to apply one or more functions we specify to the group dataframes and return a single row per dataframe/group. When we called this function we sent it two dictionary entries, each with the key indicating which column we wanted functions applied to. For the first column we actually supplied a tuple of two functions.<br> Note that these are not function invocations, like np.nanmean(), or function names, like "nanmean". They are references to functions which will return single values.
#
# The groupby object will recognize the tuple and call each function in order on the same column. The results will be in a heirarchical index, but since they are columns they don't show as an index per se. Then we indicated another column and a single function we wanted to run.
#
# *****
#
# ## Transformation
#
# Transformation is different from aggregation.<br>Where agg( ) returns a single value per column, so one row per group, tranform( ) returns an object that is the same size as the group.
#
# Essentially, it broadcasts the function you supply over the grouped dataframe, returning a new dataframe. This makes combining data later easy.
#
# **Example :** To include the average rating values in a given group by cancellation policy, but preserve the dataframe shape so that we could generate a difference between an individual observation and the sum.

# %%
cols = ['cancellation_policy','review_scores_value']

# now transform it
transform_df = df[cols].groupby('cancellation_policy').transform(np.nanmean)
transform_df.head()
# Out:
#    review_scores_value
# 0             9.307398
# 1             9.307398
# 2             9.307398
# 3             9.307398
# 4             9.237421

# %%
# So we can see that the index here is actually the same as the original dataframe.
# but let's just rename the column in the transformed version before joining them.

transform_df.rename({'review_scores_value': 'mean_review_scores'}, axis='columns', inplace=True)

# now, joining them across same indices because indexes for both dataframes are the same.
df = df.merge(transform_df, left_index=True, right_index=True)
df.head()
# Out:
#   cancellation_policy  review_scores_value        id  \
# 0            moderate                  NaN  12147973
# 1            moderate                  9.0   3075044
# 2            moderate                 10.0      6976
# 3            moderate                 10.0   1436513
# 4            flexible                 10.0   7651065
#
#                              listing_url       scrape_id last_scraped  \
# 0  https://www.airbnb.com/rooms/12147973  20160906204935   2016-09-07
# 1   https://www.airbnb.com/rooms/3075044  20160906204935   2016-09-07
# 2      https://www.airbnb.com/rooms/6976  20160906204935   2016-09-07
# 3   https://www.airbnb.com/rooms/1436513  20160906204935   2016-09-07
# 4   https://www.airbnb.com/rooms/7651065  20160906204935   2016-09-07
#
#                                             name  \
# 0                     Sunny Bungalow in the City
# 1              Charming room in pet friendly apt
# 2               Mexican Folk Art Haven in Boston
# 3  Spacious Sunny Bedroom Suite in Historic Home
# 4                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description  ...  \
# 0  Cozy, sunny, family home.  Master bedroom high...  ...
# 1  Charming and quiet room in a second floor 1910...  ...
# 2  Come stay with a friendly, middle-aged guy in ...  ...
# 3  Come experience the comforts of home away from...  ...
# 4  My comfy, clean and relaxing home is one block...  ...
#
#   review_scores_location requires_license license jurisdiction_names  \
# 0                    NaN                f     NaN                NaN
# 1                    9.0                f     NaN                NaN
# 2                    9.0                f     NaN                NaN
# 3                   10.0                f     NaN                NaN
# 4                    9.0                f     NaN                NaN
#
#   instant_bookable require_guest_profile_picture  \
# 0                f                             f
# 1                t                             f
# 2                f                             t
# 3                f                             f
# 4                f                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month mean_review_scores
# 0               NaN           9.307398
# 1              1.30           9.307398
# 2              0.47           9.307398
# 3              1.00           9.307398
# 4              2.25           9.237421
#
# [5 rows x 96 columns]

# %% [markdown]
# Now, the new column (mean_review_scores) is in place.
#
# Lets calculate the difference between a given row and it's group (the cancellation policy).

# %%
df['mean_diff'] = np.absolute(df['review_scores_value'] - df['mean_review_scores'])
df['mean_diff'].head()
# Out:
# 0         NaN
# 1    0.307398
# 2    0.692602
# 3    0.692602
# 4    0.762579
# Name: mean_diff, dtype: float64

# %% [markdown]
# *****
# ## Filtering
#
# The GroupBy object has build in support for filtering groups as well. It's often that you'll want to group by some feature, then make some transformation to the groups, then drop certain groups as part of your cleaning routines.
#
# The filter( ) function takes in a function which it applies to each group dataframe and returns either a True or a False, depending upon whether that group should be included in the results.
#
# **Example :** The groups which have a mean rating above 9.2 included in our results.

# %%
df.groupby('cancellation_policy').filter(lambda x: np.nanmean(x['review_scores_value']) > 9.2)


# Note that, the results are still indexed, but that any of the results which were in a group with a mean
# review score of less than or equal to 9.2 were not copied over.
# Out:
#      cancellation_policy  review_scores_value        id  \
# 0               moderate                  NaN  12147973
# 1               moderate                  9.0   3075044
# 2               moderate                 10.0      6976
# 3               moderate                 10.0   1436513
# 4               flexible                 10.0   7651065
# ...                  ...                  ...       ...
# 3576            flexible                  NaN  14689681
# 3577            flexible                  NaN  13750763
# 3579            flexible                  NaN  14852179
# 3582            flexible                  NaN  14585486
# 3584            flexible                  NaN  14504422
#
#                                 listing_url       scrape_id last_scraped  \
# 0     https://www.airbnb.com/rooms/12147973  20160906204935   2016-09-07
# 1      https://www.airbnb.com/rooms/3075044  20160906204935   2016-09-07
# 2         https://www.airbnb.com/rooms/6976  20160906204935   2016-09-07
# 3      https://www.airbnb.com/rooms/1436513  20160906204935   2016-09-07
# 4      https://www.airbnb.com/rooms/7651065  20160906204935   2016-09-07
# ...                                     ...             ...          ...
# 3576  https://www.airbnb.com/rooms/14689681  20160906204935   2016-09-07
# 3577  https://www.airbnb.com/rooms/13750763  20160906204935   2016-09-07
# 3579  https://www.airbnb.com/rooms/14852179  20160906204935   2016-09-07
# 3582  https://www.airbnb.com/rooms/14585486  20160906204935   2016-09-07
# 3584  https://www.airbnb.com/rooms/14504422  20160906204935   2016-09-07
#
#                                                    name  \
# 0                            Sunny Bungalow in the City
# 1                     Charming room in pet friendly apt
# 2                      Mexican Folk Art Haven in Boston
# 3         Spacious Sunny Bedroom Suite in Historic Home
# 4                                   Come Home to Boston
# ...                                                 ...
# 3576   Beautiful loft style bedroom with large bathroom
# 3577        Comfortable Space in the Heart of Brookline
# 3579  Spacious Queen Bed Room Close to Boston Univer...
# 3582                           Gorgeous funky apartment
# 3584                 (K1) Private Room near Harvard/MIT
#
#                                                 summary  \
# 0     Cozy, sunny, family home.  Master bedroom high...
# 1     Charming and quiet room in a second floor 1910...
# 2     Come stay with a friendly, middle-aged guy in ...
# 3     Come experience the comforts of home away from...
# 4     My comfy, clean and relaxing home is one block...
# ...                                                 ...
# 3576  You'd be living on the top floor of a four sto...
# 3577  Our place is close to Coolidge Corner, Allston...
# 3579  - Grocery: A full-size Star market is 2 minute...
# 3582  Funky little apartment close to public transpo...
# 3584  My place is close to My home is a warm and fri...
#
#                                                   space  \
# 0     The house has an open and cozy feel at the sam...
# 1     Small but cozy and quite room with a full size...
# 2     Come stay with a friendly, middle-aged guy in ...
# 3     Most places you find in Boston are small howev...
# 4     Clean, attractive, private room, one block fro...
# ...                                                 ...
# 3576                                                NaN
# 3577  This space consists of 2 Rooms and a private b...
# 3579                                                NaN
# 3582  Modern and relaxed space with many facilities ...
# 3584  To ensure a smooth check in: 1. You MUST have ...
#
#                                             description  ... requires_license  \
# 0     Cozy, sunny, family home.  Master bedroom high...  ...                f
# 1     Charming and quiet room in a second floor 1910...  ...                f
# 2     Come stay with a friendly, middle-aged guy in ...  ...                f
# 3     Come experience the comforts of home away from...  ...                f
# 4     My comfy, clean and relaxing home is one block...  ...                f
# ...                                                 ...  ...              ...
# 3576  You'd be living on the top floor of a four sto...  ...                f
# 3577  Our place is close to Coolidge Corner, Allston...  ...                f
# 3579  - Grocery: A full-size Star market is 2 minute...  ...                f
# 3582  Funky little apartment close to public transpo...  ...                f
# 3584  My place is close to My home is a warm and fri...  ...                f
#
#      license jurisdiction_names instant_bookable  \
# 0        NaN                NaN                f
# 1        NaN                NaN                t
# 2        NaN                NaN                f
# 3        NaN                NaN                f
# 4        NaN                NaN                f
# ...      ...                ...              ...
# 3576     NaN                NaN                f
# 3577     NaN                NaN                f
# 3579     NaN                NaN                f
# 3582     NaN                NaN                f
# 3584     NaN                NaN                t
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 0                                f                                f
# 1                                f                                f
# 2                                t                                f
# 3                                f                                f
# 4                                f                                f
# ...                            ...                              ...
# 3576                             f                                f
# 3577                             f                                f
# 3579                             f                                f
# 3582                             f                                f
# 3584                             f                                f
#
#      calculated_host_listings_count reviews_per_month mean_review_scores  \
# 0                                 1               NaN           9.307398
# 1                                 1              1.30           9.307398
# 2                                 1              0.47           9.307398
# 3                                 1              1.00           9.307398
# 4                                 1              2.25           9.237421
# ...                             ...               ...                ...
# 3576                              1               NaN           9.237421
# 3577                              1               NaN           9.237421
# 3579                              1               NaN           9.237421
# 3582                              1               NaN           9.237421
# 3584                              3               NaN           9.237421
#
#      mean_diff
# 0          NaN
# 1     0.307398
# 2     0.692602
# 3     0.692602
# 4     0.762579
# ...        ...
# 3576       NaN
# 3577       NaN
# 3579       NaN
# 3582       NaN
# 3584       NaN
#
# [1918 rows x 97 columns]

# %% [markdown]
#  ****
#
# ## Applying
#
# By far the most common operation invoked on groupby objects is the apply( ) function.
#
# apply( ) allows to apply an arbitrary function to each group, and stitch the results back for each apply( ) into a single dataframe where the index is preserved.
#
# **Example :**

# %%
df = pd.read_csv("datasets/listings.csv")      # loading the airbnb dataset

# let's consider some columns, such as : 
df = df[['cancellation_policy','review_scores_value']]
df.head()
# Out:
#   cancellation_policy  review_scores_value
# 0            moderate                  NaN
# 1            moderate                  9.0
# 2            moderate                 10.0
# 3            moderate                 10.0
# 4            flexible                 10.0

# %% [markdown]
# Previously, we found the average review score of a listing and its deviation from the group mean. This was a 2 step process. First, the transform( ) was used on the groupby object and then broadcast it to create a new column.
#
# With apply( ) this whole logic can be wrapped in a single go.

# %%
def calc_mean_review_scores(group):
    # group is a dataframe just of whatever we have grouped by, e.g. cancellation_policy, so we can treat
    # this as the complete dataframe
    avg = np.nanmean(group["review_scores_value"])
    
    # now broadcast our formula and create a new column
    group["review_scores_mean"] = np.abs(avg - group["review_scores_value"])
    return group

# Now just apply this to the groups
df.groupby('cancellation_policy').apply(calc_mean_review_scores).head()
# Out:
#   cancellation_policy  review_scores_value  review_scores_mean
# 0            moderate                  NaN                 NaN
# 1            moderate                  9.0            0.307398
# 2            moderate                 10.0            0.692602
# 3            moderate                 10.0            0.692602
# 4            flexible                 10.0            0.762579

# %% [markdown]
# Using apply can be slower than using some of the specialized functions, especially agg( ). But, if your dataframes are not huge, it's a solid general purpose approach.
#
# Groupby is a powerful and commonly used tool for data cleaning and data analysis.<br>Once you have grouped the data by some category you have a dataframe of just those values and you can conduct aggregated analsyis on the segments that you are interested. The groupby( ) function follows a split-apply-combine approach - first the data is split into subgroups, then you can apply some transformation, filtering, or aggregation, then the results are combined automatically by pandas for us.
#
# ****
#
#
# # Scales in Pandas
#
# Let's talk about scales and datatypes. Pandas supports a number of different computational data types such as strings, integers, floating point numbers - but it does not capture the "scale of data
#
# _Consider an example...._
#
# **Example :** Let's say that we have got a DataFrame of students and their academic levels such as being in grade 1, grade 2, and grade 3. <br>_Is the difference between a student in grade 1 and a student in grade 2 the same as the difference between a student in grade 8 and one in grade 9 ?_<br><br>Let's consider final exam scores these students might get on assignments.<br>_Is the difference between an A and an A- the same as the difference between an A- and a B+ ?_<br>At least, the answer is often no, when you're converting this to a percentage-based scale.
#
# Such examples depict some difference in scales.<br>As a data scientist, there's at least four different scales that's worth knowing about.
#
# 1. **Ratio scale :**
#     + Measurement units are equally spaced.
#     + Mathematical operations such as +, -, / and * are valid.
#     + valid examples can be like: height, wight, etc.
#
# 2. **Interval scale :**
#     + Like **ratio scale**, measurement units are equally spaced.
#     + There is no clear absence of value i.e. no true zero.<br>So, operations like * and / are not valid.
#     + valid example can be like: the temperature as measured in ˚C or ˚F since there's never an absence of temperature, and 0˚ (zero degrees) is actually a meaningful value itself.
#     + The direction on a compass can be another good example, where 0˚ on the compass doesn't indicate a lack of direction, but instead describes a direction itself.
#
# > For most of the work in data mining, the differences between the ratio and interval scales might not be clearly apparent or important to the algorithm, but it's important to have this distinction clear in mind when applying advanced statistical tests.
#
# 3. **Ordinal scale :**
#     + the order of the units is important, but differences between the values are not evenly spaced.
#     + valid example can be : A+, A are good example.
#     > Ordinal data is very common in machine learning and sometimes can be a bit of a challenge to work with.
#
# 4. **Nominal scale :**
#     + just called, **Categorical Data**
#     + good example : names of teams in a sport.<br>There are a limited number of teams, but changing their order or applying mathematical functions to them is meaningless.
#     > Categorical values are very common and we generally refer to categories where there are only two possible values as binary categories.
#
#
# Scales are important concept in statistics and machine learning.<br>Pandas offer numerous interesting functions to deal with converting between measurement scales.
# *****
#
# ### Example :

# %%
import pandas as pd

# Here’s an example.
# Lets create a dataframe of letter grades in descending order. We can also set an index
# value and here we'll just make it some human judgement of how good a student was, like "excellent" or "good"

df = pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
                index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 
                       'ok', 'ok', 'ok', 'poor', 'poor'],
               columns=["Grades"])
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
# datatype of this column is just an object as there are string values present in it.

df.dtypes
# Out:
# Grades    object
# dtype: object

# %% [markdown]
# To change the type to category, use astype( ) function.

# %%
df['Grades'].astype("category")
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): ['A', 'A+', 'A-', 'B', ..., 'C+', 'C-', 'D', 'D+']

# %% [markdown]
# Notice above output that there are eleven categories, and pandas is aware of what those categories are.
#
# More interesting though is that our data isn't just categorical, but that it's ordered i.e. an A- comes after a B+, and B comes before a B+.<br>We can tell pandas that the data is ordered by first creating a new categorical data type with the list of the categories (in order) and the ordered=True flag
#
# then, pass this to the astype( ) function

# %%
my_categories = pd.CategoricalDtype(categories = ['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'],
                                    ordered=True)

grades = df["Grades"].astype(my_categories)

grades
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): ['D' < 'D+' < 'C-' < 'C' ... 'B+' < 'A-' < 'A' < 'A+']

# %% [markdown]
# Now we see that pandas is not only aware that there are 11 categories, but it is also aware of the order of those categoreies.
#
# Well, because there is an ordering this can help with comparisons and boolean masking. For example, if we have a list of our grades and we compare them to a “C” we see that the lexicographical comparison returns unintended results.

# %%
df[df["Grades"] > "C"]
# Out:
#      Grades
# ok       C+
# ok       C-
# poor     D+
# poor      D

# %% [markdown]
# So, a C+ is greater than a C, but a C- and D certainly are not.
#
# If we broadcast over the dataframe which has the type set to an ordered categorical, i.e.

# %%
grades[grades > "C"]
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# Name: Grades, dtype: category
# Categories (11, object): ['D' < 'D+' < 'C-' < 'C' ... 'B+' < 'A-' < 'A' < 'A+']

# %% [markdown]
# Sometimes it is useful to represent categorical values as each being a column with a true or a false as to whether the category applies. This is especially common in feature extraction, which is a concept in data mining.<br>Variables with a boolean value are typically called dummy variables, and pandas has a built in function called get_dummies( ) which will convert the values of a single column into multiple columns of 0s and 1s indicating the presence of the dummy variable.
# ****

# %% [markdown]
# There’s one more common scale-based operation on converting a scale from something that is on the interval or ratio scale, like a numeric grade, into one which is categorical. Now, this might seem a bit counter intuitive, as you may losing information about the value. But it’s commonly done in a couple of places. For example, when visualizing the frequencies of categories, this can be an extremely useful approach, and histograms are regularly used with converted interval or ratio data.
#
# In addition, when using a machine learning classification approach on data, you need to be using categorical data, so reducing dimensionality may be useful just to apply a given technique.
#
# Pandas has a function called cut which takes as an argument some array-like structure like a column of a dataframe or a series. It also takes a number of bins to be used, and all bins are kept at equal spacing.
#
# **Example :** As previusly, we could group by state then aggregate to get a list of the average county size by state. If we further apply cut to this with, for eg., 10 bins, we can see the states listed as categoricals using the average county size.

# %%
import numpy as np
df = pd.read_csv("datasets/census.csv")

# reduce this to county-level data
df = df[df['SUMLEV'] == 50]

# And for a few groups
df = df.set_index('STNAME').groupby(level=0)['CENSUS2010POP'].agg(np.average)

df.head()
# Out:
# STNAME
# Alabama        71339.343284
# Alaska         24490.724138
# Arizona       426134.466667
# Arkansas       38878.906667
# California    642309.586207
# Name: CENSUS2010POP, dtype: float64

# %% [markdown]
# Now, let's make a "bins" of each of these - so, use cut( ) function.

# %%
pd.cut(df, 10)
# Out:
# STNAME
# Alabama                   (11706.087, 75333.413]
# Alaska                    (11706.087, 75333.413]
# Arizona                 (390320.176, 453317.529]
# Arkansas                  (11706.087, 75333.413]
# California              (579312.234, 642309.586]
# Colorado                 (75333.413, 138330.766]
# Connecticut             (390320.176, 453317.529]
# Delaware                (264325.471, 327322.823]
# District of Columbia    (579312.234, 642309.586]
# Florida                 (264325.471, 327322.823]
# Georgia                   (11706.087, 75333.413]
# Hawaii                  (264325.471, 327322.823]
# Idaho                     (11706.087, 75333.413]
# Illinois                 (75333.413, 138330.766]
# Indiana                   (11706.087, 75333.413]
# Iowa                      (11706.087, 75333.413]
# Kansas                    (11706.087, 75333.413]
# Kentucky                  (11706.087, 75333.413]
# Louisiana                 (11706.087, 75333.413]
# Maine                    (75333.413, 138330.766]
# Maryland                (201328.118, 264325.471]
# Massachusetts           (453317.529, 516314.881]
# Michigan                 (75333.413, 138330.766]
# Minnesota                 (11706.087, 75333.413]
# Mississippi               (11706.087, 75333.413]
# Missouri                  (11706.087, 75333.413]
# Montana                   (11706.087, 75333.413]
# Nebraska                  (11706.087, 75333.413]
# Nevada                  (138330.766, 201328.118]
# New Hampshire            (75333.413, 138330.766]
# New Jersey              (390320.176, 453317.529]
# New Mexico                (11706.087, 75333.413]
# New York                (264325.471, 327322.823]
# North Carolina           (75333.413, 138330.766]
# North Dakota              (11706.087, 75333.413]
# Ohio                     (75333.413, 138330.766]
# Oklahoma                  (11706.087, 75333.413]
# Oregon                   (75333.413, 138330.766]
# Pennsylvania            (138330.766, 201328.118]
# Rhode Island            (201328.118, 264325.471]
# South Carolina           (75333.413, 138330.766]
# South Dakota              (11706.087, 75333.413]
# Tennessee                 (11706.087, 75333.413]
# Texas                    (75333.413, 138330.766]
# Utah                     (75333.413, 138330.766]
# Vermont                   (11706.087, 75333.413]
# Virginia                  (11706.087, 75333.413]
# Washington              (138330.766, 201328.118]
# West Virginia             (11706.087, 75333.413]
# Wisconsin                (75333.413, 138330.766]
# Wyoming                   (11706.087, 75333.413]
# Name: CENSUS2010POP, dtype: category
# Categories (10, interval[float64, right]): [(11706.087, 75333.413] < (75333.413, 138330.766] < (138330.766, 201328.118] < (201328.118, 264325.471] ... (390320.176, 453317.529] < (453317.529, 516314.881] < (516314.881, 579312.234] < (579312.234, 642309.586]]

# %% [markdown]
# So notice that, the states like Alabama and Alaska fall into the same category, while California and the disctrict of Columbia fall in a very different category.
#
# Cutting is just one way to build categories from data, and there are many other methods.<br>For example, cut gives interval data, where the spacing between each category is equal sized. But sometimes, to form categories based on frequency – one may want the number of items in each bin to be the same, instead of the spacing between bins. So, It really depends on what the shape of data is, and what's planned to do.

# %% [markdown]
# *****
#
# # Pivot Table in Pandas
#
# A pivot table is a way of summarizing data in a DataFrame for a particular purpose. It makes heavy use of the aggregation function - agg( ).
#
# A pivot table is in itself a DataFrame, where the rows represent 1 variable that you're interested in, the columns another, and then the cells some aggregate value. A pivot table also tends to include marginal values as well, which are sum for each column and row.<br>This allows to  see the relationship between two variables at just a glance.
#
# **Example :**<br>Let's undertsnad this concept with a dataset of the Times Higher Education World University Ranking, which is one of the most influential university measures.
#
# _Let's say we want to create a new column called "Rank_Level", where institutions with world ranking 1-100 are categorized as 1st tier and those with world ranking 101 - 200 are 2nd tier, ranking 201 - 300 are 3rd tier, after 301 are other top universities._

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./datasets/cwurData.csv')
df
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# 0                 1                     7                  9
# 1                 2                     9                 17
# 2                 3                    17                 11
# 3                 1                    10                 24
# 4                 4                     2                 29
# ...             ...                   ...                ...
# 2195              7                   367                567
# 2196              4                   236                566
# 2197             18                   367                549
# 2198             40                   367                567
# 2199             83                   367                567
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# 0                      1             1          1          1           NaN
# 1                      3            12          4          4           NaN
# 2                      5             4          2          2           NaN
# 3                      4            16         16         11           NaN
# 4                      7            37         22         22           NaN
# ...                  ...           ...        ...        ...           ...
# 2195                 218           926        845        812         969.0
# 2196                 218           997        908        645         981.0
# 2197                 218           830        823        812         975.0
# 2198                 218           886        974        812         975.0
# 2199                 218           861        991        812         981.0
#
#       patents   score  year
# 0           5  100.00  2012
# 1           1   91.67  2012
# 2          15   89.50  2012
# 3          50   86.17  2012
# 4          18   85.21  2012
# ...       ...     ...   ...
# 2195      816   44.03  2015
# 2196      871   44.03  2015
# 2197      824   44.03  2015
# 2198      651   44.02  2015
# 2199      547   44.02  2015
#
# [2200 rows x 14 columns]

# %%
def create_category(ranking):
    if (ranking >= 1) & (ranking <= 100):
        return "First Tier Top Unversity"
    elif (ranking >= 101) & (ranking <= 200):
        return "Second Tier Top Unversity"
    elif (ranking >= 201) & (ranking <= 300):
        return "Third Tier Top Unversity"
    return "Other Top Unversity"

# Now, apply this to a single column of data to create a new series
df['Rank_Level'] = df['world_rank'].apply(lambda x: create_category(x))

df
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# 0                 1                     7                  9
# 1                 2                     9                 17
# 2                 3                    17                 11
# 3                 1                    10                 24
# 4                 4                     2                 29
# ...             ...                   ...                ...
# 2195              7                   367                567
# 2196              4                   236                566
# 2197             18                   367                549
# 2198             40                   367                567
# 2199             83                   367                567
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# 0                      1             1          1          1           NaN
# 1                      3            12          4          4           NaN
# 2                      5             4          2          2           NaN
# 3                      4            16         16         11           NaN
# 4                      7            37         22         22           NaN
# ...                  ...           ...        ...        ...           ...
# 2195                 218           926        845        812         969.0
# 2196                 218           997        908        645         981.0
# 2197                 218           830        823        812         975.0
# 2198                 218           886        974        812         975.0
# 2199                 218           861        991        812         981.0
#
#       patents   score  year                Rank_Level
# 0           5  100.00  2012  First Tier Top Unversity
# 1           1   91.67  2012  First Tier Top Unversity
# 2          15   89.50  2012  First Tier Top Unversity
# 3          50   86.17  2012  First Tier Top Unversity
# 4          18   85.21  2012  First Tier Top Unversity
# ...       ...     ...   ...                       ...
# 2195      816   44.03  2015       Other Top Unversity
# 2196      871   44.03  2015       Other Top Unversity
# 2197      824   44.03  2015       Other Top Unversity
# 2198      651   44.02  2015       Other Top Unversity
# 2199      547   44.02  2015       Other Top Unversity
#
# [2200 rows x 15 columns]

# %% [markdown]
# ___A pivot table allows to pivot out one of these columns into a new column headers and compare it against another column as row indices.___
#
# **Example :** Let's say we want to compare rank level versus country of the universities and we want to compare in terms of overall score ?
#
# To do this, we tell Pandas we want the values to be Score, and index to be the country and the columns to be the rank levels. Then we specify that the aggregation function, like the NumPy mean to get the average rating for universities in that country.

# %%
df.pivot_table(values='score', index='country', columns='Rank_Level', aggfunc=[np.mean, np.max])
# Out:
#                                          mean                      \
# Rank_Level           First Tier Top Unversity Other Top Unversity
# country
# Argentina                                 NaN           44.672857
# Australia                           47.942500           44.645750
# Austria                                   NaN           44.864286
# Belgium                             51.875000           45.081000
# Brazil                                    NaN           44.499706
# Bulgaria                                  NaN           44.335000
# Canada                              53.633846           44.760541
# Chile                                     NaN           44.767500
# China                               53.592500           44.564267
# Colombia                                  NaN           44.432500
# Croatia                                   NaN           44.770000
# Cyprus                                    NaN           44.210000
# Czech Republic                            NaN           44.587778
# Denmark                             49.180000           45.177500
# Egypt                                     NaN           44.230000
# Estonia                                   NaN           44.810000
# Finland                             44.415000           45.062500
# France                              51.914444           44.609028
# Germany                             49.153636           44.978305
# Greece                                    NaN           44.854286
# Hong Kong                                 NaN           45.284286
# Hungary                                   NaN           44.603333
# Iceland                                   NaN           44.980000
# India                                     NaN           44.713226
# Iran                                      NaN           44.270000
# Ireland                                   NaN           44.542500
# Israel                              56.307143           45.013333
# Italy                               48.736667           44.964177
# Japan                               58.812692           44.641583
# Lebanon                                   NaN           44.655000
# Lithuania                                 NaN           44.355000
# Malaysia                                  NaN           45.008333
# Mexico                                    NaN           45.102500
# Netherlands                         48.378333           45.163333
# New Zealand                               NaN           44.832000
# Norway                              47.056667           44.950000
# Poland                                    NaN           44.497222
# Portugal                                  NaN           44.717273
# Puerto Rico                               NaN           44.175000
# Romania                                   NaN           44.133333
# Russia                              51.846667           44.462500
# Saudi Arabia                              NaN           44.511250
# Serbia                                    NaN           44.420000
# Singapore                           50.720000                 NaN
# Slovak Republic                           NaN           44.490000
# Slovenia                                  NaN           44.615000
# South Africa                              NaN           45.246667
# South Korea                         55.990000           44.805714
# Spain                                     NaN           44.724730
# Sweden                              50.672000           45.272500
# Switzerland                         54.005000           44.625000
# Taiwan                              54.210000           44.476667
# Thailand                                  NaN           44.830000
# Turkey                                    NaN           44.481000
# USA                                 61.066726           44.871718
# Uganda                                    NaN           44.280000
# United Arab Emirates                      NaN           44.220000
# United Kingdom                      63.937931           44.881299
# Uruguay                                   NaN           44.255000
#
#                                                                          \
# Rank_Level           Second Tier Top Unversity Third Tier Top Unversity
# country
# Argentina                                  NaN                      NaN
# Australia                            49.242500                47.285000
# Austria                                    NaN                47.066667
# Belgium                              49.084000                46.746667
# Brazil                               49.565000                      NaN
# Bulgaria                                   NaN                      NaN
# Canada                               49.218182                46.826364
# Chile                                      NaN                      NaN
# China                                47.868000                46.926250
# Colombia                                   NaN                      NaN
# Croatia                                    NaN                      NaN
# Cyprus                                     NaN                      NaN
# Czech Republic                             NaN                46.320000
# Denmark                              48.965000                      NaN
# Egypt                                      NaN                      NaN
# Estonia                                    NaN                      NaN
# Finland                              50.400000                      NaN
# France                               48.888571                47.125833
# Germany                              48.695556                46.910370
# Greece                                     NaN                      NaN
# Hong Kong                            48.625000                47.100000
# Hungary                                    NaN                      NaN
# Iceland                                    NaN                      NaN
# India                                      NaN                      NaN
# Iran                                       NaN                      NaN
# Ireland                              47.845000                46.780000
# Israel                               50.005000                      NaN
# Italy                                48.618000                46.861111
# Japan                                49.157143                46.546667
# Lebanon                                    NaN                      NaN
# Lithuania                                  NaN                      NaN
# Malaysia                                   NaN                      NaN
# Mexico                                     NaN                      NaN
# Netherlands                          49.963636                46.656667
# New Zealand                                NaN                46.515000
# Norway                               50.700000                46.446667
# Poland                                     NaN                      NaN
# Portugal                                   NaN                46.480000
# Puerto Rico                                NaN                      NaN
# Romania                                    NaN                      NaN
# Russia                                     NaN                46.520000
# Saudi Arabia                               NaN                      NaN
# Serbia                                     NaN                      NaN
# Singapore                            49.320000                      NaN
# Slovak Republic                            NaN                      NaN
# Slovenia                                   NaN                      NaN
# South Africa                         49.575000                46.680000
# South Korea                          49.136667                47.490000
# Spain                                49.310000                46.675000
# Sweden                               49.306250                46.456667
# Switzerland                          48.184000                47.930000
# Taiwan                                     NaN                47.065000
# Thailand                                   NaN                46.550000
# Turkey                                     NaN                      NaN
# USA                                  49.069524                46.818333
# Uganda                                     NaN                      NaN
# United Arab Emirates                       NaN                      NaN
# United Kingdom                       48.957500                46.862273
# Uruguay                                    NaN                      NaN
#
#                                          amax                      \
# Rank_Level           First Tier Top Unversity Other Top Unversity
# country
# Argentina                                 NaN               45.66
# Australia                               51.61               45.97
# Austria                                   NaN               46.29
# Belgium                                 52.03               46.21
# Brazil                                    NaN               46.08
# Bulgaria                                  NaN               44.48
# Canada                                  60.87               45.74
# Chile                                     NaN               45.33
# China                                   55.30               45.92
# Colombia                                  NaN               44.85
# Croatia                                   NaN               44.92
# Cyprus                                    NaN               44.32
# Czech Republic                            NaN               46.23
# Denmark                                 52.94               45.83
# Egypt                                     NaN               44.52
# Estonia                                   NaN               44.94
# Finland                                 44.44               45.69
# France                                  59.72               45.55
# Germany                                 52.75               46.31
# Greece                                    NaN               46.06
# Hong Kong                                 NaN               45.77
# Hungary                                   NaN               45.69
# Iceland                                   NaN               45.05
# India                                     NaN               46.10
# Iran                                      NaN               44.58
# Ireland                                   NaN               45.25
# Israel                                  66.76               45.76
# Italy                                   52.12               46.30
# Japan                                   80.64               45.97
# Lebanon                                   NaN               44.93
# Lithuania                                 NaN               44.46
# Malaysia                                  NaN               46.23
# Mexico                                    NaN               45.99
# Netherlands                             52.42               45.82
# New Zealand                               NaN               45.80
# Norway                                  50.81               46.31
# Poland                                    NaN               45.45
# Portugal                                  NaN               45.91
# Puerto Rico                               NaN               44.29
# Romania                                   NaN               44.32
# Russia                                  56.42               45.14
# Saudi Arabia                              NaN               45.45
# Serbia                                    NaN               44.51
# Singapore                               53.52                 NaN
# Slovak Republic                           NaN               44.60
# Slovenia                                  NaN               45.02
# South Africa                              NaN               46.26
# South Korea                             66.06               46.23
# Spain                                     NaN               46.34
# Sweden                                  53.64               46.32
# Switzerland                             72.18               45.05
# Taiwan                                  54.23               45.49
# Thailand                                  NaN               45.86
# Turkey                                    NaN               45.57
# USA                                    100.00               46.30
# Uganda                                    NaN               44.40
# United Arab Emirates                      NaN               44.36
# United Kingdom                          97.64               46.30
# Uruguay                                   NaN               44.35
#
#
# Rank_Level           Second Tier Top Unversity Third Tier Top Unversity
# country
# Argentina                                  NaN                      NaN
# Australia                                50.40                    47.47
# Austria                                    NaN                    47.78
# Belgium                                  49.73                    47.14
# Brazil                                   49.82                      NaN
# Bulgaria                                   NaN                      NaN
# Canada                                   51.23                    47.69
# Chile                                      NaN                      NaN
# China                                    48.14                    47.76
# Colombia                                   NaN                      NaN
# Croatia                                    NaN                      NaN
# Cyprus                                     NaN                      NaN
# Czech Republic                             NaN                    46.32
# Denmark                                  50.17                      NaN
# Egypt                                      NaN                      NaN
# Estonia                                    NaN                      NaN
# Finland                                  50.76                      NaN
# France                                   50.34                    47.54
# Germany                                  50.58                    47.73
# Greece                                     NaN                      NaN
# Hong Kong                                49.10                    47.83
# Hungary                                    NaN                      NaN
# Iceland                                    NaN                      NaN
# India                                      NaN                      NaN
# Iran                                       NaN                      NaN
# Ireland                                  47.96                    46.79
# Israel                                   50.89                      NaN
# Italy                                    49.97                    47.59
# Japan                                    50.13                    47.00
# Lebanon                                    NaN                      NaN
# Lithuania                                  NaN                      NaN
# Malaysia                                   NaN                      NaN
# Mexico                                     NaN                      NaN
# Netherlands                              51.29                    47.11
# New Zealand                                NaN                    46.65
# Norway                                   50.70                    46.67
# Poland                                     NaN                      NaN
# Portugal                                   NaN                    46.59
# Puerto Rico                                NaN                      NaN
# Romania                                    NaN                      NaN
# Russia                                     NaN                    46.55
# Saudi Arabia                               NaN                      NaN
# Serbia                                     NaN                      NaN
# Singapore                                49.35                      NaN
# Slovak Republic                            NaN                      NaN
# Slovenia                                   NaN                      NaN
# South Africa                             50.40                    46.78
# South Korea                              50.95                    47.79
# Spain                                    50.17                    46.99
# Sweden                                   50.34                    46.79
# Switzerland                              49.17                    47.93
# Taiwan                                     NaN                    47.16
# Thailand                                   NaN                    46.55
# Turkey                                     NaN                      NaN
# USA                                      51.27                    47.82
# Uganda                                     NaN                      NaN
# United Arab Emirates                       NaN                      NaN
# United Kingdom                           49.97                    47.74
# Uruguay                                    NaN                      NaN

# %% [markdown]
# Notice that, it's a  hierarchical dataframe where the index (or, rows) are by country and the columns have 2 levels, the top level indicating that the mean value is being used and the 2nd level being the ranks.
#
# In this example we only have 1 variable, the mean, that we are looking at, so we don't really need a heirarchical index.
#
# Also notice that there are some NaN values.<br>For instance with Argentina, the NaN values indicate that Argentia has only observations in the "Other Top Unversities" category.
#
# ****
#
# Pivot tables are not limited to 1 function to apply for.<br>To perform on more than 1 function, pass a named parameter, aggfunc, which is a list of the different functions to apply, and pandas will evaluate it using hierarchical column names.
#
# **Example :** Let's try that same query, but pass in the max( ) function too.

# %%
df.pivot_table(values='score', index='country', columns='Rank_Level', aggfunc=[np.mean, np.max]).head()
# Out:
#                                mean                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN           44.672857
# Australia                   47.9425           44.645750
# Austria                         NaN           44.864286
# Belgium                     51.8750           45.081000
# Brazil                          NaN           44.499706
#
#                                                                \
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity
# country
# Argentina                        NaN                      NaN
# Australia                    49.2425                47.285000
# Austria                          NaN                47.066667
# Belgium                      49.0840                46.746667
# Brazil                       49.5650                      NaN
#
#                                amax                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN               45.66
# Australia                     51.61               45.97
# Austria                         NaN               46.29
# Belgium                       52.03               46.21
# Brazil                          NaN               46.08
#
#
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity
# country
# Argentina                        NaN                      NaN
# Australia                      50.40                    47.47
# Austria                          NaN                    47.78
# Belgium                        49.73                    47.14
# Brazil                         49.82                      NaN

# %% [markdown]
# So now, output has both the mean and the max.
# ****
# As mentioned earlier, the values within a given top level column can be summarised also.
# For instance, if we want to see an overall average for the country with the mean and we want to see the max of the max, we can indicate that we want pandas to provide marginal values.

# %%
df.pivot_table(values='score', index='country', columns='Rank_Level', aggfunc=[np.mean, np.max], 
               margins=True).head()

# an extra parameter, i.e. margins=True, is added here.
# Out:
#                                mean                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN           44.672857
# Australia                   47.9425           44.645750
# Austria                         NaN           44.864286
# Belgium                     51.8750           45.081000
# Brazil                          NaN           44.499706
#
#                                                                           \
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity        All
# country
# Argentina                        NaN                      NaN  44.672857
# Australia                    49.2425                47.285000  45.825517
# Austria                          NaN                47.066667  45.139583
# Belgium                      49.0840                46.746667  47.011000
# Brazil                       49.5650                      NaN  44.781111
#
#                                amax                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN               45.66
# Australia                     51.61               45.97
# Austria                         NaN               46.29
# Belgium                       52.03               46.21
# Brazil                          NaN               46.08
#
#
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity    All
# country
# Argentina                        NaN                      NaN  45.66
# Australia                      50.40                    47.47  51.61
# Austria                          NaN                    47.78  47.78
# Belgium                        49.73                    47.14  52.03
# Brazil                         49.82                      NaN  49.82

# %% [markdown]
# > ___A pivot table is just a multi-level dataframe, and we can access series or cells in the dataframe in a similar way as we do so for a regular dataframe.___
#
# ****

# %%
new_df = df.pivot_table(values='score', index='country', columns='Rank_Level', aggfunc=[np.mean, np.max], 
               margins=True)

print(new_df.index)

# let's look at the columns
print(new_df.columns)
# Out:
# Index(['Argentina', 'Australia', 'Austria', 'Belgium', 'Brazil', 'Bulgaria',
#        'Canada', 'Chile', 'China', 'Colombia', 'Croatia', 'Cyprus',
#        'Czech Republic', 'Denmark', 'Egypt', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Iran',
#        'Ireland', 'Israel', 'Italy', 'Japan', 'Lebanon', 'Lithuania',
#        'Malaysia', 'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Poland',
#        'Portugal', 'Puerto Rico', 'Romania', 'Russia', 'Saudi Arabia',
#        'Serbia', 'Singapore', 'Slovak Republic', 'Slovenia', 'South Africa',
#        'South Korea', 'Spain', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand',
#        'Turkey', 'USA', 'Uganda', 'United Arab Emirates', 'United Kingdom',
#        'Uruguay', 'All'],
#       dtype='object', name='country')
# MultiIndex([('mean',  'First Tier Top Unversity'),
#             ('mean',       'Other Top Unversity'),
#             ('mean', 'Second Tier Top Unversity'),
#             ('mean',  'Third Tier Top Unversity'),
#             ('mean',                       'All'),
#             ('amax',  'First Tier Top Unversity'),
#             ('amax',       'Other Top Unversity'),
#             ('amax', 'Second Tier Top Unversity'),
#             ('amax',  'Third Tier Top Unversity'),
#             ('amax',                       'All')],
#            names=[None, 'Rank_Level'])

# %% [markdown]
# Notice that the columns are hierarchical.<br>The top level column indices have two categories: mean and max.<br>The lower level column indices have four categories, which are the four rank levels.
#
# _If we want to get the average scores of First Tier Top Unversity levels in each country ?_<br>We would just need to make two dataframe projections, the first for the mean, then the second for the top tier.

# %%
new_df['mean']['First Tier Top Unversity']
# Out:
# country
# Argentina                     NaN
# Australia               47.942500
# Austria                       NaN
# Belgium                 51.875000
# Brazil                        NaN
# Bulgaria                      NaN
# Canada                  53.633846
# Chile                         NaN
# China                   53.592500
# Colombia                      NaN
# Croatia                       NaN
# Cyprus                        NaN
# Czech Republic                NaN
# Denmark                 49.180000
# Egypt                         NaN
# Estonia                       NaN
# Finland                 44.415000
# France                  51.914444
# Germany                 49.153636
# Greece                        NaN
# Hong Kong                     NaN
# Hungary                       NaN
# Iceland                       NaN
# India                         NaN
# Iran                          NaN
# Ireland                       NaN
# Israel                  56.307143
# Italy                   48.736667
# Japan                   58.812692
# Lebanon                       NaN
# Lithuania                     NaN
# Malaysia                      NaN
# Mexico                        NaN
# Netherlands             48.378333
# New Zealand                   NaN
# Norway                  47.056667
# Poland                        NaN
# Portugal                      NaN
# Puerto Rico                   NaN
# Romania                       NaN
# Russia                  51.846667
# Saudi Arabia                  NaN
# Serbia                        NaN
# Singapore               50.720000
# Slovak Republic               NaN
# Slovenia                      NaN
# South Africa                  NaN
# South Korea             55.990000
# Spain                         NaN
# Sweden                  50.672000
# Switzerland             54.005000
# Taiwan                  54.210000
# Thailand                      NaN
# Turkey                        NaN
# USA                     61.066726
# Uganda                        NaN
# United Arab Emirates          NaN
# United Kingdom          63.937931
# Uruguay                       NaN
# All                     58.350675
# Name: First Tier Top Unversity, dtype: float64

# %% [markdown]
# Notice that the output is a series object which can be confirmed by printing the type.<br>
# > Remember that, projecting a single column of values out of a DataFrame gives a series.

# %%
type(new_df["mean"]["First Tier Top Unversity"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ****
#
# __Example :__ *Let's find the country that has the maximum average score on 1st Tier Top University level ?*
#
# Use the **idxmax( )** function to achieve this.
#
# (idxmax is a built in function to the Series object.)

# %%
new_df["mean"]["First Tier Top Unversity"].idxmax()
# Out:
# 'United Kingdom'

# %% [markdown]
# ****
#
# ## Stacking & Unstacking
#
# To achieve a different shape of pivot table, it can be done with the stack( ) and unstack( ) functions.
#
# Stacking is pivoting the lowermost column index to become the innermost row index.
#
# Unstacking is the inverse of stacking, pivoting the innermost row index to become the lowermost column index.
#
# **Example :**
#
# In the original pivot table, rank levels are the lowermost column.<br>See below :

# %%
new_df.head()
# Out:
#                                mean                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN           44.672857
# Australia                   47.9425           44.645750
# Austria                         NaN           44.864286
# Belgium                     51.8750           45.081000
# Brazil                          NaN           44.499706
#
#                                                                           \
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity        All
# country
# Argentina                        NaN                      NaN  44.672857
# Australia                    49.2425                47.285000  45.825517
# Austria                          NaN                47.066667  45.139583
# Belgium                      49.0840                46.746667  47.011000
# Brazil                       49.5650                      NaN  44.781111
#
#                                amax                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# Argentina                       NaN               45.66
# Australia                     51.61               45.97
# Austria                         NaN               46.29
# Belgium                       52.03               46.21
# Brazil                          NaN               46.08
#
#
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity    All
# country
# Argentina                        NaN                      NaN  45.66
# Australia                      50.40                    47.47  51.61
# Austria                          NaN                    47.78  47.78
# Belgium                        49.73                    47.14  52.03
# Brazil                         49.82                      NaN  49.82

# %%
# stacking - the rank levels become the innermost index, thus appearing to the right just after country.
new_df = new_df.stack()
new_df
# Out:
#                                           mean    amax
# country   Rank_Level
# Argentina Other Top Unversity        44.672857   45.66
#           All                        44.672857   45.66
# Australia First Tier Top Unversity   47.942500   51.61
#           Other Top Unversity        44.645750   45.97
#           Second Tier Top Unversity  49.242500   50.40
# ...                                        ...     ...
# All       First Tier Top Unversity   58.350675  100.00
#           Other Top Unversity        44.738871   46.34
#           Second Tier Top Unversity  49.065450   51.29
#           Third Tier Top Unversity   46.843450   47.93
#           All                        47.798395  100.00
#
# [193 rows x 2 columns]

# %%
# unstacking - thus, it has restored our dataframe to its original shape.
new_df.unstack().head()
# Out:
#                                mean                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# All                       58.350675           44.738871
# Argentina                       NaN           44.672857
# Australia                 47.942500           44.645750
# Austria                         NaN           44.864286
# Belgium                   51.875000           45.081000
#
#                                                                           \
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity        All
# country
# All                         49.06545                46.843450  47.798395
# Argentina                        NaN                      NaN  44.672857
# Australia                   49.24250                47.285000  45.825517
# Austria                          NaN                47.066667  45.139583
# Belgium                     49.08400                46.746667  47.011000
#
#                                amax                      \
# Rank_Level First Tier Top Unversity Other Top Unversity
# country
# All                          100.00               46.34
# Argentina                       NaN               45.66
# Australia                     51.61               45.97
# Austria                         NaN               46.29
# Belgium                       52.03               46.21
#
#
# Rank_Level Second Tier Top Unversity Third Tier Top Unversity     All
# country
# All                            51.29                    47.93  100.00
# Argentina                        NaN                      NaN   45.66
# Australia                      50.40                    47.47   51.61
# Austria                          NaN                    47.78   47.78
# Belgium                        49.73                    47.14   52.03

# %%
new_df.unstack().unstack()

# this would actually end up unstacking all the way to just a single column, so a series object is returned.
# This column is just a "value", the meaning of which is denoted by the hierarchical index of operation, rank, and county.
# Out:
#       Rank_Level                country
# mean  First Tier Top Unversity  All                      58.350675
#                                 Argentina                      NaN
#                                 Australia                47.942500
#                                 Austria                        NaN
#                                 Belgium                  51.875000
#                                                            ...
# amax  All                       USA                     100.000000
#                                 Uganda                   44.400000
#                                 United Arab Emirates     44.360000
#                                 United Kingdom           97.640000
#                                 Uruguay                  44.350000
# Length: 600, dtype: float64

# %% [markdown]
# Pivot tables are incredibly useful when dealing with numeric data, especially if when trying to summarize the data in some form.
# ****

# %% [markdown]
# # Date/Time functionality in Pandas
#
# Manipulating dates and times is quite flexible in Pandas and thus allows to conduct more analysis such as time series analysis.<br>Actually, Pandas was originally created by Wes McKinney to handle date and time data when he worked as a consultant for hedge funds, and truly Pandas proves to be robust in this matter.
#
# Pandas has four main time related classes:
# - Timestamp
# - DatetimeIndex
# - Period
# - PeriodIndex

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Timestamp
# It represents a single timestamp and associates values with points in time.
#
# Timestamp is inter-changeable with Python's datetime in most cases.

# %%
pd.Timestamp('06/01/2018 9:05PM')    # 01-June-2018
# Out:
# Timestamp('2018-06-01 21:05:00')

# %%
# Also, create a timestamp by passing multiple parameters such as year, month, date, hour,
# minute, separately

pd.Timestamp(2018, 6, 1, 21, 5)
# Out:
# Timestamp('2018-06-01 21:05:00')

# %% [markdown]
# Timestamp also has some useful attributes, such as **isoweekday( )**, which shows the weekday of the timestamp.<br>Note that,<br>1 => Monday, and<br>7 => Sunday

# %%
pd.Timestamp(2018, 6, 1, 0, 0).isoweekday()
# Out:
# 5

# %%
pd.Timestamp(2018, 6, 1, 0, 0).day_name()
# Out:
# 'Friday'

# %%
# to extract the specific year, month, day, hour, minute, second from a timestamp
pd.Timestamp(2020, 3, 15, 4, 11, 23).second
# Out:
# 23

# %% [markdown]
# ****
# ### Period
#
# In Period, the concept is not about a specific point in time but instead, a span of time.<br>Period represents a single time span, such as a specific day or month.

# %%
pd.Period("11/2020")
# Out:
# Period('2020-11', 'M')

# %% [markdown]
# Notice above that the granularity of the period is "M" for month, since that was the finest grained piece provided.
#
# Here's an example of a period that is September 29th, 2020.

# %%
pd.Period('29/09/2020')

# it has granularity of day i.e. "D"
# Out:
# Period('2020-09-29', 'D')

# %% [markdown]
# Period objects represent the full timespan that is specified.
#
# Arithmetic operations on period is very easy and
# intuitive, for example, to find out 5 months after January 2020, simply plus 5.

# %%
pd.Period('1/2020') + 5

# output is June 2020
# Out:
# Period('2020-06', 'M')

# %%
pd.Period('3/2020') - 5

# 5 months before March 2020 is October 2019.
# Out:
# Period('2019-12', 'M')

# %% [markdown]
# > The key here is that the Period object encapsulates the granularity for arithmetic.
# ****
#
# ### DatetimeIndex and PeriodIndex
#
# The index of a timestamp is DatetimeIndex.
#
# **Example :**<br> First, let's create our example series t1, we'll use the Timestamp of September 1st, 2nd and 3rd of 2016. When we look at the series, each Timestamp is the index and has a value associated with it, in this case, a, b and c.

# %%
t1 = pd.Series(list("abc"), [pd.Timestamp("2016-09-01"), pd.Timestamp("2016-09-02"),
                         pd.Timestamp("2016-09-03")])
t1
# Out:
# 2016-09-01    a
# 2016-09-02    b
# 2016-09-03    c
# dtype: object

# %%
# looking at the type of series index, we see it is DatetimeIndex.

type(t1.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# Period-based index can be created as well.

# %%
t2 = pd.Series(list("def"), [pd.Period("2016-09"), pd.Period("2016-09"),
                           pd.Period("2016-09")])

t2
# Out:
# 2016-09    d
# 2016-09    e
# 2016-09    f
# Freq: M, dtype: object

# %%
#  looking at the type of series index, we see it is PeriodIndex.

type(t2.index)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %% [markdown]
# ****
# ### Converting to Datetime
# This feature of pandas is helpful to convert a bunch of different data-time formats into a standard format, using the function ___to_datetime()___.
#
#
# **Example :**<br>Suppose we have a list of dates as strings and we want to create a new dataframe

# %%
d1 = ["29 September 2018", "Nov 25, 2019", "2015-06-26", "7/12/18"]


ts3 = pd.DataFrame(np.random.randint(10, 100, (4,2)), index=d1,
                   columns=list("ab"))

ts3
# Out:
#                     a   b
# 29 September 2018  50  63
# Nov 25, 2019       23  90
# 2015-06-26         11  86
# 7/12/18            21  94

# %% [markdown]
# Let's convert the index of ts3 in a standard format.

# %%
ts3.index = pd.to_datetime(ts3.index)
ts3
# Out:
#              a   b
# 2018-09-29  50  63
# 2019-11-25  23  90
# 2015-06-26  11  86
# 2018-07-12  21  94

# %% [markdown]
# > to_datetime( ) also has options to change the date parse order. For example, pass in the argument __dayfirst=True__ to parse the date in European format.

# %%
# the date string here looks ambiguous, as looking at it can't be certainly said
# as what looks to be the day or month or even year. 

pd.to_datetime("4.11.10", dayfirst=True)
# Out:
# Timestamp('2010-11-04 00:00:00')

# %% [markdown]
# ****
# ### Timedelta
#
# Timedeltas are differences in times. This is not the same as a a period, but conceptually similar.
#
# **Example :**<br>To take the difference between September 3rd and  September 1st, we get a Timedelta of two days.

# %%
pd.Timestamp('9/3/2021') - pd.Timestamp('9/1/2021')
# Out:
# Timedelta('2 days 00:00:00')

# %%
pd.Timestamp('9/3/2021') - pd.Timestamp('9/1/2021 9:30AM')
# Out:
# Timedelta('1 days 14:30:00')

# %% [markdown]
# Find what the date & time is after 12 days and 3 hours past September 2nd, at 8:10 AM.

# %%
# so here, a timedelta must be added in the timestamp.

pd.Timestamp('9/2/2016 8:10AM') + pd.Timedelta('12D 3H')
# Out:
# Timestamp('2016-09-14 11:10:00')

# %% [markdown]
# ****
# ### Offset
#
# Offset is similar to timedelta, but it follows specific calendar duration rules.
#
# Offset allows flexibility in terms of types of time intervals. Besides hour, day, week, month, etc it also has business day, end-of-month, semi-month-begin etc
#
# **some examples :**
# 1. add timestamp with a week ahead

# %%
pd.Timestamp("9/4/2021") + pd.offsets.Week()
# Out:
# Timestamp('2021-09-11 00:00:00')

# %% [markdown]
# 2. let's do _end-of-month_

# %%
pd.Timestamp("9/4/2021") + pd.offsets.MonthEnd()


# so, it will give end of September month
# Out:
# Timestamp('2021-09-30 00:00:00')

# %% [markdown]
# ### Some tricks to work with Dates in a DataFrame
#
# Suppose we want to look at nine measurements, taken bi-weekly, every Sunday, starting in October 2020. Using date_range, we can create this DatetimeIndex. In data_range, we have to either specify the start or end date. If it is not explicitly specified, by default, the date is considered the start date. Then we have to specify number of periods, and a frequency. Here, let's suppose it is "2W-SUN", which means "biweekly on Sunday"

# %%
dates = pd.date_range('10-01-2020', periods=9, freq="2W-SUN")
dates
# Out:
# DatetimeIndex(['2020-10-04', '2020-10-18', '2020-11-01', '2020-11-15',
#                '2020-11-29', '2020-12-13', '2020-12-27', '2021-01-10',
#                '2021-01-24'],
#               dtype='datetime64[ns]', freq='2W-SUN')

# %% [markdown]
# Some other frequencies, available in Pandas doc, can be :
# - "business day" or "B"

# %%
d1 = pd.date_range('10-01-2021', periods=9, freq="B")
d1
# Out:
# DatetimeIndex(['2021-10-01', '2021-10-04', '2021-10-05', '2021-10-06',
#                '2021-10-07', '2021-10-08', '2021-10-11', '2021-10-12',
#                '2021-10-13'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# - "quaterly" or "QS-JUN"

# %%
d2 = pd.date_range('10-01-2021', periods=9, freq="QS-JUN")
d2
# Out:
# DatetimeIndex(['2021-12-01', '2022-03-01', '2022-06-01', '2022-09-01',
#                '2022-12-01', '2023-03-01', '2023-06-01', '2023-09-01',
#                '2023-12-01'],
#               dtype='datetime64[ns]', freq='QS-JUN')

# %% [markdown]
# ****
# Let's create some data.

# %%
dates = pd.date_range('10-01-2016', periods=9, freq='2W-SUN')
df = pd.DataFrame({'Count 1': 100 + np.random.randint(-5, 10, 9).cumsum(),
                   'Count 2': 120 + np.random.randint(-5, 10, 9)},
                   index=dates)
df
# Out:
#             Count 1  Count 2
# 2016-10-02      103      126
# 2016-10-16      101      124
# 2016-10-30      104      126
# 2016-11-13      111      127
# 2016-11-27      113      123
# 2016-12-11      114      127
# 2016-12-25      113      116
# 2017-01-08      109      117
# 2017-01-22      113      117

# %%
df.index
# Out:
# DatetimeIndex(['2016-10-02', '2016-10-16', '2016-10-30', '2016-11-13',
#                '2016-11-27', '2016-12-11', '2016-12-25', '2017-01-08',
#                '2017-01-22'],
#               dtype='datetime64[ns]', freq='2W-SUN')

# %%
# to find difference between each date's value

df.diff()
# Out:
#             Count 1  Count 2
# 2016-10-02      NaN      NaN
# 2016-10-16     -2.0     -2.0
# 2016-10-30      3.0      2.0
# 2016-11-13      7.0      1.0
# 2016-11-27      2.0     -4.0
# 2016-12-11      1.0      4.0
# 2016-12-25     -1.0    -11.0
# 2017-01-08     -4.0      1.0
# 2017-01-22      4.0      0.0

# %% [markdown]
# To know what the mean count is for each month in DataFrame.<br>It can done  using resample( ) function.
#
# > **Converting from a higher frequency from a lower frequency is called Downsampling.**
#
# Looking below output we can say,<br>
# Here the dates gets collapsed on a monthly cadence. We haven't had to write our own groupby method and figure it all out ourselves because that is the power of using the resampling built-in function.

# %%
df.resample("M").mean()
# Out:
#                Count 1     Count 2
# 2016-10-31  102.666667  125.333333
# 2016-11-30  112.000000  125.000000
# 2016-12-31  113.500000  121.500000
# 2017-01-31  111.000000  117.000000

# %% [markdown]
# ****
# #### Date-Time Indexing and Slicing
#
# This is a wonderful feature, indeed. Here, partial string indexing can be used to find values from a particular year.

# %%
df["2017"]
# Out:
# /Users/barmanr/.pyenv/versions/3.7.8/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
#             Count 1  Count 2
# 2017-01-08      109      117
# 2017-01-22      113      117

# %%
df['2016-12']
# Out:
# /Users/barmanr/.pyenv/versions/3.7.8/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
#             Count 1  Count 2
# 2016-12-11      114      127
# 2016-12-25      113      116

# %% [markdown]
# Another example can be, to slice on a range of dates.

# %%
df['2016-12' : ]
# Out:
#             Count 1  Count 2
# 2016-12-11      114      127
# 2016-12-25      113      116
# 2017-01-08      109      117
# 2017-01-22      113      117

# %%
pd.mea

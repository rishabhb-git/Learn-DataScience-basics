# %%
import pandas as pd
import numpy as np

# %%
movies    = pd.read_csv("../datasets/movies_dataset/movies.csv", index_col=0)
directors = pd.read_csv("../datasets/movies_dataset/directors.csv", index_col=0)

# %%
movies
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 5     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 4736  48363          0           3      321952
# 4743  48370      27000          19     3151130
# 4748  48375          0           7           0
# 4749  48376          0           3           0
# 4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
directors
# Out:
#           director_name    id gender
# 0         James Cameron  4762   Male
# 1        Gore Verbinski  4763   Male
# 2            Sam Mendes  4764   Male
# 3     Christopher Nolan  4765   Male
# 4        Andrew Stanton  4766   Male
# ...                 ...   ...    ...
# 2344      Shane Carruth  7106   Male
# 2345   Neill Dela Llana  7107    NaN
# 2346        Scott Smith  7108    NaN
# 2347        Daniel Hsia  7109   Male
# 2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 3 columns]

# %% [markdown]
# <br>
#
# Let's merge both dataframes to get complete data start working.
#
# These steps are similar to [Dealing-with-an-IMDB-dataset in our Pandas-3.ipynb file](./Pandas-3.ipynb#Dealing-with-an-IMDB-dataset), i.e. :
#
# - firstly, merging `movies` and `directors`
# - dropping repeated columns

# %%
data = movies.merge(directors, left_on="director_id", right_on="id", how="left")

data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  id_y gender
# 0         4762  2009   Dec  Thursday      James Cameron  4762   Male
# 1         4763  2007   May  Saturday     Gore Verbinski  4763   Male
# ...

# %%
data.drop(["director_id", "id_y"], axis=1, inplace=True)

data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %% [markdown]
# <br>Working downstream with copy of `data` :

# %%
df = data.copy(deep=True)

# %% [markdown]
# #### Observe the dataset :

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_x           1465 non-null   int64
#  1   budget         1465 non-null   int64
#  2   popularity     1465 non-null   int64
#  3   revenue        1465 non-null   int64
#  4   title          1465 non-null   object
#  5   vote_average   1465 non-null   float64
#  6   vote_count     1465 non-null   int64
#  7   year           1465 non-null   int64
#  8   month          1465 non-null   object
#  9   day            1465 non-null   object
#  10  director_name  1465 non-null   object
#  11  gender         1341 non-null   object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 148.8+ KB

# %%
df.describe(include="all")
# Out:
#                 id_x        budget   popularity       revenue   title  \
# count    1465.000000  1.465000e+03  1465.000000  1.465000e+03    1465
# unique           NaN           NaN          NaN           NaN    1465
# top              NaN           NaN          NaN           NaN  Avatar
# freq             NaN           NaN          NaN           NaN       1
# mean    45225.191126  4.802295e+07    30.855973  1.432539e+08     NaN
# std      1189.096396  4.935541e+07    34.845214  2.064918e+08     NaN
# min     43597.000000  0.000000e+00     0.000000  0.000000e+00     NaN
# 25%     44236.000000  1.400000e+07    11.000000  1.738013e+07     NaN
# 50%     45022.000000  3.300000e+07    23.000000  7.578164e+07     NaN
# 75%     45990.000000  6.600000e+07    41.000000  1.792469e+08     NaN
# max     48395.000000  3.800000e+08   724.000000  2.787965e+09     NaN
#
#         vote_average    vote_count         year month     day  \
# count    1465.000000   1465.000000  1465.000000  1465    1465
# ...

# %% [markdown]
# <br>
#
# ### How to make changes in `data` (pre-processing of dataset)
# <br>
#
# __Scenario 1__ : change the `revenue` and `budget` columns from "dollar" unit to "million dollar" unit.

# %%
df["revenue"] = (df["revenue"]/(10**6)).round(2)
df["budget"]  = (df["budget"]/(10**6)).round(2)

df.rename(columns={"revenue" : "revenue_Mdollar",
                     "budget"  : "budget_Mdollar"
                  }
            ,inplace=True)

df
# Out:
#        id_x  budget_Mdollar  popularity  revenue_Mdollar  \
# 0     43597          237.00         150          2787.97
# 1     43598          300.00         139           961.00
# 2     43599          245.00         107           880.67
# 3     43600          250.00         112          1084.94
# 4     43602          258.00         115           890.87
# ...     ...             ...         ...              ...
# 1460  48363            0.00           3             0.32
# 1461  48370            0.03          19             3.15
# 1462  48375            0.00           7             0.00
# 1463  48376            0.00           3             0.00
# 1464  48395            0.22          14             2.04
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %% [markdown]
# <br>
#
# __Scenario 2__: find high rated movies. A high rated movie movie is the one whose `vote_average` column's value is greater than 7.
#
# steps :
# - create a boolean mask.
# - pass the boolean mask within `data.loc` to fetch all such rows that turned out `True` in above boolean mask.

# %%
df.loc[data["vote_average"] > 7]
# Out:
#        id_x  budget_Mdollar  popularity  revenue_Mdollar  \
# 0     43597          237.00         150          2787.97
# 3     43600          250.00         112          1084.94
# 14    43616          250.00         120           956.02
# 16    43619          250.00          94           958.40
# 19    43622          200.00         100          1845.03
# ...     ...             ...         ...              ...
# 1456  48321            0.01          20             7.00
# 1457  48323            0.00           5             0.00
# 1458  48335            0.06          27             3.22
# 1460  48363            0.00           3             0.32
# 1461  48370            0.03          19             3.15
#
#                                           title  vote_average  vote_count  \
# 0                                        Avatar           7.2       11800
# 3                         The Dark Knight Rises           7.6        9106
# ...

# %%
df.loc[df["vote_average"] > 7, ["title" , "director_name", "year"]]
# Out:
#                                           title      director_name  year
# 0                                        Avatar      James Cameron  2009
# 3                         The Dark Knight Rises  Christopher Nolan  2012
# 14    The Hobbit: The Battle of the Five Armies      Peter Jackson  2014
# 16          The Hobbit: The Desolation of Smaug      Peter Jackson  2013
# 19                                      Titanic      James Cameron  1997
# ...                                         ...                ...   ...
# 1456                                 Eraserhead        David Lynch  1977
# 1457                                 The Mighty      Peter Chelsom  1998
# 1458                                         Pi   Darren Aronofsky  1998
# 1460                             The Last Waltz    Martin Scorsese  1978
# 1461                                     Clerks        Kevin Smith  1994
#
# [301 rows x 3 columns]

# %% [markdown]
# <br>__Scenario 3__: find high rated movies on or after 2015 year.

# %%
df[(df["vote_average"] > 7) & (df["year"] >= 2015)]
# Out:
#        id_x  budget_Mdollar  popularity  revenue_Mdollar  \
# 30    43641           190.0         102          1506.25
# 78    43724           150.0         434           378.86
# 106   43773           135.0         100           532.95
# 162   43867           108.0         167           630.16
# 312   44128            75.0          48           108.15
# 394   44281            44.0          68           155.76
# 625   44770            35.0          53           194.56
# 635   44784            40.0          48           165.48
# 808   45194            30.0          65            91.71
# 833   45293            28.0          61           201.63
# 839   45301            28.0          57           133.35
# 1344  47181             5.0          22            24.80
#
#                         title  vote_average  vote_count  year month  \
# 30                  Furious 7           7.3        4176  2015   Apr
# 78         Mad Max: Fury Road           7.2        9427  2015   May
# ...

# %% [markdown]
# <br>__Scenario 4__: find info of all such movies that lexicographically fall below movie "Avengers".

# %%
df[df["title"] < "Avengers"].head()
# Out:
#      id_x  budget_Mdollar  popularity  revenue_Mdollar                title  \
# 0   43597           237.0         150          2787.97               Avatar
# 23  43629           200.0          78          1025.49  Alice in Wonderland
# 40  43656           200.0          45           769.65                 2012
# 41  43657           200.0          39           325.23    A Christmas Carol
# 69  43709           155.0          39           167.30            Alexander
#
#     vote_average  vote_count  year month        day    director_name gender
# 0            7.2       11800  2009   Dec   Thursday    James Cameron   Male
# 23           6.4        4645  2010   Mar  Wednesday       Tim Burton   Male
# 40           5.6        4903  2009   Oct   Saturday  Roland Emmerich   Male
# 41           6.6        1095  2009   Nov  Wednesday  Robert Zemeckis   Male
# 69           5.6         927  2004   Nov     Sunday     Oliver Stone   Male

# %% [markdown]
# <br>__Scenario 5__: filter such movie titles that contain word - "The".
#
# here, "the" and "The" are treated differently i.e. case sensitivity do follows.

# %%
df.loc[df["title"].str.contains("the"), ["title"]]
# Out:
#                                             title
# 1        Pirates of the Caribbean: At World's End
# 8      Pirates of the Caribbean: Dead Man's Chest
# 12    Pirates of the Caribbean: On Stranger Tides
# 14      The Hobbit: The Battle of the Five Armies
# 25            Transformers: Revenge of the Fallen
# ...                                           ...
# 1401                               Get on the Bus
# 1402                     Friday the 13th Part III
# 1421                       Friday the 13th Part 2
# 1432                           All the Real Girls
# 1438                      Everything Put Together
#
# [129 rows x 1 columns]

# %% [markdown]
# <br>__Scenario 6__: such movies that start with "Batman". (remember here, case sensitivity do follows)

# %%
df.loc[df["title"].str.startswith("Batman")]
# Out:
#       id_x  budget_Mdollar  popularity  revenue_Mdollar  \
# 5    43606           250.0         155           873.26
# 74   43716           150.0         115           374.22
# 128  43807           125.0          50           238.21
# 184  43896           100.0          48           336.53
# 257  44025            80.0          59           280.00
# 704  44956            35.0          44           411.35
#
#                                   title  vote_average  vote_count  year month  \
# 5    Batman v Superman: Dawn of Justice           5.7        7004  2016   Mar
# 74                        Batman Begins           7.5        7359  2005   Jun
# 128                      Batman & Robin           4.2        1418  1997   Jun
# 184                      Batman Forever           5.2        1498  1995   May
# 257                      Batman Returns           6.6        1673  1992   Jun
# 704                              Batman           7.0        2096  1989   Jun
#
# ...

# %% [markdown]
# <br>__Scenario 7__: find the 5 top most popular movies.

# %%
df.sort_values(["popularity"], ascending=False).head()
# Out:
#       id_x  budget_Mdollar  popularity  revenue_Mdollar  \
# 58   43692           165.0         724           675.12
# 78   43724           150.0         434           378.86
# 119  43796           140.0         271           655.01
# 120  43797           125.0         206           752.10
# 45   43662           185.0         187          1004.56
#
#                                                  title  vote_average  \
# 58                                        Interstellar           8.1
# 78                                  Mad Max: Fury Road           7.2
# 119  Pirates of the Caribbean: The Curse of the Bla...           7.5
# 120              The Hunger Games: Mockingjay - Part 1           6.6
# 45                                     The Dark Knight           8.2
#
#      vote_count  year month        day      director_name gender
# 58        10867  2014   Nov  Wednesday  Christopher Nolan   Male
# 78         9427  2015   May  Wednesday      George Miller   Male
# ...

# %% [markdown]
# <br>__Scenario 8__: find names and their release year of all movies created by "Christopher Nolan". Present the output with recent released movie at the top and oldest released movie at the bottom.

# %%
(df.loc[df["director_name"]=="Christopher Nolan", ["title", "year"]]
    .sort_values(["year"], ascending=False)
)
# Out:
#                       title  year
# 58             Interstellar  2014
# 3     The Dark Knight Rises  2012
# 59                Inception  2010
# 45          The Dark Knight  2008
# 641            The Prestige  2006
# 74            Batman Begins  2005
# 565                Insomnia  2002
# 1341                Memento  2000

# %% [markdown]
# <br>__Scenario 9__: Count of all those movies which were released in the year 2015, 2016 or 2012.

# %%
mask = df['year'].isin([2015, 2016, 2012])
mask
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: year, Length: 1465, dtype: bool

# %%
print(df.loc[mask, ["title"]].count())      ## counts the number of non-NA rows in one column

df.loc[mask, ["title"]]
# Out:
# title    116
# dtype: int64
#                                    title
# 2                                Spectre
# 3                  The Dark Knight Rises
# 5     Batman v Superman: Dawn of Justice
# 13                        Men in Black 3
# 20                            Battleship
# ...                                  ...
# 1370                   The Boy Next Door
# 1395                            Amnesiac
# 1410                           Stonewall
# 1439                           Good Kill
# 1440      Alleluia! The Devil's Carnival
#
# [116 rows x 1 columns]

# %% [markdown]
# <br>__Scenario 10__: find all movies of a director.

# %%
df["director_name"].value_counts()
# Out:
# Steven Spielberg      26
# Martin Scorsese       19
# Clint Eastwood        19
# Woody Allen           18
# Ridley Scott          16
#                       ..
# Tim Hill               5
# Jonathan Liebesman     5
# Roman Polanski         5
# Larry Charles          5
# Nicole Holofcener      5
# Name: director_name, Length: 199, dtype: int64

# %% [markdown]
# ## Groupings
#
# - via `.groupby()`
#
# Internally, how Pandas perfrom Grouping ?
# 1. When `.groupby([col1, col2])` is called on a dataframe, for a column, firstly Pandas creats smaller "groups" w.r.t. those columns (i.e. col1, col2, etc.).
#
#
# 2. Secondly, Pandas "apply" an aggregate function like - sum, min, max, count, etc.
#
#
# 3. Thirdly and finally, Pandas would "combine" the aggregated results.
#
#
# <h3 style="text-align:center;">GROUPBY -> APPLY of aggregate functions -> Combine</h3>

# %% [markdown]
# __Scneario 11__: find maximum budget spend by each director.

# %%
## step 1.

df.groupby(["director_name"])

# %%
## step 2. and 3.

df.groupby(["director_name"])["budget_Mdollar"].max()
# Out:
# director_name
# Adam McKay                     100.0
# Adam Shankman                   80.0
# Alejandro González Iñárritu    135.0
# Alex Proyas                    140.0
# Alexander Payne                 30.0
#                                ...
# Wes Craven                      40.0
# Wolfgang Petersen              175.0
# Woody Allen                     30.0
# Zack Snyder                    250.0
# Zhang Yimou                     94.0
# Name: budget_Mdollar, Length: 199, dtype: float64

# %% [markdown]
# <br>__Scenario 12__: find count of movies made by each director. The director with most number of movies made should appear at top.
#
# - `.groupby(["director_name"])["title"].count()` => gives counts of all "title" under each unique "director_name"
# - `.sort_values()` => sort the count values

# %%
df.groupby(["director_name"])["title"].count().sort_values(ascending=False)
# Out:
# director_name
# Steven Spielberg    26
# Clint Eastwood      19
# Martin Scorsese     19
# Woody Allen         18
# Robert Rodriguez    16
#                     ..
# Paul Weitz           5
# John Madden          5
# Paul Verhoeven       5
# John Whitesell       5
# Kevin Reynolds       5
# Name: title, Length: 199, dtype: int64

# %% [markdown]
# <br>__Scenario 13__: find the "Most Productive Director" - the director who produced most number of movies per year.

# %%
df.groupby(["director_name"])["year"].min().head()

## when did a Director released his first movie. Or, in which year did a Director start his career.
# Out:
# director_name
# Adam McKay                     2004
# Adam Shankman                  2001
# Alejandro González Iñárritu    2000
# Alex Proyas                    1994
# Alexander Payne                1999
# Name: year, dtype: int64

# %%
df.groupby(["director_name"])["year"].max().head()
# Out:
# director_name
# Adam McKay                     2015
# Adam Shankman                  2012
# Alejandro González Iñárritu    2015
# Alex Proyas                    2016
# Alexander Payne                2013
# Name: year, dtype: int64

# %% [markdown]
# For each `director_name`, if we subtract his min-year value from his max-year value, we would get the career span of each director. Now, for each director, his total movies divided by his career span would give total movies produced per year.
#
# The maximum of this value would correspond to "Most Productive Director".
#
# Let's perform a groupby on `director_name` and perform aggregations on `title` and `year` columns, where we would need aggregate-count of `title` column, and aggregate-min & aggregate-max of `year` column.
#
# This process is essentially : __GROUPBY -> APPLY of agg functions -> COMBINE__

# %%
df_agg = df.groupby(["director_name"])[["title" , "year"]].aggregate({"title" : "count",
                                                             "year" : ["min", "max"]
                                                            })

df_agg
# Out:
#                             title  year
#                             count   min   max
# director_name
# Adam McKay                      6  2004  2015
# Adam Shankman                   8  2001  2012
# Alejandro González Iñárritu     6  2000  2015
# Alex Proyas                     5  1994  2016
# Alexander Payne                 5  1999  2013
# ...                           ...   ...   ...
# Wes Craven                     10  1984  2011
# Wolfgang Petersen               7  1981  2006
# Woody Allen                    18  1977  2013
# Zack Snyder                     7  2004  2016
# Zhang Yimou                     6  2002  2014
#
# [199 rows x 3 columns]

# %%
df_agg["year"]["max"].head()

## doing this gives same Series like we got above
# Out:
# director_name
# Adam McKay                     2015
# Adam Shankman                  2012
# Alejandro González Iñárritu    2015
# Alex Proyas                    2016
# Alexander Payne                2013
# Name: max, dtype: int64

# %%
df_agg.columns
# Out:
# MultiIndex([('title', 'count'),
#             ( 'year',   'min'),
#             ( 'year',   'max')],
#            )

# %% [markdown]
# Now, it's indeed cumbersome to use and understand `df_agg` , because its a Multilevel-Indexed dataframe.
#
# 1. So let's convert its columns into Linear-Indexed.
#
#
# 2. After step 1, reset the index and make `director_name` as a normal column.

# %%
df_agg.columns = ["_".join(col) for col in df_agg.columns]      ## step 1

df_agg.reset_index(inplace=True)                                ## step 2

df_agg
# Out:
#                    director_name  title_count  year_min  year_max
# 0                     Adam McKay            6      2004      2015
# 1                  Adam Shankman            8      2001      2012
# 2    Alejandro González Iñárritu            6      2000      2015
# 3                    Alex Proyas            5      1994      2016
# 4                Alexander Payne            5      1999      2013
# ..                           ...          ...       ...       ...
# 194                   Wes Craven           10      1984      2011
# 195            Wolfgang Petersen            7      1981      2006
# 196                  Woody Allen           18      1977      2013
# 197                  Zack Snyder            7      2004      2016
# 198                  Zhang Yimou            6      2002      2014
#
# [199 rows x 4 columns]

# %%
## create new column of "active_years"

df_agg["active_years"] = df_agg["year_max"] - df_agg["year_min"]

df_agg.head()
# Out:
#                  director_name  title_count  year_min  year_max  active_years
# 0                   Adam McKay            6      2004      2015            11
# 1                Adam Shankman            8      2001      2012            11
# 2  Alejandro González Iñárritu            6      2000      2015            15
# 3                  Alex Proyas            5      1994      2016            22
# 4              Alexander Payne            5      1999      2013            14

# %% [markdown]
# <br>Now,
#
# Productivity of a Director = Movies made by him per year = __title_count ÷ active_years__

# %%
df_agg["productivity_of_director"] = df_agg["title_count"] / df_agg["active_years"]

df_agg
# Out:
#                    director_name  title_count  year_min  year_max  \
# 0                     Adam McKay            6      2004      2015
# 1                  Adam Shankman            8      2001      2012
# 2    Alejandro González Iñárritu            6      2000      2015
# 3                    Alex Proyas            5      1994      2016
# 4                Alexander Payne            5      1999      2013
# ..                           ...          ...       ...       ...
# 194                   Wes Craven           10      1984      2011
# 195            Wolfgang Petersen            7      1981      2006
# 196                  Woody Allen           18      1977      2013
# 197                  Zack Snyder            7      2004      2016
# 198                  Zhang Yimou            6      2002      2014
#
#      active_years  productivity_of_director
# 0              11                  0.545455
# 1              11                  0.727273
# ...

# %%
df_agg.sort_values(["productivity_of_director"], ascending=False, inplace=True)

# df_agg.reset_index(inplace=True)
### no need to do reset_index, because this will convert the existing implicit indices into a new column namely-"index". 

df_agg.head()
# Out:
#         director_name  title_count  year_min  year_max  active_years  \
# 190       Tyler Perry            9      2006      2013             7
# 73    Jason Friedberg            5      2006      2010             4
# 169        Shawn Levy           11      2002      2014            12
# 158  Robert Rodriguez           16      1992      2014            22
# 1       Adam Shankman            8      2001      2012            11
#
#      productivity_of_director
# 190                  1.285714
# 73                   1.250000
# 169                  0.916667
# 158                  0.727273
# 1                    0.727273

# %% [markdown]
# Hence, these are our top 5 Most Productive Directors!!

# %% [markdown]
# <br>
#
# __Scenario 14__: For the years 2010-2015 (both inclusive), find - average, lowest and highest `vote_average` of movies released in each year.

# %%
(df[(df["year"] >= 2010) & (df["year"] <= 2015)]
 .groupby(["year"])
 .aggregate({"vote_average" : ["mean", "min", "max"]})
)
# Out:
#      vote_average
#              mean  min  max
# year
# 2010     6.223810  4.2  8.1
# 2011     6.098507  4.1  7.7
# 2012     6.216327  4.9  7.8
# 2013     6.315789  3.3  7.9
# 2014     6.313208  4.1  8.1
# 2015     6.141463  3.9  7.7

# %% [markdown]
# <br>__Scenario 15__:
#
# Find all "High Budget Directors".<br>A "high budget director" is a director who has, at least once in his life time, created a movie with budget >= 100M $.
#
# 1. firstly, we should find maximum budget ever spend by each director => via `groupby()["budget"].max()`
# 2. then, filter out such directors whose maximum budget surpassed the level of 100M $.

# %%
## step 1

# df.groupby(["director_name"])["budget_Mdollar"].max()
### this gives a Series, let's convert into a dataframe via reset_index

df_dir_maxBudget = df.groupby(["director_name"])["budget_Mdollar"].max().reset_index()

df_dir_maxBudget
# Out:
#                    director_name  budget_Mdollar
# 0                     Adam McKay           100.0
# 1                  Adam Shankman            80.0
# 2    Alejandro González Iñárritu           135.0
# 3                    Alex Proyas           140.0
# 4                Alexander Payne            30.0
# ..                           ...             ...
# 194                   Wes Craven            40.0
# 195            Wolfgang Petersen           175.0
# 196                  Woody Allen            30.0
# 197                  Zack Snyder           250.0
# 198                  Zhang Yimou            94.0
#
# [199 rows x 2 columns]

# %%
## step 2

df_dir_maxBudget.loc[df_dir_maxBudget["budget_Mdollar"] > 100]
# Out:
#                    director_name  budget_Mdollar
# 2    Alejandro González Iñárritu           135.0
# 3                    Alex Proyas           140.0
# 5                 Andrew Adamson           225.0
# 10                       Ang Lee           137.0
# 15              Barry Sonnenfeld           225.0
# ..                           ...             ...
# 185                    Tim Story           130.0
# 187                  Tom Shadyac           175.0
# 188                   Tom Tykwer           102.0
# 195            Wolfgang Petersen           175.0
# 197                  Zack Snyder           250.0
#
# [79 rows x 2 columns]

# %% [markdown]
# These are such 79 directors called as - "High Budget Directors".

# %% [markdown]
# <br>__Scenario 16__: Find the details of all such movies, that were made by a "High Budget Director".
#
# This is similar to __Scenario 15__, and after finding out high-budget-directors, we can find all movies of every high-budget-director, via join or merge. But, that would be lot of operations and lengthy approach.
#
# We can use __Group-based-Filtering__ to achieve this.
#
# - `.filter()`
#
# Approach :- Create groups (via `groupby`) of each director. Pass each group in a filter-based function that returns `True` if the director's maximum budgeted movie has been above $ 1M, otherwise `False`. Certainly, the boolean value corresponds to the director_name; `True` means such a director is "High Budget Director".

# %%
df.groupby(["director_name"]).filter(lambda x: x["budget_Mdollar"].max() >= 100)

## lambda function says, if any director's maximum budget (GROUP -> APPLY)
# Out:
#        id_x  budget_Mdollar  popularity  revenue_Mdollar  \
# 0     43597          237.00         150          2787.97
# 1     43598          300.00         139           961.00
# 2     43599          245.00         107           880.67
# 3     43600          250.00         112          1084.94
# 4     43602          258.00         115           890.87
# ...     ...             ...         ...              ...
# 1450  48267            0.40          33           100.00
# 1451  48268            0.20          13             4.51
# 1452  48274            0.00           5             2.61
# 1458  48335            0.06          27             3.22
# 1460  48363            0.00           3             0.32
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %% [markdown]
# <br>__Scenario 17__:
#
# Which movies were "Expensive" (or, "Over Budget") an which were "Inexpensive".
#
# <code>
#     budget_minus_meanBudget = budget - budget.mean()
#     if budget_minus_meanBudget > 0:
#         "Expensive or Over Budget"
#     else:
#         "Inexpensive"
# </code>

# %%
df_transform = df.copy()

df_transform
# Out:
#        id_x  budget_Mdollar  popularity  revenue_Mdollar  \
# 0     43597          237.00         150          2787.97
# 1     43598          300.00         139           961.00
# 2     43599          245.00         107           880.67
# 3     43600          250.00         112          1084.94
# 4     43602          258.00         115           890.87
# ...     ...             ...         ...              ...
# 1460  48363            0.00           3             0.32
# 1461  48370            0.03          19             3.15
# 1462  48375            0.00           7             0.00
# 1463  48376            0.00           3             0.00
# 1464  48395            0.22          14             2.04
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
def sub_mean(x):
    return x["budget_Mdollar"] - x["budget_Mdollar"].mean()
    

df_transform["budget_minus_meanBudget"] = df_transform.groupby(["director_name"]).transform(sub_mean)

df_transform
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:41, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'budget_Mdollar'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [179], in <module>
#       1 def sub_mean(x):
# ...

# %% [markdown]
# > this results in KeyError because, there is a limitation of `transform` that it allows __only 1 column__ to be used with it. Since we are operating on "budget_Mdollar" column, so after doing `groupby()` we'll have to fetch out "budget_Mdollar" and then proceed for the `transform`.
#
# ⛔ Generally, `transform` is not preferred because it can only be used on 1 column, at 1 time.<br>
# Whereas with `apply` multiple columns can be in single time, so it's mostly preferred.
#
# Above usage is wrong, Correct way to use `transform` is this :

# %%
def sub_mean(x):
    return round(x - x.mean(), 2)


df_transform["budget_minus_meanBudget"] = df_transform.groupby(["director_name"])["budget_Mdollar"].transform(sub_mean)
# Out:
#        id_x  budget_Mdollar  popularity  revenue_Mdollar  \
# 0     43597          237.00         150          2787.97
# 1     43598          300.00         139           961.00
# 2     43599          245.00         107           880.67
# 3     43600          250.00         112          1084.94
# 4     43602          258.00         115           890.87
# ...     ...             ...         ...              ...
# 1460  48363            0.00           3             0.32
# 1461  48370            0.03          19             3.15
# 1462  48375            0.00           7             0.00
# 1463  48376            0.00           3             0.00
# 1464  48395            0.22          14             2.04
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %% [markdown]
# <br>__Scenario 18__: Which movie was a "risky" investment. Also discussed [here in Pandas-3 file](./Pandas-3.ipynb#Scenario-9:-Finding-risky-movie,-using-apply-function)
#
# syntax : `apply`
#
# This can be found via the logic that, if average revenue of the director is more than the movie's budget, then the movie can be said as "risky". To do so, we can groupby the dataframe by the director's name, and using `apply` function, find the required data.
#
# Means, for a Director,
# - `avg(revenue)` of all his movies > `budget` of 1 movie => "Risky" movie

# %%
def calculate_risky(x):
    x["risky"] = (x["budget_Mdollar"] - x["revenue_Mdollar"].mean()) > 0     ## RHS generates either True or False value
    return x


df_risky = df.groupby("director_name").apply(calculate_risky)

df_risky
# Out:
#        id_x  budget_Mdollar  popularity  revenue_Mdollar  \
# 0     43597          237.00         150          2787.97
# 1     43598          300.00         139           961.00
# 2     43599          245.00         107           880.67
# 3     43600          250.00         112          1084.94
# 4     43602          258.00         115           890.87
# ...     ...             ...         ...              ...
# 1460  48363            0.00           3             0.32
# 1461  48370            0.03          19             3.15
# 1462  48375            0.00           7             0.00
# 1463  48376            0.00           3             0.00
# 1464  48395            0.22          14             2.04
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %% [markdown]
# <br>Let's see which movies were actually "Risky" :

# %%
df_risky[df_risky["risky"] == True]
# Out:
#        id_x  budget_Mdollar  popularity  revenue_Mdollar  \
# 7     43608           200.0         107           586.09
# 12    43614           380.0         135          1045.71
# 15    43618           200.0          37           310.67
# 20    43624           209.0          64           303.03
# 24    43630           210.0           3           459.36
# ...     ...             ...         ...              ...
# 1347  47224             5.0           7             3.26
# 1349  47229             5.0           3             4.84
# 1351  47233             5.0           6             0.00
# 1356  47263            15.0          10             0.00
# 1383  47453             3.5           4             0.00
#
#                                             title  vote_average  vote_count  \
# 7                               Quantum of Solace           6.1        2965
# 12    Pirates of the Caribbean: On Stranger Tides           6.4        4948
# ...

# %% [markdown]
# <br>__Scenario 19__: all movies of Christopher Nolan

# %%
df.loc[df["director_name"] == "Christopher Nolan", ["revenue_Mdollar", "budget_Mdollar"]]
# Out:
#       revenue_Mdollar  budget_Mdollar
# 3             1084.94           250.0
# 45            1004.56           185.0
# 58             675.12           165.0
# 59             825.53           160.0
# 74             374.22           150.0
# 565            113.71            46.0
# 641            109.68            40.0
# 1341            39.72             9.0

# %%
(df.loc[df["director_name"] == "Christopher Nolan", ["revenue_Mdollar", "budget_Mdollar"]]
   .apply([np.sum, np.mean, np.max, np.min], axis=0)    ## vertical operation
)
# Out:
#       revenue_Mdollar  budget_Mdollar
# sum          4227.480        1005.000
# mean          528.435         125.625
# amax         1084.940         250.000
# amin           39.720           9.000

# %%
(df.loc[df["director_name"] == "Christopher Nolan", ["revenue_Mdollar", "budget_Mdollar"]]
   .apply([np.sum, np.mean, np.max, np.min], axis=1)     ## horizontal operation, as per axis
)
# Out:
#           sum     mean     amax   amin
# 3     1334.94  667.470  1084.94  250.0
# 45    1189.56  594.780  1004.56  185.0
# 58     840.12  420.060   675.12  165.0
# 59     985.53  492.765   825.53  160.0
# 74     524.22  262.110   374.22  150.0
# 565    159.71   79.855   113.71   46.0
# 641    149.68   74.840   109.68   40.0
# 1341    48.72   24.360    39.72    9.0

# %% [markdown]
# <br>Custom functions can also be specified within `.apply`.
